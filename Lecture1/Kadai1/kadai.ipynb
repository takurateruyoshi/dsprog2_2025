# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import time

# %%
path = ''
db_name = 'github_google.db'

try:
    #DBへのコネクションを確立
    conn = sqlite3.connect(path + db_name)

    #SQL(ROBを操作するための言語)を実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # SQL文の作成
    # テーブルの作成
    sql = "CREATE TABLE repositories (id INTEGER PRIMARY KEY, name TEXT, pl TEXT, star INTEGER);"

    # SQL文の実行
    cur.execute(sql)

    conn.commit()  # 変更を保存

except sqlite3.Error as e:
    print('SQLite error:', e)
    
finally:
    # DBへの接続を閉じる
    conn.close()

# %%
page_now = 1

# %%
# https://github.com/orgs/google/repositories?page=1  ---  リポジトリ一覧ページのURL
repositories = []

for page in range(page_now, 95):
    time.sleep(1)
    url = f"https://github.com/orgs/google/repositories?page={page}"
    print(f"ページ{page}: {url}")
    try:
        res = requests.get(url)

        #200以外の接続を弾く
        res.raise_for_status()
        
        soup = BeautifulSoup(res.text, 'html.parser')

        selsectors = soup.find_all(class_ = "ListItem-module__listItem--k4eMk")
        print(f"ページ{page}のセクター数: {len(selsectors)}")
        for selsector in selsectors:

            # リポジトリ名、プログラミング言語、スター数を取得し改行を削除して文字に変換
            name = selsector.find(class_ = "Title-module__anchor--GmXUE Title-module__inline--oM0P7")
            name = name.text.strip() if name else "N/A"
            pl = selsector.find(class_ = "ReposListItem-module__Text_4--mkG7R")
            pl = pl.text.strip() if pl else "N/A"
            star = selsector.find(class_ = "ReposListItem-module__Link_1--v5NDF prc-Link-Link-85e08")
            star = star.text.strip() if star else "0"

            # スター数の文字列を整数に変換
            if star[-1] == "k":
                star = int(float(star[:-1]) * 1000)
            else:
                star = int(star)

            #取得したデータをリポジトリリストに追加
            print(f"name:{name} pl:{pl} star:{star}")
            repositories.append((name, pl, star))
            
    except requests.RequestException as e:
        print(f"Error fetching page {page}: {e}")
        print("次回はこのページから再開します")
        page_now = page
        break
# Out:
# ページ53: https://github.com/orgs/google/repositories?page=53
# ページ53のセクター数: 30
# name:dart-json_diff pl:Dart star:19
# name:mystyle pl:Python star:18
# name:web-bsd-hunt pl:Go star:8
# name:vk_callback_swapchain pl:C++ star:14
# name:butteraugli pl:C++ star:141
# name:spirv-tutor pl:Shell star:8
# name:stm32-bootloader-client-rs pl:Rust star:3
# name:gfw-deployments pl:Python star:39
# name:coop-analytics pl:Python star:3
# name:fledge-key-value-server pl:N/A star:0
# name:ms-tpm-20-ref pl:C star:142
# name:libprotobuf-mutator-asn1 pl:C++ star:9
# name:open-source-pdks pl:N/A star:9
# name:magic-github-proxy pl:Python star:8
# name:codeu-starter-project pl:Java star:20
# name:codeu_project_2018 pl:Java star:5
# name:u2f-ref-code pl:JavaScript star:179
# name:google-drive-proxy pl:C# star:39
# name:google-drive-shell-extension pl:C++ star:69
# name:chive-prosody pl:HTML star:4
# name:cross-device-sdk pl:Kotlin star:14
# name:schemaorg-java pl:Java star:41
# name:crumsort-rs pl:Rust star:5
# name:plusfish pl:C++ star:10
# name:sqlcommenter-php pl:PHP star:0
# name:connectedappssdk pl:Java star:3
# name:go-cabfile pl:Go star:7
# name:GCP-deployment-scripts-for-PI-Core pl:PowerShell star:9
# name:WebFundamentals pl:JavaScript star:2500
# name:go-flow-levee pl:Go star:17
# ページ54: https://github.com/orgs/google/repositories?page=54
# ページ54のセクター数: 30
# name:chiplets-cost-model pl:Python star:5
# name:chatbase-python pl:Python star:44
# name:kiosk-app-reference-implementation pl:Kotlin star:2
# name:ai-weather-climate pl:Python star:5
# name:viai-sdk pl:Python star:3
# name:skywater-pdk-ip-sky90fd_fd_ip_sram pl:N/A star:0
# name:skywater-pdk-libs-sky90fd_fd_io pl:N/A star:0
# name:skywater-pdk-libs-sky90fd_fd_pr pl:N/A star:0
# name:skywater-pdk-libs-sky90fd_fd_sc pl:N/A star:0
# name:skywater-pdk-libs-sky90fd_osu_sc pl:N/A star:0
# name:one-weird-trick pl:Jupyter Notebook star:0
# name:pmax_migration pl:Python star:0
# name:stable-retraining-conversational-agents pl:N/A star:0
# name:go-pcie-tlp pl:Go star:11
# name:globalfoundries-pdks pl:N/A star:3
# name:globalfoundries-pdk-libs-gf180mcu_fd_bd_sram pl:N/A star:0
# name:HyperProtoBench pl:C++ star:8
# name:live-transcribe-speech-engine pl:Java star:222
# name:sxg-validator pl:JavaScript star:3
# name:rappor pl:R star:163
# name:bazel-to-cmake pl:Python star:45
# name:e3d_lstm pl:Python star:56
# name:santa-tracker-android pl:Java star:399
# name:log4jscanner pl:Go star:116
# name:zoom-to-inpaint pl:Python star:6
# name:chrometracing pl:Go star:3
# name:DAPLink-port pl:C star:13
# name:causalexpanalysis pl:R star:4
# name:poweranalysis pl:R star:5
# name:MOE pl:Java star:76
# ページ55: https://github.com/orgs/google/repositories?page=55
# ページ55のセクター数: 30
# name:tritious pl:JavaScript star:8
# name:dcm-trix-addon pl:JavaScript star:6
# name:argtail-check pl:Go star:8
# name:squidwarden pl:Go star:11
# name:qhbm-library pl:Python star:16
# name:BEGIN-dataset pl:N/A star:5
# name:randen pl:C++ star:30
# name:tock-on-titan pl:Rust star:21
# name:makerspace-lipo-charger pl:Makefile star:7
# name:ion pl:C++ star:91
# name:makerspace-partsbin pl:Python star:12
# name:import-mailbox-to-gmail pl:Python star:73
# name:tf_mesh_renderer pl:Python star:112
# name:ctfscoreboard pl:Python star:56
# name:cocoapods-size pl:Python star:29
# name:cluster-scheduler-simulator pl:Scala star:52
# name:dokka pl:Kotlin star:468
# name:etc2comp pl:C++ star:124
# name:periph pl:Go star:163
# name:tensorflow-recorder pl:Python star:32
# name:hotel-ads-etl-tool pl:Python star:7
# name:budget-protector pl:JavaScript star:0
# name:jsontoken pl:Java star:15
# name:infra-structured-map pl:Java star:6
# name:martian-java pl:Java star:12
# name:i18n_sanitycheck pl:Java star:7
# name:nel-reporter-java pl:Java star:7
# name:gtm-currency-rates-sync pl:JavaScript star:10
# name:embed-dart-vm pl:C++ star:19
# name:Kotlin-FirViewer pl:Kotlin star:6
# ページ56: https://github.com/orgs/google/repositories?page=56
# ページ56のセクター数: 30
# name:cwisstable pl:C++ star:15
# name:swift-jupyter pl:Python star:92
# name:bongo pl:Rust star:8
# name:gfbuild-shadertrap pl:Shell star:4
# name:google-my-business-samples pl:Python star:78
# name:swift-benchmark pl:Swift star:50
# name:tmppy pl:Python star:14
# name:radium pl:HTML star:3
# name:libcppbor pl:C++ star:5
# name:AndroidForegroundCompat pl:Java star:6
# name:airdialogue pl:Python star:11
# name:aistreamer pl:C++ star:58
# name:skywater-pdk-libs-sky130_fd_pr_reram pl:N/A star:11
# name:sample-sql-translator pl:Python star:15
# name:gfbuild-SPIRV-Tools pl:Shell star:10
# name:vapso pl:JavaScript star:8
# name:llvm-bazel pl:Starlark star:44
# name:asylo pl:C++ star:127
# name:knative-gcp pl:Go star:74
# name:fractribution pl:Python star:13
# name:github_actions_playground pl:Python star:1
# name:nanopb-cpputest-comparators pl:C++ star:1
# name:tweakr-codelab pl:Kotlin star:4
# name:where-am-i pl:Kotlin star:15
# name:responsible-innovation pl:Jupyter Notebook star:1
# name:blockbuster pl:Python star:6
# name:ekep-analysis pl:Shell star:1
# name:android-gradle-dsl pl:HTML star:108
# name:gitiles pl:Java star:181
# name:security-annotation-tools pl:Kotlin star:5
# ページ57: https://github.com/orgs/google/repositories?page=57
# ページ57のセクター数: 30
# name:rfmt pl:Python star:14
# name:java-run pl:Java star:2
# name:quiver-log pl:Dart star:14
# name:hardware-perfcounter pl:C star:20
# name:gfbuild-graphicsfuzz pl:Shell star:6
# name:dv360_feature_adoption pl:JavaScript star:2
# name:cortex-demos pl:C++ star:12
# name:universal-dash-transmuxer pl:C++ star:25
# name:physics-math-tutorials pl:Jupyter Notebook star:4
# name:longt5 pl:N/A star:0
# name:gcb-tools pl:Go star:2
# name:scrollytell pl:TypeScript star:11
# name:wide_bnn_sampling pl:Python star:1
# name:dynamic-video-depth pl:Python star:40
# name:gnostic-go-generator pl:Go star:19
# name:IdleWakeups pl:C# star:3
# name:java-video-live-stream pl:Shell star:1
# name:depan pl:Java star:19
# name:disapproved-ads-auditor pl:Python star:3
# name:hs-ten pl:Haskell star:3
# name:hs-portray pl:Haskell star:2
# name:dtraceStacksToPprof pl:Go star:0
# name:grumpy pl:Go star:640
# name:web-prototyping-tool pl:TypeScript star:9
# name:rust-async-coap pl:Rust star:12
# name:agera pl:Java star:633
# name:html-quiz pl:JavaScript star:105
# name:fledge-shim pl:TypeScript star:6
# name:rainbow pl:C++ star:0
# name:secret-manager-with-sendgrid pl:Python star:2
# ページ58: https://github.com/orgs/google/repositories?page=58
# ページ58のセクター数: 30
# name:standard-payments pl:N/A star:5
# name:vulncode-db pl:Python star:72
# name:ktsan pl:N/A star:71
# name:inspectorspacetime pl:JavaScript star:20
# name:bi-tempered-loss pl:Python star:27
# name:go-cpy pl:Go star:5
# name:exists-ref pl:Rust star:1
# name:nucleus pl:C++ star:122
# name:crclib.dart pl:Dart star:20
# name:overcoming-conflicting-data pl:N/A star:3
# name:pezl pl:Go star:0
# name:aiyprojects-raspbian pl:Python star:694
# name:cuckoo-index pl:C++ star:17
# name:goexpect pl:Go star:138
# name:observable pl:Dart star:24
# name:mechahamster pl:C# star:202
# name:REAPER pl:C++ star:96
# name:ghost-dataplane pl:C++ star:1
# name:music-synthesizer-for-android pl:Jupyter Notebook star:84
# name:ga-serverless-streaming pl:Python star:6
# name:pyaedj pl:Python star:9
# name:structured_labels pl:Python star:1
# name:svcca pl:Jupyter Notebook star:141
# name:orthotope pl:Haskell star:12
# name:ezgantt pl:JavaScript star:26
# name:videotts pl:JavaScript star:0
# name:hs-dependent-literals pl:Haskell star:2
# name:floodlight-audit pl:JavaScript star:8
# name:nginx-sxg-module pl:C star:17
# name:climb-tracker pl:Java star:11
# ページ59: https://github.com/orgs/google/repositories?page=59
# ページ59のセクター数: 30
# name:hs-numeric-logarithms pl:Haskell star:3
# name:hs-collate pl:Haskell star:3
# name:hs-batching pl:Haskell star:3
# name:hs-fin-vec pl:Haskell star:3
# name:hs-niche-containers pl:Haskell star:2
# name:hs-attenuation pl:Haskell star:2
# name:hs-wrapped pl:Haskell star:3
# name:closure-stylesheets pl:Java star:65
# name:cloudprober pl:Go star:149
# name:h2e_technical_documentation pl:N/A star:33
# name:integers pl:C++ star:8
# name:makani pl:C++ star:118
# name:youtube-8m pl:Python star:852
# name:amt-forensics pl:Python star:5
# name:healthcare-text-annotation pl:N/A star:10
# name:PS3ControllerAutoSleep pl:AppleScript star:15
# name:skywater-pdk-libs-sky130_fd_bd_sram pl:N/A star:6
# name:paragraph pl:C++ star:8
# name:private-retrieval pl:Java star:9
# name:google-visualization-python pl:Python star:47
# name:flutter_flux pl:Dart star:35
# name:go-pbmoney pl:Go star:6
# name:farmhash pl:C++ star:104
# name:actions-on-google-template-sdk pl:N/A star:7
# name:startup-os pl:Java star:106
# name:phoneme-aligned-graphemes-in-tts pl:HTML star:2
# name:RED pl:MATLAB star:41
# name:segy-stack pl:C++ star:10
# name:php-photoslibrary pl:PHP star:32
# name:xsecurelock-saver-rs pl:Rust star:11
# ページ60: https://github.com/orgs/google/repositories?page=60
# ページ60のセクター数: 30
# name:floq-client pl:Python star:5
# name:upvote_py2 pl:Python star:31
# name:gomemcache pl:Go star:470
# name:autocjk pl:Python star:5
# name:exposure-notifications-internals pl:Java star:32
# name:gfbuild-amber pl:Shell star:4
# name:lexical-masks pl:Python star:5
# name:mimosa pl:C++ star:5
# name:aistplusplus_dataset pl:JavaScript star:4
# name:gfbuild-glslang pl:Shell star:9
# name:android-cuttlefish-authentication pl:Python star:1
# name:language-resources pl:C++ star:93
# name:infact pl:C++ star:18
# name:localized-narratives pl:HTML star:11
# name:platforms-bios-buildenv pl:Dockerfile star:1
# name:x509test pl:Python star:14
# name:percy-node pl:JavaScript star:14
# name:web_notifications.dart pl:Dart star:12
# name:LLpatch pl:C++ star:7
# name:compare-codecs pl:Python star:16
# name:certificate-transparency-rfcs pl:Python star:36
# name:librato.dart pl:Dart star:5
# name:kasane pl:Python star:17
# name:cloud-print-connector pl:Go star:183
# name:gcm pl:Java star:512
# name:schism pl:Scheme star:67
# name:concourse-resources pl:Go star:19
# name:gtm-oauth2 pl:Objective-C star:69
# name:traceout pl:Go star:13
# name:go-patchutils pl:Go star:6
# ページ61: https://github.com/orgs/google/repositories?page=61
# ページ61のセクター数: 30
# name:disable-keyboard-shortcuts pl:Makefile star:12
# name:aiyprojects-raspbian-tools pl:Python star:5
# name:explaining-in-style pl:Jupyter Notebook star:27
# name:fuzzer-test-suite pl:C star:280
# name:vulkan-pre-rotation-demo pl:C++ star:8
# name:gfbuild-llpc pl:Shell star:4
# name:intellij-kotlin pl:Kotlin star:32
# name:emu-control pl:Go star:2
# name:deluca-lung pl:Python star:3
# name:ehr-predictions pl:Python star:17
# name:aichoreographer pl:HTML star:4
# name:makerfaire-booth pl:Python star:10
# name:lovefield pl:JavaScript star:367
# name:testimony pl:Go star:22
# name:vim-selector pl:Vim Script star:11
# name:cpp-proto-builder pl:C++ star:3
# name:open-chiplet pl:N/A star:3
# name:trusted-worklet-server pl:C++ star:2
# name:trusted-key-value-server pl:C++ star:2
# name:prediction_framework pl:Python star:7
# name:deluca-igpc pl:Jupyter Notebook star:3
# name:cssi-labs pl:HTML star:120
# name:stenographer pl:Go star:232
# name:usb-cereal pl:HTML star:12
# name:rtb_troubleshooting_connector pl:JavaScript star:2
# name:nsc-tutorial pl:Jupyter Notebook star:2
# name:hrepl pl:Haskell star:8
# name:dv-3po pl:JavaScript star:5
# name:CSP-Validator pl:Python star:14
# name:gsrsup pl:C++ star:3
# ページ62: https://github.com/orgs/google/repositories?page=62
# ページ62のセクター数: 30
# name:AFL pl:C star:665
# name:keytransparency pl:Go star:150
# name:gitprotocolio pl:Go star:18
# name:libpam-policycache pl:C star:18
# name:pikov pl:Jupyter Notebook star:6
# name:federated-ml-health pl:Jupyter Notebook star:13
# name:rich-test-results pl:Java star:21
# name:neural-light-transport pl:Python star:36
# name:codeu_project_2017 pl:Java star:104
# name:gfbuild-swiftshader pl:Shell star:5
# name:python-cloud-utils pl:Python star:19
# name:domaintest pl:Java star:15
# name:mysteryofthreebots pl:TypeScript star:12
# name:dnae pl:Python star:5
# name:last-fm-dashboard pl:JavaScript star:15
# name:guice-aqueduct pl:Java star:5
# name:hana-bq-beam-connector pl:N/A star:10
# name:stress_transfer pl:Python star:4
# name:arithmancer pl:Python star:30
# name:contentbox pl:CSS star:25
# name:maps-for-work-samples pl:N/A star:148
# name:java-sourcetools pl:Java star:15
# name:gwteventbinder pl:Java star:29
# name:usbinfo pl:Python star:22
# name:flutter-provide pl:Dart star:58
# name:closure-builder pl:JavaScript star:16
# name:dv360-api pl:JavaScript star:10
# name:resumable-assert pl:C star:10
# name:auction-insights-visualization pl:JavaScript star:7
# name:asylo-site pl:HTML star:16
# ページ63: https://github.com/orgs/google/repositories?page=63
# ページ63のセクター数: 30
# name:asylo-examples pl:C++ star:14
# name:shenzhen-go pl:JavaScript star:43
# name:dv360-automation pl:Jupyter Notebook star:10
# name:swiftlogfirecloud pl:Swift star:8
# name:bband-adaband pl:MATLAB star:11
# name:skywater-pdk-actions pl:Python star:9
# name:openssl-tests pl:Makefile star:16
# name:hover pl:Java star:281
# name:opensmartbutton pl:C star:5
# name:talos-dv360 pl:JavaScript star:2
# name:hammer-kit pl:C star:9
# name:devsite-template pl:N/A star:2
# name:mosaic pl:Rust star:5
# name:tcpauth pl:C star:23
# name:recog pl:JavaScript star:4
# name:transperf pl:Python star:24
# name:rescue-tools-reiserfs pl:Python star:4
# name:localsubnetsetd pl:Python star:3
# name:experience-accessibility pl:Java star:8
# name:ihmehimmeli pl:C++ star:25
# name:kube-node-tracer pl:Shell star:3
# name:fidi pl:C++ star:6
# name:proto-quic pl:N/A star:277
# name:transmat pl:TypeScript star:27
# name:git-presubmit-linter pl:Shell star:13
# name:pyvisionproductsearch pl:Python star:9
# name:blueprint pl:Go star:80
# name:mysql-ripple pl:C++ star:50
# name:skywater-pdk-libs-sky130_fd_sc_hdll pl:Verilog star:6
# name:skywater-pdk-libs-sky130_fd_sc_hs pl:Verilog star:5
# ページ64: https://github.com/orgs/google/repositories?page=64
# ページ64のセクター数: 30
# name:skywater-pdk-libs-sky130_fd_sc_hvl pl:Verilog star:5
# name:skywater-pdk-libs-sky130_fd_sc_ls pl:Verilog star:5
# name:skywater-pdk-libs-sky130_fd_sc_ms pl:Verilog star:5
# name:skywater-pdk-libs-sky130_fd_sc_lp pl:Verilog star:6
# name:coapblaster pl:Java star:9
# name:formal-ml pl:Lean star:7
# name:cabal2bazel pl:Starlark star:6
# name:ffcc pl:MATLAB star:73
# name:retriever_parsing pl:Python star:5
# name:custom-tab-groups pl:JavaScript star:5
# name:prog-edu-assistant-quizzes pl:Jupyter Notebook star:5
# name:pygtrie pl:Python star:130
# name:pcbdl pl:Python star:27
# name:look-before-you-speak pl:HTML star:3
# name:applied-machine-learning-intensive pl:Jupyter Notebook star:71
# name:tirg pl:Python star:88
# name:autobidding-readiness-monitor pl:Python star:3
# name:merror pl:C++ star:5
# name:actions-on-google-flashcards-template-sdk pl:JavaScript star:5
# name:actions-on-google-trivia-template-sdk pl:JavaScript star:8
# name:splot-java pl:Java star:11
# name:hotel-booking-api-validator pl:Go star:7
# name:googlesource-auth-tools pl:Go star:6
# name:starlark-rust pl:N/A star:24
# name:protodatastore-cpp pl:C++ star:4
# name:dspl pl:Python star:202
# name:pinject pl:Python star:87
# name:wasserstein-dist pl:Python star:17
# name:dotty pl:Python star:13
# name:go-pcie-screamer pl:Go star:6
# ページ65: https://github.com/orgs/google/repositories?page=65
# ページ65のセクター数: 30
# name:sge-monorepo pl:Go star:11
# name:http_pattern_matcher pl:C++ star:9
# name:brailleback pl:Java star:23
# name:hubvantage pl:JavaScript star:3
# name:example_extrapolation pl:Python star:5
# name:security-research-pocs pl:C++ star:252
# name:ga360-bqml-toolkit pl:Jupyter Notebook star:5
# name:pytruth pl:Python star:19
# name:android-emulator-m1-preview pl:N/A star:162
# name:nitroml pl:Jupyter Notebook star:6
# name:perforce-utils pl:Shell star:4
# name:arrow-logo pl:Dart star:8
# name:stm32_bare_lib pl:C star:30
# name:usbmon pl:C star:14
# name:timecast pl:Python star:4
# name:tcav-for-ehr pl:Python star:4
# name:dicomproxy pl:Java star:4
# name:idaidle pl:CMake star:6
# name:forklift pl:JavaScript star:5
# name:ftc-object-detection pl:C++ star:28
# name:containerregistry pl:Python star:115
# name:open-location-code-swift pl:Swift star:16
# name:midi-dump-tools pl:C star:10
# name:sky-optimization pl:N/A star:15
# name:image-supplemental-feed-creator pl:Python star:4
# name:compare_gan pl:Python star:313
# name:zeroshell-linode pl:Shell star:15
# name:apis-client-generator pl:Python star:50
# name:gae-secure-scaffold-python pl:Python star:42
# name:dart-gl pl:C++ star:16
# ページ66: https://github.com/orgs/google/repositories?page=66
# ページ66のセクター数: 30
# name:network-mapper pl:N/A star:21
# name:mako pl:C++ star:14
# name:sling pl:C++ star:266
# name:tie pl:JavaScript star:48
# name:citest pl:Python star:40
# name:spindle-dv360 pl:Python star:6
# name:canvas-5-polyfill pl:JavaScript star:47
# name:trueview-sdf-generator pl:JavaScript star:5
# name:mannequinchallenge pl:Python star:102
# name:skicka pl:Go star:117
# name:cauliflowervest pl:Python star:47
# name:vsaq pl:JavaScript star:180
# name:StrawNet pl:HTML star:4
# name:retiming pl:Python star:22
# name:aistreams pl:C++ star:4
# name:safeside pl:C++ star:56
# name:blockly-ios pl:Swift star:107
# name:open-gantry pl:CSS star:8
# name:swift pl:N/A star:11000
# name:coursebuilder-core pl:Python star:113
# name:hypebot pl:Python star:9
# name:python-lakeside pl:Python star:18
# name:path-auditor pl:C++ star:40
# name:xscreensaver-dbus pl:Haskell star:5
# name:tim-gan pl:Python star:7
# name:swift-structural pl:Swift star:9
# name:spherical-harmonics pl:C++ star:87
# name:spatiotemporal-graphnn-tf pl:Jupyter Notebook star:4
# name:reftable pl:C star:10
# name:google-reauth-python pl:Python star:11
# ページ67: https://github.com/orgs/google/repositories?page=67
# ページ67のセクター数: 30
# name:vogon pl:JavaScript star:50
# name:automl-video-ondevice pl:Python star:19
# name:gulava pl:Java star:12
# name:analytics-audience-automation-tool pl:JavaScript star:4
# name:gxui pl:Go star:292
# name:python-laurel pl:Python star:18
# name:nvidia_libs_test pl:C++ star:21
# name:breadboard pl:C++ star:22
# name:xssxss pl:C star:7
# name:vc-defer pl:Emacs Lisp star:7
# name:device-access-codelab-web-app pl:JavaScript star:7
# name:firing-range pl:Java star:237
# name:CTAP2-test-tool-corpus pl:N/A star:3
# name:portrait-shadow-manipulation pl:Jupyter Notebook star:52
# name:google-api-java-client-samples pl:Java star:1000
# name:libprio-cc pl:C++ star:4
# name:favcolor-server pl:Ruby star:8
# name:wmt19-paraphrased-references pl:N/A star:6
# name:speed-opportunity-finder pl:Python star:5
# name:kilt pl:Go star:3
# name:context-expression-nature-study pl:MATLAB star:5
# name:modem pl:Jupyter Notebook star:18
# name:roman-word-bubbling pl:CSS star:7
# name:ct-hackday-schwag pl:Go star:6
# name:p4-pdpi pl:C++ star:10
# name:angular-a11y-workshop pl:TypeScript star:6
# name:angular_cli pl:Dart star:20
# name:binnavi pl:Java star:456
# name:vkb pl:CMake star:8
# name:cluster-scoped-cicd pl:Makefile star:6
# ページ68: https://github.com/orgs/google/repositories?page=68
# ページ68のセクター数: 30
# name:autol2 pl:Python star:3
# name:ssl_logger pl:Python star:210
# name:rekall-profiles pl:HTML star:48
# name:rekall pl:Python star:402
# name:seq2seq pl:Python star:1300
# name:inject.dart pl:Dart star:198
# name:tinkCryptoHelper pl:Java star:7
# name:in-silico-labeling pl:Python star:76
# name:berrydb pl:C++ star:20
# name:android-arscblamer pl:Java star:105
# name:render-timing-for-unity pl:C++ star:39
# name:tcp_killer pl:Python star:43
# name:supersonic pl:C++ star:43
# name:files.dart pl:Dart star:7
# name:region-flags pl:HTML star:107
# name:it-cert-automation pl:Python star:19
# name:fhir-ml pl:N/A star:0
# name:it-cert-automation-project pl:Python star:20
# name:jws pl:Python star:14
# name:ruby-openid-apps-discovery pl:Ruby star:23
# name:x pl:N/A star:0
# name:orchestra pl:Python star:24
# name:gke-auditor pl:Java star:13
# name:google-authenticator pl:Java star:984
# name:box2d.dart pl:Dart star:35
# name:dart-scissors pl:Dart star:26
# name:dart-glfw pl:C++ star:13
# name:gtm-http-fetcher pl:Objective-C star:26
# name:DirectXShaderCompiler pl:C++ star:808
# name:llvm-project pl:C++ star:15000
# ページ69: https://github.com/orgs/google/repositories?page=69
# ページ69のセクター数: 30
# name:google-apputils pl:Python star:31
# name:chrome-opt-out-extension pl:JavaScript star:11
# name:meet-on-fhir pl:JavaScript star:15
# name:bgu pl:C++ star:50
# name:actions-on-google-pq2-template-sdk pl:JavaScript star:6
# name:cpp-async-rpc pl:C++ star:21
# name:article-recommender pl:Python star:4
# name:opencasebook pl:Ruby star:26
# name:goterm pl:Go star:37
# name:spectral-density pl:Python star:32
# name:soong_verification pl:Lean star:6
# name:causal-panel-synthetic-data pl:R star:13
# name:wicked-good-xpath pl:JavaScript star:67
# name:gcp-fwrule-open-domain pl:Shell star:7
# name:b-con pl:Python star:6
# name:x-amber pl:C star:35
# name:debaised-analysis pl:HTML star:9
# name:fusion-power-video pl:C++ star:8
# name:cloud-network-reachability pl:N/A star:4
# name:zero-touch-reseller-tool pl:Java star:6
# name:controlled-noisy-web-labels pl:HTML star:4
# name:walk pl:C star:11
# name:dv360-bidbyweather pl:JavaScript star:5
# name:self-published-geo pl:Python star:12
# name:iosched-ios pl:Swift star:55
# name:pymql pl:Python star:9
# name:asset-check pl:JavaScript star:7
# name:agency-ads-management-solutions pl:JavaScript star:5
# name:compynator pl:Python star:12
# name:edf pl:Go star:9
# ページ70: https://github.com/orgs/google/repositories?page=70
# ページ70のセクター数: 30
# name:mlir-npcomp pl:N/A star:5
# name:knowledge-base-gmail-addon pl:JavaScript star:5
# name:closure-compiler-js pl:JavaScript star:62
# name:py-ast-utils pl:Python star:12
# name:sonic-p4rt pl:N/A star:4
# name:repose pl:Python star:4
# name:or-models pl:N/A star:4
# name:git-sync-changes pl:Shell star:8
# name:airdialogue_model pl:Python star:12
# name:iot-environment-sensors pl:C++ star:6
# name:gvisor-containerd-shim pl:Go star:28
# name:lipsync pl:JavaScript star:55
# name:prochlo pl:C++ star:11
# name:python-gflags pl:Python star:54
# name:rtc-video-quality pl:Python star:29
# name:loaner pl:Python star:63
# name:tpm-js pl:C++ star:36
# name:cloud-network-reachabilty pl:N/A star:4
# name:wikiloop-analysis pl:Python star:5
# name:draft-irtf-cfrg-vrf pl:Go star:7
# name:tock pl:Rust star:785
# name:ringdroid pl:Java star:264
# name:triemap pl:Go star:5
# name:framecount-colorbars-v1 pl:Java star:4
# name:casfs pl:Python star:5
# name:python-atfork pl:Python star:14
# name:python-subprocess32 pl:Python star:46
# name:where-is-my-watch pl:N/A star:0
# name:novm pl:Go star:121
# name:pam-cryptsetup pl:C star:13
# ページ71: https://github.com/orgs/google/repositories?page=71
# ページ71のセクター数: 30
# name:parallel-chunks pl:Python star:4
# name:google-authenticator-android pl:Java star:482
# name:responsive-search-ads-builder pl:JavaScript star:5
# name:categorybuilder pl:Python star:23
# name:capsicum-linux pl:C star:38
# name:cmockery pl:Shell star:369
# name:CurbsidePickup pl:JavaScript star:5
# name:androiddevicesjs pl:TypeScript star:4
# name:google-input-tools pl:JavaScript star:123
# name:weighted-dict pl:Python star:10
# name:samba-documents-provider pl:Java star:126
# name:cartoonset pl:HTML star:12
# name:gvisor-website pl:HTML star:19
# name:prettytensor pl:Python star:143
# name:vmregistry pl:Go star:16
# name:HardwarePrototypingToolkit pl:N/A star:5
# name:gapid-dev-releases pl:N/A star:5
# name:applied-computing-series pl:Python star:12
# name:cloudprint_logocert pl:Python star:32
# name:tflow2 pl:Go star:20
# name:dart_google_apps pl:Dart star:8
# name:blockly-tools pl:Shell star:16
# name:covid19-face-shield pl:N/A star:6
# name:lvmd pl:Go star:20
# name:chrome-media-audio-papers pl:HTML star:5
# name:git-rebaser pl:Python star:5
# name:adcase pl:Python star:5
# name:powered-caster-vehicle pl:C++ star:9
# name:play-instant-unity-plugin pl:C# star:33
# name:git-appraise-eclipse pl:Java star:9
# ページ72: https://github.com/orgs/google/repositories?page=72
# ページ72のセクター数: 30
# name:python-fanotify pl:C star:19
# name:slothfs pl:Go star:11
# name:emoticon-composer-font pl:HTML star:6
# name:cloud-analytics-ts pl:TypeScript star:4
# name:angular_node_bind.dart pl:Dart star:13
# name:allied-oscillators pl:JavaScript star:3
# name:create-framework pl:Dart star:7
# name:wayback-machine-button pl:JavaScript star:9
# name:certificate-maker pl:JavaScript star:34
# name:night-sight pl:N/A star:13
# name:galogen pl:C++ star:15
# name:chatbase-node pl:JavaScript star:24
# name:guava-js-umd pl:JavaScript star:4
# name:NeuroNER-CSPMC pl:Python star:9
# name:cxx-std-draft pl:TeX star:804
# name:revisiting-self-supervised pl:Python star:40
# name:jacs pl:Python star:11
# name:cameraview pl:Java star:1000
# name:gulp-google-closure-deps pl:JavaScript star:7
# name:gerrit-linter pl:Go star:5
# name:sprockets pl:Python star:12
# name:restor pl:Objective-C star:27
# name:blockly-experimental pl:JavaScript star:11
# name:OctoPrint-LEDStripControl pl:Python star:40
# name:OctoPrint-TemperatureFailsafe pl:Python star:27
# name:OctoPrint-HeaterTimeout pl:Python star:9
# name:palette.js pl:JavaScript star:93
# name:certificate-transparency-java pl:Java star:31
# name:AppSpeedIndex pl:Python star:6
# name:gpu-runtime pl:C++ star:7
# ページ73: https://github.com/orgs/google/repositories?page=73
# ページ73のセクター数: 30
# name:gcnn-survey-paper pl:Python star:33
# name:apps_script_tools pl:Dart star:7
# name:macops-keychainminder pl:Objective-C star:17
# name:embedding-tests pl:Python star:11
# name:tracing-framework pl:JavaScript star:197
# name:netstack pl:Go star:281
# name:multi-task-architecture-search pl:Python star:5
# name:pyringe pl:Python star:77
# name:eddystone pl:C star:749
# name:statechart pl:C++ star:35
# name:deputy-api-python-client pl:Python star:10
# name:checkers pl:Python star:9
# name:shlex pl:Go star:45
# name:nixysa pl:Python star:12
# name:szl pl:C++ star:15
# name:abpackage pl:R star:13
# name:gps_data_solutions pl:Go star:5
# name:sredocs pl:Go star:8
# name:tiff pl:Go star:16
# name:google-api-ruby-client-samples pl:N/A star:153
# name:gpu-mux pl:Python star:8
# name:jarvan pl:Python star:4
# name:enjarify pl:Python star:541
# name:orderedcode pl:Go star:12
# name:wikiloop-wikidata-game pl:JavaScript star:4
# name:automation-inspector pl:JavaScript star:13
# name:floog pl:TSQL star:5
# name:icing-search pl:N/A star:5
# name:distributed-git-forks pl:Shell star:10
# name:phase-prediction pl:HTML star:5
# ページ74: https://github.com/orgs/google/repositories?page=74
# ページ74のセクター数: 30
# name:campaign-manager-bulk-uploader pl:Python star:10
# name:swift-lldb pl:C++ star:193
# name:swift-clang pl:C++ star:157
# name:swift-llvm pl:LLVM star:177
# name:swift-corelibs-libdispatch pl:C star:480
# name:swift-corelibs-foundation pl:C star:1200
# name:mr4c pl:Java star:218
# name:graph-gen pl:Python star:9
# name:sa360-bidbyweather pl:JavaScript star:5
# name:swift-corelibs-xctest pl:Swift star:269
# name:gfbuild-SPIRV-Cross pl:N/A star:0
# name:MOE-py pl:Java star:15
# name:cloud-function-edit-drive-permissions pl:Python star:9
# name:GeoexperimentsResearch pl:R star:56
# name:image-compression pl:C++ star:34
# name:gdata-python-client pl:HTML star:229
# name:pixelvisualcorecamera pl:Java star:34
# name:vim-searchindex pl:Vim Script star:24
# name:retrieval-qa-eval pl:Python star:11
# name:cap-library pl:HTML star:26
# name:pulito pl:JavaScript star:10
# name:neural_rerendering_in_the_wild pl:Python star:33
# name:rxcppuniq pl:C++ star:6
# name:charted pl:Dart star:59
# name:boundedwait pl:Go star:5
# name:fleetspeak-doc pl:N/A star:3
# name:earthstudio-ffmpeg-automator pl:Shell star:7
# name:page-timer pl:JavaScript star:46
# name:dpy pl:Python star:13
# name:crunchy pl:C++ star:15
# ページ75: https://github.com/orgs/google/repositories?page=75
# ページ75のセクター数: 30
# name:dimsum pl:C++ star:24
# name:copper pl:Python star:8
# name:cpix_cc pl:C++ star:6
# name:intellij-protocol-buffer-editor pl:Java star:9
# name:vim-codereview pl:Vim Script star:8
# name:vim-syncopate pl:Vim Script star:7
# name:grpc-kapt pl:Kotlin star:5
# name:swift-package-manager pl:Swift star:1400
# name:webview-local-server pl:Java star:43
# name:kleaver pl:C star:9
# name:gocw pl:Go star:7
# name:pyctr pl:Python star:7
# name:blockly-android pl:Java star:212
# name:android-kerberos-authenticator pl:Java star:9
# name:uiimage-additions pl:Objective-C star:9
# name:emitto pl:Go star:6
# name:stereo-magnification pl:Python star:88
# name:ldpush pl:Python star:24
# name:googlemock pl:N/A star:203
# name:battery-historian pl:Go star:972
# name:graph_distillation pl:Python star:19
# name:byterun pl:Python star:270
# name:wear-sensors pl:Java star:19
# name:wear-screeninfo pl:Java star:8
# name:wear-displaylock pl:Java star:11
# name:cm-user-tool pl:JavaScript star:7
# name:science-journal-arduino pl:C star:65
# name:nel-collector pl:Go star:10
# name:google-api-cpp-client pl:C++ star:103
# name:libcxx pl:C++ star:71
# ページ76: https://github.com/orgs/google/repositories?page=76
# ページ76のセクター数: 30
# name:vectorio pl:Go star:14
# name:openjdk-kerberos pl:Java star:8
# name:astc-codec pl:C++ star:30
# name:atlassian-addons-audit-sheet pl:Python star:10
# name:protorpc pl:Python star:36
# name:kiwi-solver pl:Java star:8
# name:cssi-blogasaurus pl:HTML star:13
# name:gpu-emulation-stress-test pl:C++ star:28
# name:rust-shell pl:Rust star:18
# name:git-phabricator-mirror pl:Go star:9
# name:prometheus-slo-burn-example pl:Go star:26
# name:bookbot-navigation pl:C++ star:11
# name:android-wear-stitch-script pl:Python star:18
# name:squires pl:Python star:6
# name:web-activities pl:JavaScript star:9
# name:keyczar pl:N/A star:140
# name:neural-logic-machines pl:Python star:49
# name:sha1dc-jni pl:Java star:6
# name:flatui pl:C++ star:82
# name:motive pl:C++ star:41
# name:expt-analysis pl:Python star:4
# name:chromeosnavigationdemo pl:Kotlin star:5
# name:github-issue-mover pl:Dart star:57
# name:gjstest pl:C++ star:48
# name:godepq pl:Go star:32
# name:harpia pl:Shell star:11
# name:pjflate pl:Java star:6
# name:us-altgr-intl pl:Perl star:7
# name:error-prone-javac pl:Java star:20
# name:gwt-charts pl:Java star:25
# ページ77: https://github.com/orgs/google/repositories?page=77
# ページ77のセクター数: 30
# name:git-patrol pl:Python star:6
# name:horenso pl:Perl star:13
# name:n-digit-mnist pl:Python star:18
# name:pagespeed-inslides pl:JavaScript star:18
# name:go-structeditor pl:Go star:11
# name:navc pl:Go star:18
# name:ios-chatbot pl:Objective-C star:31
# name:codemirror-mode-jsonnet pl:JavaScript star:11
# name:ps_log pl:PowerShell star:8
# name:support-tools pl:Python star:23
# name:wikiloop-datasets pl:N/A star:3
# name:heroku-buildpack-bazel pl:Shell star:9
# name:skylark pl:Go star:73
# name:image-rebase pl:Go star:9
# name:zsldemo pl:Kotlin star:6
# name:easy-grid pl:JavaScript star:45
# name:keps pl:Go star:9
# name:hyou pl:Python star:24
# name:shipshape pl:Go star:34
# name:glslang pl:N/A star:924
# name:quark pl:C star:8
# name:vr180 pl:Java star:15
# name:orismologer pl:Go star:5
# name:chord pl:JavaScript star:4
# name:qpp pl:JavaScript star:9
# name:go-microservice-helpers pl:Go star:29
# name:node-sec-roadmap pl:JavaScript star:29
# name:gdata-java-client pl:Java star:111
# name:gtm_load_timer pl:Objective-C star:7
# name:hangouts-chat-bot-cloud-function-nodejs-example pl:JavaScript star:9
# ページ78: https://github.com/orgs/google/repositories?page=78
# ページ78のセクター数: 30
# name:googletv-android-samples pl:Java star:71
# name:dbm-lineitem-copier pl:JavaScript star:10
# name:dcm-bulk-trafficking pl:JavaScript star:10
# name:google-api-objectivec-client pl:N/A star:124
# name:radioreceiver pl:JavaScript star:82
# name:meta_tagger pl:Python star:17
# name:btls pl:Haskell star:11
# name:opuscpp pl:C++ star:12
# name:credstore pl:Go star:14
# name:khll-paper-experiments pl:N/A star:5
# name:link022 pl:Go star:28
# name:capillary pl:Java star:40
# name:active-qa pl:Python star:64
# name:python-dimond pl:Python star:17
# name:detectorgraph pl:C++ star:9
# name:node-dependency-analysis pl:TypeScript star:9
# name:syzygy pl:C++ star:60
# name:physical-web pl:Java star:655
# name:ioweb2016 pl:HTML star:88
# name:blue-green-deployment-controller pl:Go star:14
# name:cornerstone pl:JavaScript star:594
# name:appengine-jenkins pl:Shell star:25
# name:Safelight pl:JavaScript star:6
# name:blkcgroup pl:Python star:10
# name:cpython-pt pl:Python star:8
# name:protobuf-dt pl:Java star:22
# name:cpp-netlib pl:C++ star:584
# name:mysql pl:C++ star:82
# name:sawbuck pl:C++ star:39
# name:uribeacon pl:N/A star:108
# ページ79: https://github.com/orgs/google/repositories?page=79
# ページ79のセクター数: 30
# name:ohmu pl:C++ star:19
# name:recki-ct pl:PHP star:37
# name:url_diff pl:Python star:29
# name:filesystem-proposal pl:C++ star:17
# name:developer.github.com pl:Ruby star:1100
# name:helloargdx pl:Java star:18
# name:emoji4unicode pl:Python star:20
# name:closure-linter pl:Python star:28
# name:ced pl:C++ star:12
# name:mozart pl:Python star:8
# name:python-yaml-config pl:Python star:7
# name:cloud-berg pl:Python star:8
# name:fast-optimized-community-significance pl:R star:5
# name:binplist pl:Python star:24
# name:svalbard pl:Go star:12
# name:go-write pl:Go star:4
# name:cornerstoneWADOImageLoader pl:JavaScript star:264
# name:cornerstoneTools pl:JavaScript star:451
# name:sa360-bulk-editor pl:JavaScript star:5
# name:election-au-2016 pl:Go star:33
# name:fancy-regex pl:Rust star:16
# name:realestate10k pl:HTML star:6
# name:asymproj_edge_dnn pl:Python star:16
# name:google-gdata pl:C# star:10
# name:bottlerocket pl:Scala star:25
# name:pandas pl:Python star:19000
# name:cog pl:Python star:11
# name:bottery pl:JavaScript star:149
# name:sa360-flightsfeed pl:JavaScript star:7
# name:audio-sync-kit pl:Python star:21
# ページ80: https://github.com/orgs/google/repositories?page=80
# ページ80のセクター数: 30
# name:BucketServer pl:Go star:6
# name:ORFConverter pl:C# star:10
# name:chatbase-dotnet pl:C# star:11
# name:dtask pl:C star:14
# name:virtual-tutors pl:HTML star:11
# name:ioweb2015 pl:JavaScript star:110
# name:minions pl:Go star:12
# name:gdata-objectivec-client pl:Objective-C star:90
# name:macops-MOLFCMClient pl:Objective-C star:6
# name:detangle pl:JavaScript star:15
# name:pg_page_verification pl:C star:13
# name:layered-scene-inference pl:Python star:20
# name:chaps-linux pl:Makefile star:14
# name:amp-toolbox pl:JavaScript star:248
# name:quickshift pl:C++ star:22
# name:web-audio-recognition pl:Jupyter Notebook star:31
# name:coursebuilder-resources pl:Shell star:10
# name:0x0g-2018-badge pl:C star:5
# name:dbm-trix-addon pl:JavaScript star:9
# name:fplutil pl:Python star:42
# name:coursebuilder-releases pl:N/A star:10
# name:google-visualization-java pl:Java star:34
# name:asr-recipes pl:Shell star:10
# name:identity-aware-prober pl:Go star:8
# name:xrtl pl:C++ star:26
# name:token_bind pl:C star:17
# name:differentiable-atomistic-potentials pl:Python star:11
# name:swift-integration-tests pl:Python star:87
# name:swift-compiler-rt pl:C star:52
# name:swift-llbuild pl:C++ star:221
# ページ81: https://github.com/orgs/google/repositories?page=81
# ページ81のセクター数: 30
# name:swift-cmark pl:C star:616
# name:maddpg-replication pl:Jupyter Notebook star:13
# name:node-armor pl:N/A star:0
# name:virtualdesktops-extension pl:JavaScript star:13
# name:nips_assignments pl:C++ star:13
# name:sparrowhawk pl:Shell star:59
# name:zooshi pl:C++ star:57
# name:http_prefetching pl:JavaScript star:6
# name:kv-s3105c pl:C star:5
# name:fastboot-mobile pl:Kotlin star:13
# name:amss pl:R star:28
# name:search-samples pl:Java star:238
# name:abstreet pl:Rust star:6
# name:dl_bounds pl:Python star:8
# name:chrome-tabber pl:JavaScript star:7
# name:beacon-platform pl:N/A star:258
# name:dcm_bulk_onboarding pl:JavaScript star:3
# name:fast-simple-lcsk pl:C++ star:9
# name:dcm-video-uploader pl:Python star:12
# name:TouchTime pl:Java star:19
# name:uniflow-polymer pl:HTML star:15
# name:rally pl:Java star:10
# name:teknowledge pl:Python star:15
# name:clerk pl:C++ star:16
# name:ahdlc pl:C star:4
# name:aperture_supervision pl:Python star:15
# name:YetAnotherChatApp pl:Java star:8
# name:grittibanzli pl:C++ star:6
# name:ds-trix-addon pl:JavaScript star:13
# name:hat-backup pl:Rust star:30
# ページ82: https://github.com/orgs/google/repositories?page=82
# ページ82のセクター数: 30
# name:angular-sticky-element pl:TypeScript star:9
# name:vae-seq pl:Python star:32
# name:cloud-cup pl:JavaScript star:8
# name:cloud-cup-android pl:Java star:34
# name:fest pl:N/A star:10
# name:decoupled_gaussian_process pl:Python star:8
# name:safevarargs pl:N/A star:13
# name:opentest pl:N/A star:0
# name:encrypted-bigquery-client pl:Python star:34
# name:rbe-integration-test pl:Python star:5
# name:chained-promise pl:TypeScript star:18
# name:synergyfinderengineered pl:R star:5
# name:amp-client-id-library pl:JavaScript star:13
# name:go-trace pl:Go star:10
# name:hell0world-curriculum pl:HTML star:8
# name:intelligent_annotation_dialogs pl:Jupyter Notebook star:7
# name:cornerstoneMath pl:JavaScript star:46
# name:burst-denoising pl:Python star:58
# name:generativemloncloud pl:Python star:14
# name:aiyprojects-deeplearn-tensorflow pl:TypeScript star:10
# name:tensorflow-tools pl:JavaScript star:11
# name:hugeml pl:N/A star:0
# name:coq-bpf pl:Coq star:8
# name:pinotify pl:Java star:3
# name:CallBuilder pl:Java star:24
# name:catnip pl:Python star:10
# name:yaricv32 pl:Verilog star:10
# name:unigem-objective-c pl:Objective-C star:7
# name:speech_style_transfer pl:HTML star:4
# name:perf_api.dart pl:Dart star:19
# ページ83: https://github.com/orgs/google/repositories?page=83
# ページ83のセクター数: 30
# name:golden pl:Go star:3
# name:latency-benchmark pl:C star:38
# name:joint_vae pl:OpenEdge ABL star:12
# name:stumblybot pl:Python star:12
# name:mt pl:C++ star:13
# name:cornerstoneWebImageLoader pl:JavaScript star:51
# name:streamy-dart pl:Dart star:22
# name:dicomParser pl:JavaScript star:232
# name:vulkan-cpp-library pl:C++ star:23
# name:bbcpu pl:Verilog star:11
# name:dev-on-chromeos-gce-setup pl:Shell star:5
# name:pbvi pl:Python star:8
# name:capture-thread pl:C++ star:29
# name:pblog pl:C star:9
# name:text2text pl:Python star:22
# name:ce-open-data-set pl:N/A star:18
# name:voice-iot-maker-demo pl:JavaScript star:21
# name:terminal-app-function-keys pl:Python star:23
# name:FakeMaker pl:JavaScript star:17
# name:genomics-protos pl:Python star:8
# name:clicktrackers-panel pl:Python star:8
# name:yara-procdump-python pl:C star:5
# name:streaming_hdp pl:Go star:8
# name:coursebuilder-android-container-module pl:Python star:12
# name:sync3k-server pl:Scala star:4
# name:tern-closure pl:JavaScript star:18
# name:helm-broker pl:Go star:12
# name:ndash pl:C++ star:17
# name:VRD pl:Python star:7
# name:sync3k-client pl:TypeScript star:5
# ページ84: https://github.com/orgs/google/repositories?page=84
# ページ84のセクター数: 30
# name:acme pl:Go star:51
# name:dart-sync-webdriver pl:Dart star:26
# name:dart-sync-socket pl:Dart star:18
# name:Legilimency pl:Python star:13
# name:mipsqa pl:Python star:10
# name:devicehub pl:Java star:11
# name:gtd-txt pl:Shell star:8
# name:bitutils pl:Python star:7
# name:sonic-midi pl:Ruby star:5
# name:gumbel_sinkhorn pl:Python star:18
# name:arc-xcode-test-engine pl:PHP star:16
# name:energystrategies pl:TypeScript star:7
# name:marmot pl:Go star:13
# name:clojure-turtle pl:Clojure star:33
# name:dev-on-chromeos-che pl:N/A star:7
# name:dev-on-chromeos-openvpn pl:Shell star:6
# name:keytransparency-java pl:Java star:9
# name:bocado pl:Python star:11
# name:anvil-build pl:Python star:15
# name:river pl:N/A star:0
# name:trix-auto-complete pl:JavaScript star:10
# name:MAB pl:R star:12
# name:idris-protobuf pl:Idris star:11
# name:energysimulation pl:Jupyter Notebook star:17
# name:pyrios pl:Go star:26
# name:thread-weaver pl:Java star:60
# name:cwd_jmp pl:Shell star:8
# name:kratu pl:JavaScript star:33
# name:codeu_coding_assessment_b_2017 pl:Java star:60
# name:coverage pl:Emacs Lisp star:12
# ページ85: https://github.com/orgs/google/repositories?page=85
# ページ85のセクター数: 30
# name:ts-gulp pl:N/A star:0
# name:git-annex-external-gcs pl:N/A star:0
# name:makerspace-emonth pl:KiCad Layout star:10
# name:paper-gui pl:HTML star:17
# name:testrunner-rosemary pl:Java star:9
# name:spline pl:Java star:14
# name:creatism pl:HTML star:9
# name:mockable_filesystem.dart pl:Dart star:8
# name:okay pl:Go star:10
# name:metaserver pl:Go star:5
# name:microdhcpd pl:Go star:8
# name:pubkeystore pl:Go star:6
# name:unimorph pl:HTML star:4
# name:GL-Shader-Validator pl:Python star:18
# name:light-my-piano pl:Python star:22
# name:grr_go_client pl:Go star:9
# name:fury pl:Go star:9
# name:grr_go_api_client pl:Go star:7
# name:rttcp pl:Python star:16
# name:functions-demo pl:JavaScript star:6
# name:packet-queue pl:Python star:10
# name:easybundler pl:Java star:19
# name:chkstream pl:Python star:10
# name:glmmplus pl:R star:7
# name:codeu_coding_assessment_2017 pl:Java star:100
# name:address-geocoder-js pl:HTML star:9
# name:classp pl:Bison star:14
# name:xmpmeta pl:C++ star:11
# name:depth_fusion pl:C++ star:6
# name:amp-pwa-demo pl:JavaScript star:33
# ページ86: https://github.com/orgs/google/repositories?page=86
# ページ86のセクター数: 30
# name:Zhi pl:Python star:14
# name:agata pl:JavaScript star:7
# name:prerender-test pl:JavaScript star:11
# name:audit-normalmap pl:C star:10
# name:varstruct pl:C++ star:15
# name:emre pl:C++ star:5
# name:simple-reinforcement-learning pl:Python star:30
# name:homebrew-google-authenticator pl:Ruby star:15
# name:request-test pl:Python star:5
# name:blockly-repo pl:N/A star:5
# name:pindrop pl:C++ star:27
# name:goldfinch pl:N/A star:17
# name:scene_lab pl:C++ star:21
# name:corgi pl:C++ star:32
# name:dropzone-polyfill pl:HTML star:5
# name:ot-crdt-papers pl:JavaScript star:26
# name:windowtester pl:Java star:19
# name:fpc pl:C star:5
# name:fchan-go pl:Go star:23
# name:xdelta3-decoder-js pl:C star:10
# name:appengine-phabricator pl:Shell star:15
# name:cpp-frp pl:C++ star:19
# name:yang_vocoder pl:MATLAB star:26
# name:keystone pl:Elm star:7
# name:adapt-googleanalytics pl:JavaScript star:6
# name:deepboost pl:C++ star:53
# name:mcic-coco pl:N/A star:13
# name:readahead pl:Go star:13
# name:source_transformer.dart pl:Dart star:4
# name:mcafp pl:Python star:17
# ページ87: https://github.com/orgs/google/repositories?page=87
# ページ87のセクター数: 30
# name:gtm-oauth pl:Objective-C star:23
# name:morphie pl:C++ star:15
# name:libgep pl:C++ star:19
# name:smilesparser pl:Python star:11
# name:built_json.dart pl:N/A star:10
# name:conferenceDB pl:HTML star:6
# name:indexable-pwa-samples pl:JavaScript star:14
# name:enum_class.dart pl:N/A star:7
# name:sass_generator pl:N/A star:0
# name:vpn-reverse-tether pl:C star:61
# name:protocall pl:Python star:6
# name:transliteration pl:N/A star:31
# name:power-traces pl:Protocol Buffer star:12
# name:indexed-db-as-promised pl:JavaScript star:4
# name:gotrace pl:N/A star:0
# name:cameraraw pl:Go star:13
# name:everythingisconnected pl:JavaScript star:5
# name:libkml pl:C++ star:55
# name:geovelo pl:JavaScript star:24
# name:gfw-toolkit pl:Python star:21
# name:googleapps-message-recall pl:Python star:19
# name:macops-MOMenu pl:Objective-C star:9
# name:dart2java pl:Java star:14
# name:param_runner pl:Shell star:8
# name:gde-speakersbureau pl:JavaScript star:12
# name:AppUpdateTrackerLib pl:Java star:12
# name:rustcxx pl:Rust star:22
# name:dualhttp pl:JavaScript star:11
# name:go-webdav pl:Go star:19
# name:dorusu-js pl:JavaScript star:15
# ページ88: https://github.com/orgs/google/repositories?page=88
# ページ88のセクター数: 30
# name:identity-toolkit-go-client pl:Go star:24
# name:dynamex-proto pl:Protocol Buffer star:11
# name:auto-common pl:N/A star:0
# name:auto-service pl:N/A star:0
# name:auto-factory pl:N/A star:0
# name:prudaq pl:Eagle star:32
# name:realtime-help pl:Python star:17
# name:pepper.js pl:JavaScript star:53
# name:instant-hangouts pl:JavaScript star:49
# name:LiquidFunPaint pl:Java star:54
# name:easy-gwt-mock pl:Java star:6
# name:gofountain pl:Go star:16
# name:VoltAir pl:C++ star:83
# name:bzip2-rpc pl:C star:9
# name:gipfeli pl:C++ star:26
# name:go-circuits pl:Go star:10
# name:rpki-mgmt pl:Puppet star:12
# name:simplecfg pl:Java star:8
# name:maketrace pl:C++ star:15
# name:Chrome.Docs pl:JavaScript star:9
# name:bluesky-watchface pl:C star:4
# name:slowfs pl:Go star:10
# name:arc-jazzy-linter pl:PHP star:4
# name:merge_pyi pl:Python star:12
# name:drone-firebase pl:Go star:12
# name:cncmicroscope-cad pl:OpenSCAD star:8
# name:access-bridge-explorer pl:C# star:57
# name:gitwf pl:N/A star:0
# name:arc-proselint pl:PHP star:11
# name:channel-id-enclave pl:N/A star:10
# ページ89: https://github.com/orgs/google/repositories?page=89
# ページ89のセクター数: 30
# name:generator-goro pl:JavaScript star:14
# name:xpaf pl:C++ star:54
# name:google-empty-test-module pl:N/A star:0
# name:cloud-reporting pl:Java star:6
# name:reagera pl:Java star:8
# name:py-decorators-tutorial pl:Jupyter Notebook star:11
# name:identity-toolkit-node-client pl:JavaScript star:16
# name:GOS-conventions pl:Shell star:10
# name:identity-toolkit-java-client pl:Java star:27
# name:jalic pl:C star:10
# name:arc-regex-line-length-linter pl:PHP star:8
# name:identity-toolkit-ruby-client pl:Ruby star:9
# name:file-system-stress-testing pl:C star:21
# name:linux-sensor pl:C star:10
# name:multibox pl:N/A star:95
# name:offline-content-packager pl:N/A star:20
# name:crush-tools pl:Shell star:21
# name:flutter-data pl:Dart star:9
# name:resolver-library pl:Python star:10
# name:hops pl:C++ star:12
# name:kythe-cloud9 pl:JavaScript star:3
# name:physical-web-core pl:N/A star:0
# name:flooefi pl:N/A star:0
# name:serialization.dart pl:Dart star:14
# name:templatekit pl:Objective-C star:9
# name:metrosvg pl:C++ star:12
# name:paramgmt pl:Python star:29
# name:pienoon pl:C++ star:112
# name:translation-cards pl:Java star:11
# name:topdown-btg-preordering pl:C++ star:10
# ページ90: https://github.com/orgs/google/repositories?page=90
# ページ90のセクター数: 30
# name:openpgp-interop pl:N/A star:6
# name:appengine-codiad pl:JavaScript star:30
# name:godata pl:Go star:14
# name:opentest4j pl:Java star:39
# name:identity-toolkit-php-client pl:PHP star:22
# name:google-maven-parents pl:N/A star:4
# name:identity-toolkit-python-client pl:Python star:21
# name:Refaster pl:Java star:18
# name:strabo pl:Elixir star:13
# name:http2preload pl:Go star:9
# name:checkers_classic pl:Python star:12
# name:node-nest pl:JavaScript star:12
# name:intellij-cmdline-vcs-plugin pl:Java star:4
# name:docopt-scripts pl:Go star:10
# name:xpra-upstart pl:N/A star:10
# name:steamkeysactivator pl:AppleScript star:18
# name:homebrew-xpra pl:Ruby star:10
# name:shipshape-demo pl:Python star:9
# name:hashing-demo pl:C++ star:12
# name:autopiper pl:C++ star:11
# name:inception pl:N/A star:170
# name:clang-lens pl:Haskell star:9
# name:crisis-info-hub pl:JavaScript star:16
# name:dart-immutables pl:Dart star:8
# name:streamhtmlparser pl:C star:10
# name:pods-helper pl:Objective-C star:10
# name:cluster-insight pl:Python star:24
# name:freebase-wikidata-converter pl:PHP star:27
# name:snappy-start pl:C star:23
# name:capsicum-man-pages pl:Groff star:3
# ページ91: https://github.com/orgs/google/repositories?page=91
# ページ91のセクター数: 30
# name:rust-multihash pl:Rust star:10
# name:organ-donor-app pl:N/A star:0
# name:trace-viewer pl:N/A star:77
# name:rowhammer-test pl:C++ star:200
# name:ferret pl:Java star:15
# name:module-server pl:JavaScript star:44
# name:autoparse pl:Ruby star:33
# name:android-studio-check pl:Java star:11
# name:chromeos-filesystems pl:JavaScript star:25
# name:gojiraw pl:Go star:9
# name:terminal-py pl:Python star:5
# name:lmctfy pl:C++ star:240
# name:dart-shapeshift pl:Dart star:8
# name:calenviroscreen pl:R star:5
# name:cncmicroscope-code pl:C++ star:10
# name:o3dtoydefense pl:JavaScript star:9
# name:epr pl:JavaScript star:12
# name:codename-mvsv pl:JavaScript star:10
# name:io-captions-gadget pl:Python star:9
# name:ytstatistics-demo pl:Java star:11
# name:sensei pl:C++ star:16
# name:comid pl:Dart star:18
# name:service_worker.dart pl:Dart star:10
# name:google-visualization-issues pl:N/A star:35
# name:dart-doc_coverage pl:Dart star:12
# name:voter-info-tool pl:JavaScript star:10
# name:chrome-language-immersion pl:JavaScript star:19
# name:coursebuilder_xblock_module pl:Python star:12
# name:py-html-contextual-escaping pl:Python star:9
# name:json-sans-eval pl:HTML star:11
# ページ92: https://github.com/orgs/google/repositories?page=92
# ページ92のセクター数: 30
# name:mysql-tools pl:Python star:78
# name:refr pl:C++ star:9
# name:coursebuilder-hello-world-module pl:Python star:5
# name:dart-emacs-plugin-unsupported pl:Emacs Lisp star:11
# name:older-mirrored-patches pl:N/A star:10
# name:objectfilter pl:Python star:10
# name:retrofit pl:Java star:7300
# name:nfc-smart-tag pl:Java star:6
# name:irrduino pl:Processing star:13
# name:reportlatency pl:Perl star:8
# name:gmailsnooze pl:JavaScript star:7
# name:deliberate pl:N/A star:0
# name:network-visualizer-x pl:N/A star:0
# name:reboot-somalia pl:N/A star:0
# name:citizen-x pl:N/A star:0
# name:pytypedecl pl:Python star:17
# name:rysim pl:Erlang star:14
# name:jsontoken-tmp pl:N/A star:0
# name:go-shlex pl:N/A star:0
# name:zarathustra pl:Java star:13
# name:pull-request-mailer pl:Haskell star:9
# name:elfling pl:C++ star:12
# name:vim-ft-vroom pl:Vim Script star:8
# name:picview-for-android pl:Java star:33
# name:picasa-app-demo pl:Java star:14
# name:web-starter-kit-extras pl:N/A star:29
# name:simple-pedometer pl:Java star:48
# name:sensor-data-collection-library pl:Java star:21
# name:ashier pl:Python star:15
# name:coursebuilder-lti-module pl:Python star:5
# ページ93: https://github.com/orgs/google/repositories?page=93
# ページ93のセクター数: 30
# name:episodes.dart pl:Dart star:26
# name:polymer-dart-log-controller pl:Dart star:16
# name:ebola-tools pl:Python star:9
# name:pubsubhubbub pl:N/A star:0
# name:dart-tagtree pl:Dart star:14
# name:turing-doodle pl:JavaScript star:68
# name:linear-book-scanner pl:Python star:25
# name:java-thread-sanitizer pl:Java star:25
# name:gin pl:N/A star:0
# name:go-glicko2 pl:N/A star:0
# name:rct-automation pl:C++ star:15
# name:Idris-dev pl:Haskell star:633
# name:forcefield pl:Gosu star:18
# name:dart-gif-encoder pl:Dart star:13
# name:glassbox pl:R star:10
# name:coursebuilder-learning-analytics pl:N/A star:0
# name:NLSdata pl:R star:8
# name:jenkins-flaky-test-report pl:N/A star:0
# name:build-debian-cloud pl:Python star:117
# name:dart-collab pl:Dart star:9
# name:wheelbarrow pl:Python star:14
# name:photo-sphere pl:N/A star:0
# name:oss-bench pl:N/A star:5
# name:heartbleed-burp-extension pl:Java star:13
# name:lab_device_proxy pl:Python star:8
# name:gdal-autotest2 pl:N/A star:0
# name:patchfield pl:Java star:43
# name:googleapps-password-generator pl:N/A star:30
# name:YouCompleteSubl pl:N/A star:0
# name:favcolor-findidp pl:N/A star:10
# ページ94: https://github.com/orgs/google/repositories?page=94
# ページ94のセクター数: 21
# name:appengine_xblock_runtime pl:Python star:16
# name:memcache-collections pl:Python star:21
# name:course-builder pl:N/A star:0
# name:favcolor-android pl:Java star:22
# name:systemjs pl:JavaScript star:20
# name:favcolor-ios pl:N/A star:0
# name:pixelcycle-sample-app pl:Dart star:14
# name:container-rfc pl:N/A star:23
# name:gae-channel-api.dart pl:Dart star:17
# name:ChannelPlate pl:JavaScript star:18
# name:testRunner pl:JavaScript star:9
# name:devtoolsExtended pl:JavaScript star:22
# name:self-hosted-rss-to-email pl:Go star:9
# name:zimu pl:C star:5
# name:tsviewdb pl:JavaScript star:21
# name:beta-binomial-fitting pl:N/A star:0
# name:wiberg-minimization pl:N/A star:10
# name:crx2app pl:JavaScript star:15
# name:concatenate.js pl:JavaScript star:18
# name:firmata.py pl:Python star:16
# name:sirius pl:N/A star:0

# %%
path = ''
db_name = 'github_google.db'

try:
    #DBへのコネクションを確立
    conn = sqlite3.connect(path + db_name)

    #SQL(ROBを操作するための言語)を実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # SQL文の作成
    # 複数レコードの挿入
    sql = "INSERT INTO repositories (name, pl, star) VALUES (?, ?, ?);"

    # SQL文の実行
    cur.executemany(sql, repositories)

    conn.commit()  # 変更を保存
    

except sqlite3.Error as e:
    print('SQLite error:', e)
    
finally:
    # DBへの接続を閉じる
    conn.close()

# %%
path = ''
db_name = 'github_google.db'

try:
    #DBへのコネクションを確立
    conn = sqlite3.connect(path + db_name)

    #SQL(ROBを操作するための言語)を実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # SQL文の作成
    # データの挿入
    sql = "SELECT * FROM repositories;"
    
    # SQL文の実行
    cur.execute(sql)

except sqlite3.Error as e:
    print('SQLite error:', e)
    
else:
    # 取得したデータを表示
    for row in cur:
        id, name, pl, repositories = row
        print(f"id: {id}, name: {name}, pl: {pl}, repositories: {repositories}")

finally:
    # DBへの接続を閉じる
    conn.close()
# Out:
# id: 1, name: go-containerregistry, pl: Go, repositories: 601
# id: 2, name: quiche, pl: C++, repositories: 161
# id: 3, name: benchmark, pl: C++, repositories: 1700
# id: 4, name: jetpack-camera-app, pl: Kotlin, repositories: 49
# id: 5, name: gvisor, pl: Go, repositories: 1500
# id: 6, name: adk-python, pl: Python, repositories: 2400
# id: 7, name: android-cuttlefish, pl: C++, repositories: 175
# id: 8, name: XNNPACK, pl: C, repositories: 450
# id: 9, name: tunix, pl: Python, repositories: 172
# id: 10, name: device-infra, pl: Java, repositories: 23
# id: 11, name: dive, pl: C++, repositories: 10
# id: 12, name: nomulus, pl: Java, repositories: 295
# id: 13, name: cel-java, pl: Java, repositories: 28
# id: 14, name: dawn, pl: C++, repositories: 137
# id: 15, name: j2cl, pl: Java, repositories: 153
# id: 16, name: xls, pl: C++, repositories: 217
# id: 17, name: orbax, pl: Python, repositories: 71
# id: 18, name: ml-metrics, pl: Python, repositories: 4
# id: 19, name: perfetto, pl: C++, repositories: 619
# id: 20, name: automotive-design-compose, pl: Rust, repositories: 32
# id: 21, name: TestParameterInjector, pl: Java, repositories: 37
# id: 22, name: grain, pl: Python, repositories: 56
# id: 23, name: meridian, pl: Python, repositories: 209
# id: 24, name: docsy, pl: JavaScript, repositories: 953
# id: 25, name: heir, pl: C++, repositories: 106
# id: 26, name: init2winit, pl: Python, repositories: 10
# id: 27, name: langfun, pl: Python, repositories: 69
# id: 28, name: filament, pl: C++, repositories: 2100
# id: 29, name: chromium-policy-vulnfeed, pl: Go, repositories: 6
# id: 30, name: bloaty, pl: C++, repositories: 365
# id: 31, name: s2geometry, pl: C++, repositories: 337
# id: 32, name: pullsheet, pl: Go, repositories: 20
# id: 33, name: nearby, pl: C++, repositories: 185
# id: 34, name: nsscache, pl: Python, repositories: 59
# id: 35, name: adk-samples, pl: Python, repositories: 1900
# id: 36, name: crubit, pl: C++, repositories: 54
# id: 37, name: zerocopy, pl: Rust, repositories: 131
# id: 38, name: Xee, pl: Python, repositories: 38
# id: 39, name: ecclesia-machine-management, pl: C++, repositories: 4
# id: 40, name: adk-docs, pl: HTML, repositories: 641
# id: 41, name: embardiment, pl: C#, repositories: 1
# id: 42, name: koladata, pl: C++, repositories: 14
# id: 43, name: earthengine-community, pl: Jupyter Notebook, repositories: 867
# id: 44, name: tcmalloc, pl: C++, repositories: 530
# id: 45, name: osv-scalibr, pl: Go, repositories: 90
# id: 46, name: aqt, pl: Python, repositories: 30
# id: 47, name: ground-android, pl: Kotlin, repositories: 138
# id: 48, name: adk-java, pl: Java, repositories: 199
# id: 49, name: angle, pl: C++, repositories: 689
# id: 50, name: yggdrasil-decision-forests, pl: C++, repositories: 70
# id: 51, name: skia, pl: C++, repositories: 1600
# id: 52, name: skia-buildbot, pl: Go, repositories: 79
# id: 53, name: error-prone, pl: Java, repositories: 774
# id: 54, name: torchax, pl: Python, repositories: 14
# id: 55, name: pdl, pl: Rust, repositories: 12
# id: 56, name: mcp-security, pl: Python, repositories: 81
# id: 57, name: oss-rebuild, pl: Go, repositories: 39
# id: 58, name: atheris, pl: Python, repositories: 118
# id: 59, name: fonts, pl: HTML, repositories: 2800
# id: 60, name: adk-python-community, pl: Python, repositories: 18
# id: 61, name: json_serializable.dart, pl: Dart, repositories: 436
# id: 62, name: xrblocks, pl: TypeScript, repositories: 14
# id: 63, name: ksp, pl: Kotlin, repositories: 358
# id: 64, name: fuzztest, pl: C++, repositories: 114
# id: 65, name: gson, pl: Java, repositories: 4400
# id: 66, name: qwix, pl: Python, repositories: 5
# id: 67, name: jsonschema-go, pl: Go, repositories: 18
# id: 68, name: gops, pl: Go, repositories: 337
# id: 69, name: adk-js, pl: TypeScript, repositories: 12
# id: 70, name: cel-cpp, pl: C++, repositories: 63
# id: 71, name: tarpc, pl: Rust, repositories: 214
# id: 72, name: civics_cdf_validator, pl: Python, repositories: 22
# id: 73, name: osv-scanner, pl: Go, repositories: 481
# id: 74, name: dagger, pl: Java, repositories: 3100
# id: 75, name: osv.dev, pl: Python, repositories: 251
# id: 76, name: oracle-toolkit, pl: Shell, repositories: 35
# id: 77, name: dranet, pl: Go, repositories: 26
# id: 78, name: site-kit-wp, pl: JavaScript, repositories: 326
# id: 79, name: earthengine-api, pl: JavaScript, repositories: 1100
# id: 80, name: go-attestation, pl: Go, repositories: 101
# id: 81, name: filonov, pl: Python, repositories: 1
# id: 82, name: libnss-cache, pl: C, repositories: 26
# id: 83, name: assertor, pl: Rust, repositories: 15
# id: 84, name: ground-platform, pl: TypeScript, repositories: 98
# id: 85, name: closure-templates, pl: Java, repositories: 193
# id: 86, name: flax, pl: Jupyter Notebook, repositories: 756
# id: 87, name: adk-go, pl: Go, repositories: 272
# id: 88, name: clspv, pl: LLVM, repositories: 100
# id: 89, name: gemma.cpp, pl: C++, repositories: 573
# id: 90, name: langextract, pl: Python, repositories: 1200
# id: 91, name: secure-aggregation, pl: Rust, repositories: 2
# id: 92, name: pack, pl: Rust, repositories: 14
# id: 93, name: gurl, pl: C++, repositories: 0
# id: 94, name: shell-encryption, pl: C++, repositories: 41
# id: 95, name: certificate-transparency-go, pl: Go, repositories: 278
# id: 96, name: source_helper.dart, pl: Dart, repositories: 6
# id: 97, name: mug, pl: Java, repositories: 75
# id: 98, name: conscrypt, pl: Java, repositories: 311
# id: 99, name: libphonenumber, pl: C++, repositories: 2100
# id: 100, name: copybara, pl: Java, repositories: 291
# id: 101, name: earthengine-catalog, pl: Jsonnet, repositories: 93
# id: 102, name: oss-fuzz-vulns, pl: Python, repositories: 46
# id: 103, name: sentencepiece, pl: C++, repositories: 1300
# id: 104, name: dart-neats, pl: Dart, repositories: 89
# id: 105, name: go-querystring, pl: Go, repositories: 183
# id: 106, name: timesketch, pl: Python, repositories: 634
# id: 107, name: snappy, pl: C++, repositories: 1000
# id: 108, name: trillian-examples, pl: Go, repositories: 67
# id: 109, name: oss-fuzz, pl: Shell, repositories: 2500
# id: 110, name: android-security-lints, pl: Kotlin, repositories: 11
# id: 111, name: secops-wrapper, pl: Python, repositories: 27
# id: 112, name: syzkaller, pl: Go, repositories: 1300
# id: 113, name: dwh-migration-tools, pl: Java, repositories: 63
# id: 114, name: workflow-graph, pl: TypeScript, repositories: 27
# id: 115, name: android-fhir, pl: Kotlin, repositories: 317
# id: 116, name: silifuzz, pl: C++, repositories: 31
# id: 117, name: highway, pl: C++, repositories: 387
# id: 118, name: mozc, pl: C++, repositories: 438
# id: 119, name: garf, pl: Python, repositories: 3
# id: 120, name: tensorstore, pl: C++, repositories: 134
# id: 121, name: peoplemath, pl: TypeScript, repositories: 39
# id: 122, name: brotli, pl: TypeScript, repositories: 1300
# id: 123, name: kotlin-fhirpath, pl: Kotlin, repositories: 1
# id: 124, name: digitalbuildings, pl: Python, repositories: 159
# id: 125, name: fscrypt, pl: Go, repositories: 104
# id: 126, name: go-units, pl: Go, repositories: 2
# id: 127, name: trillian, pl: Go, repositories: 420
# id: 128, name: go-github, pl: Go, repositories: 2200
# id: 129, name: gke-policy-automation, pl: Go, repositories: 27
# id: 130, name: merchant-api-samples, pl: Java, repositories: 5
# id: 131, name: go-cloud, pl: Go, repositories: 824
# id: 132, name: aoss-verifier, pl: Go, repositories: 4
# id: 133, name: seesaw, pl: Go, repositories: 508
# id: 134, name: go-jsonnet, pl: Go, repositories: 249
# id: 135, name: osv-scanner-v1, pl: Go, repositories: 2
# id: 136, name: security-research, pl: C, repositories: 502
# id: 137, name: certtostore, pl: Go, repositories: 32
# id: 138, name: neuroglancer, pl: TypeScript, repositories: 333
# id: 139, name: crosvm, pl: Rust, repositories: 130
# id: 140, name: minijail, pl: C, repositories: 36
# id: 141, name: netkat, pl: C++, repositories: 3
# id: 142, name: osv-scanner-action, pl: Python, repositories: 24
# id: 143, name: jax-datetime, pl: Python, repositories: 1
# id: 144, name: glome, pl: C, repositories: 18
# id: 145, name: gutil, pl: C++, repositories: 4
# id: 146, name: boringssl, pl: C++, repositories: 851
# id: 147, name: fleetbench, pl: C++, repositories: 15
# id: 148, name: testrun, pl: Python, repositories: 16
# id: 149, name: across, pl: HTML, repositories: 8
# id: 150, name: budoux-extension, pl: TypeScript, repositories: 8
# id: 151, name: closure-compiler, pl: JavaScript, repositories: 1200
# id: 152, name: scaaml, pl: Python, repositories: 54
# id: 153, name: ink, pl: C++, repositories: 12
# id: 154, name: fhir, pl: C++, repositories: 203
# id: 155, name: dotprompt, pl: Python, repositories: 40
# id: 156, name: clusterfuzz, pl: Python, repositories: 592
# id: 157, name: horologist, pl: Kotlin, repositories: 109
# id: 158, name: nccl-plugin-gpudirect-tcpxo, pl: C++, repositories: 1
# id: 159, name: tsl, pl: C++, repositories: 28
# id: 160, name: llvm-propeller, pl: C++, repositories: 45
# id: 161, name: gnostic-models, pl: Go, repositories: 6
# id: 162, name: go-sev-guest, pl: Go, repositories: 28
# id: 163, name: fhir-gateway, pl: Java, repositories: 34
# id: 164, name: kotlin, pl: Kotlin, repositories: 6100
# id: 165, name: or-tools, pl: C++, repositories: 2300
# id: 166, name: open-dice, pl: C++, repositories: 9
# id: 167, name: googletest-rust, pl: Rust, repositories: 27
# id: 168, name: android-beat, pl: N/A, repositories: 0
# id: 169, name: bumble, pl: Python, repositories: 105
# id: 170, name: gwpsan, pl: C++, repositories: 10
# id: 171, name: nftables, pl: Go, repositories: 161
# id: 172, name: wasefire, pl: Rust, repositories: 27
# id: 173, name: clasp, pl: TypeScript, repositories: 477
# id: 174, name: guava, pl: Java, repositories: 11000
# id: 175, name: go-tdx-guest, pl: Go, repositories: 28
# id: 176, name: googleapis.dart, pl: Dart, repositories: 126
# id: 177, name: openhtf, pl: Python, repositories: 220
# id: 178, name: github_workflows_playground, pl: N/A, repositories: 1
# id: 179, name: eclipsa-audio-plugin, pl: C++, repositories: 8
# id: 180, name: adk-web, pl: TypeScript, repositories: 159
# id: 181, name: gce-tcb-verifier, pl: Go, repositories: 3
# id: 182, name: github-team, pl: Shell, repositories: 1
# id: 183, name: pyglove, pl: Python, repositories: 33
# id: 184, name: shaderc, pl: C++, repositories: 408
# id: 185, name: fhir-data-pipes, pl: Jupyter Notebook, repositories: 118
# id: 186, name: cel-go, pl: Go, repositories: 252
# id: 187, name: arolla, pl: C++, repositories: 14
# id: 188, name: inverting-proxy, pl: Go, repositories: 80
# id: 189, name: ChromeBrowserEnterprise, pl: C#, repositories: 53
# id: 190, name: travel-impact-model-website, pl: TypeScript, repositories: 3
# id: 191, name: learned_optimization, pl: Python, repositories: 68
# id: 192, name: gfxstream, pl: C++, repositories: 11
# id: 193, name: rpmpack, pl: Go, repositories: 32
# id: 194, name: cctz, pl: C++, repositories: 173
# id: 195, name: weather-tools, pl: Python, repositories: 45
# id: 196, name: schema-dts, pl: TypeScript, repositories: 46
# id: 197, name: foteli, pl: C++, repositories: 1
# id: 198, name: protobuf.dart, pl: Dart, repositories: 197
# id: 199, name: sedpack, pl: Python, repositories: 8
# id: 200, name: mdbook-i18n-helpers, pl: Rust, repositories: 36
# id: 201, name: zx, pl: JavaScript, repositories: 1200
# id: 202, name: tabuli, pl: C++, repositories: 7
# id: 203, name: deps.dev, pl: Go, repositories: 37
# id: 204, name: tsec, pl: TypeScript, repositories: 15
# id: 205, name: github-sandbox, pl: N/A, repositories: 210
# id: 206, name: dotguides, pl: TypeScript, repositories: 1
# id: 207, name: aarch64-esr-decoder, pl: Rust, repositories: 20
# id: 208, name: torq, pl: Python, repositories: 1
# id: 209, name: osdfir-infrastructure, pl: Smarty, repositories: 18
# id: 210, name: github_nonpublic_api, pl: Python, repositories: 9
# id: 211, name: cel-spec, pl: Starlark, repositories: 268
# id: 212, name: libhoth, pl: C, repositories: 26
# id: 213, name: flatbuffers, pl: C++, repositories: 3400
# id: 214, name: oss-fuzz-gen, pl: Python, repositories: 203
# id: 215, name: auto, pl: Java, repositories: 1200
# id: 216, name: xctestrunner, pl: Python, repositories: 69
# id: 217, name: escapevelocity, pl: Java, repositories: 10
# id: 218, name: postcss-rename, pl: TypeScript, repositories: 20
# id: 219, name: praxis, pl: Python, repositories: 44
# id: 220, name: transit, pl: N/A, repositories: 206
# id: 221, name: riegeli, pl: C++, repositories: 61
# id: 222, name: swiftshader, pl: C++, repositories: 313
# id: 223, name: osdemo, pl: Rust, repositories: 1
# id: 224, name: j2objc, pl: Java, repositories: 993
# id: 225, name: turbine, pl: Java, repositories: 23
# id: 226, name: differential-privacy, pl: Go, repositories: 407
# id: 227, name: caliper, pl: Java, repositories: 108
# id: 228, name: aidl-language, pl: N/A, repositories: 4
# id: 229, name: selinux-policy-languages, pl: N/A, repositories: 2
# id: 230, name: pdl-language, pl: N/A, repositories: 2
# id: 231, name: comprehensive-rust, pl: Rust, repositories: 1900
# id: 232, name: webcrypto.dart, pl: Dart, repositories: 70
# id: 233, name: budoux, pl: Python, repositories: 38
# id: 234, name: pytype, pl: Python, repositories: 289
# id: 235, name: paxml, pl: Python, repositories: 70
# id: 236, name: renameio, pl: Go, repositories: 29
# id: 237, name: seqio, pl: Python, repositories: 60
# id: 238, name: google-toolbox-for-mac, pl: Objective-C, repositories: 266
# id: 239, name: gtm-session-fetcher, pl: Objective-C, repositories: 164
# id: 240, name: alioth, pl: Rust, repositories: 21
# id: 241, name: iwa-vscode-extension, pl: TypeScript, repositories: 3
# id: 242, name: mobly, pl: Python, repositories: 203
# id: 243, name: project-voice, pl: TypeScript, repositories: 11
# id: 244, name: duet, pl: Python, repositories: 16
# id: 245, name: cro3, pl: Rust, repositories: 15
# id: 246, name: arb-editor, pl: TypeScript, repositories: 7
# id: 247, name: codeql-action, pl: TypeScript, repositories: 420
# id: 248, name: dfindexeddb, pl: Python, repositories: 11
# id: 249, name: sound-checker, pl: Kotlin, repositories: 9
# id: 250, name: traceviz, pl: TypeScript, repositories: 0
# id: 251, name: etils, pl: Python, repositories: 25
# id: 252, name: labs-prototypes, pl: Jupyter Notebook, repositories: 22
# id: 253, name: vector_math.dart, pl: Dart, repositories: 88
# id: 254, name: pprof, pl: Go, repositories: 641
# id: 255, name: rust-crate-audits, pl: N/A, repositories: 12
# id: 256, name: aarch64-rt, pl: Rust, repositories: 7
# id: 257, name: aside, pl: TypeScript, repositories: 11
# id: 258, name: privacy-sandbox-aggregation-service, pl: Go, repositories: 14
# id: 259, name: rbrotli-enc, pl: Rust, repositories: 5
# id: 260, name: ads-api-report-fetcher, pl: TypeScript, repositories: 17
# id: 261, name: guice, pl: Java, repositories: 1700
# id: 262, name: mobly-bundled-snippets, pl: Java, repositories: 64
# id: 263, name: metrax, pl: Python, repositories: 12
# id: 264, name: magika, pl: Python, repositories: 475
# id: 265, name: sec-gemini, pl: Svelte, repositories: 20
# id: 266, name: symphony-gcp, pl: Python, repositories: 1
# id: 267, name: cameratrapai, pl: Python, repositories: 43
# id: 268, name: ml-compiler-opt, pl: Python, repositories: 113
# id: 269, name: google-cloud-datastore-quadruple, pl: M4, repositories: 1
# id: 270, name: styleguide, pl: HTML, repositories: 13000
# id: 271, name: array_record, pl: C++, repositories: 23
# id: 272, name: mobly-android-screen-recorder, pl: Python, repositories: 3
# id: 273, name: certificate-transparency-community-site, pl: HTML, repositories: 68
# id: 274, name: tsunami-security-scanner-plugins, pl: Java, repositories: 212
# id: 275, name: tsunami-security-scanner, pl: Java, repositories: 919
# id: 276, name: keep-sorted, pl: Go, repositories: 26
# id: 277, name: docsy-example, pl: HTML, repositories: 735
# id: 278, name: perf_data_converter, pl: C++, repositories: 63
# id: 279, name: android-emulator-hypervisor-driver, pl: C, repositories: 256
# id: 280, name: ads_oneshop, pl: Python, repositories: 7
# id: 281, name: EarlGrey, pl: Objective-C, repositories: 739
# id: 282, name: zetasql, pl: C++, repositories: 232
# id: 283, name: myvibe, pl: N/A, repositories: 1
# id: 284, name: business_intelligence_group, pl: Jupyter Notebook, repositories: 3
# id: 285, name: mobly-bluetooth-ref-validation, pl: Python, repositories: 3
# id: 286, name: googletest, pl: C++, repositories: 11000
# id: 287, name: oboe, pl: C++, repositories: 612
# id: 288, name: cloud-android-orchestration, pl: Go, repositories: 35
# id: 289, name: compile-testing, pl: Java, repositories: 124
# id: 290, name: fhir-py, pl: Python, repositories: 15
# id: 291, name: product_video_ads, pl: TypeScript, repositories: 25
# id: 292, name: xplat, pl: Java, repositories: 4
# id: 293, name: go-tpm, pl: Go, repositories: 171
# id: 294, name: guava-beta-checker, pl: Java, repositories: 19
# id: 295, name: google-authenticator-libpam, pl: C, repositories: 302
# id: 296, name: spatial-media, pl: Python, repositories: 455
# id: 297, name: jimfs, pl: Java, repositories: 283
# id: 298, name: truth, pl: Java, repositories: 267
# id: 299, name: longfellow-zk, pl: C++, repositories: 79
# id: 300, name: kernel-research, pl: C++, repositories: 8
# id: 301, name: bindiff, pl: Java, repositories: 205
# id: 302, name: shifter, pl: Go, repositories: 26
# id: 303, name: cddlconv, pl: TypeScript, repositories: 1
# id: 304, name: coset, pl: Rust, repositories: 22
# id: 305, name: sbom-conformance, pl: Go, repositories: 3
# id: 306, name: brax, pl: Jupyter Notebook, repositories: 316
# id: 307, name: starlark-go, pl: Go, repositories: 228
# id: 308, name: GoogleSignIn-iOS, pl: Objective-C, repositories: 245
# id: 309, name: rust_icu, pl: Rust, repositories: 31
# id: 310, name: jsir, pl: C++, repositories: 9
# id: 311, name: walt, pl: Java, repositories: 76
# id: 312, name: meterstick, pl: Jupyter Notebook, repositories: 20
# id: 313, name: cpu_features, pl: C++, repositories: 289
# id: 314, name: binexport, pl: C++, repositories: 232
# id: 315, name: kotlin-fhir, pl: Kotlin, repositories: 11
# id: 316, name: saxml, pl: Python, repositories: 31
# id: 317, name: ever, pl: Jupyter Notebook, repositories: 3
# id: 318, name: sso-offloading, pl: TypeScript, repositories: 1
# id: 319, name: kf, pl: Go, repositories: 60
# id: 320, name: vizier, pl: Python, repositories: 108
# id: 321, name: instrumentsToPprof, pl: Go, repositories: 12
# id: 322, name: mozc-devices, pl: C++, repositories: 175
# id: 323, name: ml_collections, pl: Python, repositories: 46
# id: 324, name: graph-renderer, pl: N/A, repositories: 0
# id: 325, name: toucan, pl: C++, repositories: 2
# id: 326, name: container-explorer, pl: Go, repositories: 12
# id: 327, name: googet, pl: Go, repositories: 45
# id: 328, name: google-api-objectivec-client-for-rest, pl: Objective-C, repositories: 337
# id: 329, name: desugar_jdk_libs, pl: Java, repositories: 31
# id: 330, name: uncertainty-baselines, pl: Python, repositories: 215
# id: 331, name: bt-navi-tests, pl: Python, repositories: 3
# id: 332, name: capslock, pl: Go, repositories: 40
# id: 333, name: go-tpm-tools, pl: C, repositories: 84
# id: 334, name: jax-cfd, pl: Jupyter Notebook, repositories: 132
# id: 335, name: p4-infra, pl: C++, repositories: 2
# id: 336, name: kotlin_convert, pl: Kotlin, repositories: 2
# id: 337, name: built_collection.dart, pl: Dart, repositories: 52
# id: 338, name: quiver-dart, pl: Dart, repositories: 132
# id: 339, name: pthreadpool, pl: C++, repositories: 148
# id: 340, name: webkit_inspection_protocol.dart, pl: Dart, repositories: 18
# id: 341, name: semantic-locators, pl: JavaScript, repositories: 13
# id: 342, name: brotli-wheels, pl: N/A, repositories: 10
# id: 343, name: openintent, pl: N/A, repositories: 5
# id: 344, name: re2, pl: C++, repositories: 1200
# id: 345, name: bazel-common, pl: Starlark, repositories: 44
# id: 346, name: bughunters, pl: N/A, repositories: 24
# id: 347, name: filament-assets, pl: Mathematica, repositories: 1
# id: 348, name: xarray-beam, pl: Python, repositories: 14
# id: 349, name: gsocguides, pl: CSS, repositories: 174
# id: 350, name: mpact-cheriot, pl: C++, repositories: 1
# id: 351, name: glazier, pl: Python, repositories: 92
# id: 352, name: mpact-riscv, pl: C++, repositories: 6
# id: 353, name: tfp-causalimpact, pl: Python, repositories: 16
# id: 354, name: fscryptctl, pl: C, repositories: 37
# id: 355, name: capirca, pl: Python, repositories: 210
# id: 356, name: imt, pl: C++, repositories: 3
# id: 357, name: neper, pl: C, repositories: 86
# id: 358, name: autofdo, pl: C++, repositories: 120
# id: 359, name: ARC-GEN, pl: Python, repositories: 4
# id: 360, name: fresnel, pl: Go, repositories: 18
# id: 361, name: dart_cli_pkg, pl: Dart, repositories: 24
# id: 362, name: fiddle, pl: Python, repositories: 20
# id: 363, name: elemental2, pl: Java, repositories: 38
# id: 364, name: jsinterop-base, pl: Java, repositories: 17
# id: 365, name: jsinterop-annotations, pl: Java, repositories: 8
# id: 366, name: jsinterop-generator, pl: Java, repositories: 23
# id: 367, name: genie-for-sap-abap-ai-assistant-sample, pl: ABAP, repositories: 7
# id: 368, name: omaha-client, pl: Rust, repositories: 4
# id: 369, name: sbat-rs, pl: Rust, repositories: 7
# id: 370, name: authenticode-rs, pl: Rust, repositories: 12
# id: 371, name: gpt-disk-rs, pl: Rust, repositories: 12
# id: 372, name: hackable_diffusion, pl: Python, repositories: 2
# id: 373, name: zimtohrli, pl: Jupyter Notebook, repositories: 10
# id: 374, name: safevalues, pl: TypeScript, repositories: 15
# id: 375, name: uri.dart, pl: Dart, repositories: 43
# id: 376, name: mangle, pl: Go, repositories: 145
# id: 377, name: mono_repo.dart, pl: Dart, repositories: 33
# id: 378, name: python-fire, pl: Python, repositories: 1500
# id: 379, name: gn-language-server, pl: Rust, repositories: 4
# id: 380, name: ragvis, pl: N/A, repositories: 0
# id: 381, name: xarray-tensorstore, pl: Python, repositories: 5
# id: 382, name: flogger, pl: Java, repositories: 125
# id: 383, name: breakpad, pl: C++, repositories: 770
# id: 384, name: hotels-template-library, pl: C++, repositories: 7
# id: 385, name: google-ctf, pl: Python, repositories: 582
# id: 386, name: process_runner, pl: Dart, repositories: 7
# id: 387, name: nsync, pl: C, repositories: 94
# id: 388, name: quic-trace, pl: C++, repositories: 22
# id: 389, name: temporian, pl: Python, repositories: 46
# id: 390, name: mtail, pl: Go, repositories: 393
# id: 391, name: obr, pl: C++, repositories: 4
# id: 392, name: turbinia, pl: Python, repositories: 167
# id: 393, name: google-java-format, pl: Java, repositories: 904
# id: 394, name: addlicense, pl: Go, repositories: 189
# id: 395, name: GoogleAppMeasurement, pl: Swift, repositories: 21
# id: 396, name: rrg, pl: Rust, repositories: 27
# id: 397, name: evt-air-risk-aiaa-scitech-2026, pl: Python, repositories: 1
# id: 398, name: watchface, pl: Kotlin, repositories: 5
# id: 399, name: double-conversion, pl: C++, repositories: 302
# id: 400, name: der-ascii, pl: Go, repositories: 29
# id: 401, name: inject-common, pl: Java, repositories: 8
# id: 402, name: jaxite, pl: Python, repositories: 7
# id: 403, name: airio, pl: Python, repositories: 11
# id: 404, name: buzzer, pl: Go, repositories: 37
# id: 405, name: jpegli, pl: C++, repositories: 35
# id: 406, name: ts-bridge, pl: Go, repositories: 20
# id: 407, name: slo-generator, pl: Python, repositories: 87
# id: 408, name: autobound, pl: Python, repositories: 19
# id: 409, name: pdsl-xray, pl: Java, repositories: 3
# id: 410, name: test-server, pl: Go, repositories: 8
# id: 411, name: sbsim, pl: Python, repositories: 35
# id: 412, name: tracey, pl: Go, repositories: 0
# id: 413, name: smbios-validation-tool, pl: Go, repositories: 19
# id: 414, name: pmax_best_practices_dashboard, pl: Shell, repositories: 15
# id: 415, name: pubmed-rag, pl: Jupyter Notebook, repositories: 1
# id: 416, name: loudness_ebur128, pl: C++, repositories: 2
# id: 417, name: python-proto-converter, pl: Python, repositories: 3
# id: 418, name: pathways-job, pl: Go, repositories: 5
# id: 419, name: humanio, pl: JavaScript, repositories: 6
# id: 420, name: anonymous-tokens, pl: C++, repositories: 22
# id: 421, name: eDistantObject, pl: Objective-C, repositories: 35
# id: 422, name: built_value.dart, pl: Dart, repositories: 192
# id: 423, name: fleetspeak, pl: Go, repositories: 31
# id: 424, name: yamlfmt, pl: Go, repositories: 61
# id: 425, name: tf-shell, pl: Python, repositories: 3
# id: 426, name: rootcanal, pl: C++, repositories: 9
# id: 427, name: skcms, pl: N/A, repositories: 2
# id: 428, name: deepvariant, pl: Python, repositories: 767
# id: 429, name: drjax, pl: Python, repositories: 1
# id: 430, name: jaxloop, pl: Jupyter Notebook, repositories: 2
# id: 431, name: private-join-and-compute, pl: C++, repositories: 151
# id: 432, name: gnxi, pl: Python, repositories: 123
# id: 433, name: winops, pl: Go, repositories: 15
# id: 434, name: intellij-community, pl: Java, repositories: 5600
# id: 435, name: wireit, pl: TypeScript, repositories: 114
# id: 436, name: aarch64-paging, pl: Rust, repositories: 10
# id: 437, name: synopsys-dw-uart, pl: Rust, repositories: 0
# id: 438, name: command-fds, pl: Rust, repositories: 8
# id: 439, name: OpenSK, pl: Rust, repositories: 318
# id: 440, name: capsem, pl: Python, repositories: 0
# id: 441, name: private-membership, pl: C++, repositories: 13
# id: 442, name: yapf, pl: Python, repositories: 902
# id: 443, name: rune, pl: C, repositories: 46
# id: 444, name: trillian-website, pl: HTML, repositories: 20
# id: 445, name: vanir, pl: Python, repositories: 29
# id: 446, name: cabbie, pl: Go, repositories: 20
# id: 447, name: travel-impact-model, pl: N/A, repositories: 26
# id: 448, name: nsjail, pl: C++, repositories: 293
# id: 449, name: sandboxed-api, pl: C++, repositories: 194
# id: 450, name: deepsomatic, pl: N/A, repositories: 41
# id: 451, name: licenseclassifier, pl: Go, repositories: 79
# id: 452, name: distbench, pl: C++, repositories: 17
# id: 453, name: ide-perf, pl: Kotlin, repositories: 14
# id: 454, name: native-pkcs11, pl: Rust, repositories: 18
# id: 455, name: mpact-sim, pl: C++, repositories: 8
# id: 456, name: webview-ads, pl: HTML, repositories: 1
# id: 457, name: gematria, pl: Python, repositories: 18
# id: 458, name: taxinomia, pl: Go, repositories: 0
# id: 459, name: opendocs, pl: N/A, repositories: 51
# id: 460, name: jaxopt, pl: Python, repositories: 73
# id: 461, name: threat-team, pl: YARA, repositories: 7
# id: 462, name: generative-ai-docs, pl: Jupyter Notebook, repositories: 738
# id: 463, name: oss-policies-info, pl: N/A, repositories: 23
# id: 464, name: cloud-forensics-utils, pl: Python, repositories: 90
# id: 465, name: play-unreal-engine-plugin, pl: C++, repositories: 6
# id: 466, name: security-testbeds, pl: Tcl, repositories: 43
# id: 467, name: amber, pl: C++, repositories: 70
# id: 468, name: proto-lens, pl: Haskell, repositories: 118
# id: 469, name: play-services-plugins, pl: Java, repositories: 155
# id: 470, name: packetdrill, pl: C, repositories: 232
# id: 471, name: codemirror.dart, pl: Dart, repositories: 33
# id: 472, name: emboss, pl: Python, repositories: 26
# id: 473, name: playground-elements, pl: TypeScript, repositories: 61
# id: 474, name: snippet-uiautomator, pl: Java, repositories: 21
# id: 475, name: slowjam, pl: HTML, repositories: 14
# id: 476, name: fswalker, pl: Go, repositories: 11
# id: 477, name: sanitizers, pl: C, repositories: 1100
# id: 478, name: reflectable.dart, pl: Dart, repositories: 63
# id: 479, name: private-compute-services, pl: Java, repositories: 118
# id: 480, name: llm-sidebar-with-context, pl: JavaScript, repositories: 1
# id: 481, name: mediapy, pl: Jupyter Notebook, repositories: 20
# id: 482, name: learn-oss-with-google, pl: Python, repositories: 10
# id: 483, name: google.github.io, pl: HTML, repositories: 68
# id: 484, name: minimalloc, pl: C++, repositories: 15
# id: 485, name: smccc, pl: Rust, repositories: 3
# id: 486, name: s2a-proto, pl: N/A, repositories: 6
# id: 487, name: s2a-go, pl: Go, repositories: 10
# id: 488, name: GoogleUtilities, pl: Objective-C, repositories: 57
# id: 489, name: mount-zip, pl: C++, repositories: 19
# id: 490, name: dnsmasq_exporter, pl: Go, repositories: 61
# id: 491, name: libultrahdr, pl: C++, repositories: 46
# id: 492, name: GTMAppAuth, pl: Swift, repositories: 220
# id: 493, name: ffn, pl: Python, repositories: 103
# id: 494, name: trax, pl: Python, repositories: 828
# id: 495, name: mobly-wifi, pl: Python, repositories: 0
# id: 496, name: CausalImpact, pl: R, repositories: 260
# id: 497, name: create-service-account, pl: Python, repositories: 12
# id: 498, name: wmt-mqm-human-evaluation, pl: N/A, repositories: 11
# id: 499, name: polymorphicDSL, pl: Java, repositories: 6
# id: 500, name: apitools, pl: Python, repositories: 116
# id: 501, name: flink-connector-gcp, pl: Java, repositories: 3
# id: 502, name: bundletool, pl: Java, repositories: 409
# id: 503, name: rdma-unit-test, pl: C++, repositories: 16
# id: 504, name: kafel, pl: C, repositories: 54
# id: 505, name: GiftStick, pl: Python, repositories: 21
# id: 506, name: minja, pl: C++, repositories: 25
# id: 507, name: gin-config, pl: Python, repositories: 119
# id: 508, name: quahog, pl: Go, repositories: 1
# id: 509, name: sagetv, pl: Java, repositories: 173
# id: 510, name: protobuf-gradle-plugin, pl: Groovy, repositories: 282
# id: 511, name: struct2tensor, pl: Python, repositories: 21
# id: 512, name: material-design-icons, pl: N/A, repositories: 9700
# id: 513, name: closure-compiler-npm, pl: JavaScript, repositories: 71
# id: 514, name: allocation-instrumenter, pl: Java, repositories: 89
# id: 515, name: draco, pl: C++, repositories: 1000
# id: 516, name: jscin, pl: JavaScript, repositories: 18
# id: 517, name: kati, pl: Rust, repositories: 121
# id: 518, name: GoogleDataTransport, pl: Objective-C, repositories: 36
# id: 519, name: cql, pl: Go, repositories: 12
# id: 520, name: interop-ios-for-google-sdks, pl: Objective-C, repositories: 3
# id: 521, name: app-check, pl: Objective-C, repositories: 6
# id: 522, name: fully-homomorphic-encryption, pl: C++, repositories: 266
# id: 523, name: strict-csp, pl: TypeScript, repositories: 10
# id: 524, name: jaxonnxruntime, pl: Python, repositories: 23
# id: 525, name: subcommands, pl: Go, repositories: 50
# id: 526, name: ukey2, pl: Java, repositories: 20
# id: 527, name: dataflow-ml-starter, pl: Python, repositories: 8
# id: 528, name: async-request-dispatcher-rs, pl: Rust, repositories: 0
# id: 529, name: virtual-broadcast-production-assistant, pl: JavaScript, repositories: 16
# id: 530, name: honggfuzz, pl: C, repositories: 529
# id: 531, name: kctf, pl: Go, repositories: 75
# id: 532, name: gcp_scanner, pl: Python, repositories: 106
# id: 533, name: bigwheels, pl: C++, repositories: 39
# id: 534, name: web-game-samples, pl: JavaScript, repositories: 12
# id: 535, name: fleetspeak-rs, pl: Rust, repositories: 7
# id: 536, name: eng-edu, pl: Jupyter Notebook, repositories: 428
# id: 537, name: edward2, pl: Jupyter Notebook, repositories: 78
# id: 538, name: fuse-archive, pl: C++, repositories: 24
# id: 539, name: github-webhook-pubsub-bridge, pl: Go, repositories: 3
# id: 540, name: safe-mmio, pl: Rust, repositories: 5
# id: 541, name: percore, pl: Rust, repositories: 2
# id: 542, name: go-licenses, pl: Go, repositories: 128
# id: 543, name: pybind11clif, pl: C++, repositories: 7
# id: 544, name: shaderc-rs, pl: Rust, repositories: 71
# id: 545, name: closure-net, pl: N/A, repositories: 0
# id: 546, name: rax, pl: Python, repositories: 12
# id: 547, name: go-dap, pl: Go, repositories: 28
# id: 548, name: distributed_point_functions, pl: C++, repositories: 19
# id: 549, name: rust-scudo, pl: Rust, repositories: 9
# id: 550, name: casimir, pl: Rust, repositories: 0
# id: 551, name: ota-analyzer, pl: JavaScript, repositories: 4
# id: 552, name: crumbles, pl: Java, repositories: 0
# id: 553, name: tuple.dart, pl: Dart, repositories: 27
# id: 554, name: grinder.dart, pl: Dart, repositories: 36
# id: 555, name: webdriver.dart, pl: Dart, repositories: 47
# id: 556, name: sync_http.dart, pl: Dart, repositories: 16
# id: 557, name: flutter-mediapipe, pl: Dart, repositories: 25
# id: 558, name: dart-basics, pl: Dart, repositories: 18
# id: 559, name: genc, pl: C++, repositories: 7
# id: 560, name: carfac, pl: Jupyter Notebook, repositories: 50
# id: 561, name: kube-startup-cpu-boost, pl: Go, repositories: 24
# id: 562, name: jni-bind, pl: C++, repositories: 36
# id: 563, name: autocxx, pl: Rust, repositories: 164
# id: 564, name: ghc-source-gen, pl: Haskell, repositories: 32
# id: 565, name: tsunami-security-scanner-callback-server, pl: Java, repositories: 2
# id: 566, name: partner-ads-experience, pl: N/A, repositories: 0
# id: 567, name: fast-isotropic-median-filter, pl: C++, repositories: 3
# id: 568, name: ink-stroke-modeler, pl: C++, repositories: 17
# id: 569, name: cad_campaign_anomaly_detector, pl: JavaScript, repositories: 2
# id: 570, name: pcie_lmt, pl: Go, repositories: 3
# id: 571, name: llvm-memprof, pl: C++, repositories: 0
# id: 572, name: soql-tool, pl: Apex, repositories: 2
# id: 573, name: pl011-uart, pl: Rust, repositories: 1
# id: 574, name: saif-data, pl: N/A, repositories: 0
# id: 575, name: link-diver, pl: TypeScript, repositories: 10
# id: 576, name: wire, pl: Go, repositories: 711
# id: 577, name: grpc-binary, pl: Swift, repositories: 2
# id: 578, name: kunit-docs, pl: HTML, repositories: 8
# id: 579, name: evolve-forms, pl: Apex, repositories: 45
# id: 580, name: matched_markets, pl: Python, repositories: 30
# id: 581, name: flow-lens, pl: TypeScript, repositories: 9
# id: 582, name: distributed_graph_flow, pl: N/A, repositories: 0
# id: 583, name: go-eventlog, pl: Go, repositories: 4
# id: 584, name: Serberus, pl: N/A, repositories: 0
# id: 585, name: node-gles, pl: C++, repositories: 31
# id: 586, name: co-op-4-all, pl: TypeScript, repositories: 5
# id: 587, name: data-driven-discretization-1d, pl: Jupyter Notebook, repositories: 61
# id: 588, name: howtodiv, pl: Python, repositories: 2
# id: 589, name: corpuscrawler, pl: Python, repositories: 54
# id: 590, name: accompanist, pl: Kotlin, repositories: 654
# id: 591, name: proto-task-queue, pl: Python, repositories: 6
# id: 592, name: arm-gic, pl: Rust, repositories: 11
# id: 593, name: python-spanner-orm, pl: Python, repositories: 15
# id: 594, name: multichase, pl: C, repositories: 93
# id: 595, name: graph-mining, pl: C++, repositories: 42
# id: 596, name: executor.nvim, pl: Lua, repositories: 9
# id: 597, name: s2-geometry-library-java, pl: Java, repositories: 237
# id: 598, name: gnostic, pl: Go, repositories: 272
# id: 599, name: cluster-data, pl: TeX, repositories: 206
# id: 600, name: cassowary.dart, pl: Dart, repositories: 15
# id: 601, name: speaker-id, pl: Python, repositories: 39
# id: 602, name: localtoast, pl: Go, repositories: 13
# id: 603, name: generative-ai-go, pl: Go, repositories: 91
# id: 604, name: if-this-then-ad, pl: TypeScript, repositories: 16
# id: 605, name: dynamicworld, pl: Jupyter Notebook, repositories: 22
# id: 606, name: effcee, pl: C++, repositories: 40
# id: 607, name: facade, pl: Python, repositories: 16
# id: 608, name: har2csv, pl: JavaScript, repositories: 15
# id: 609, name: reflow-list, pl: TypeScript, repositories: 6
# id: 610, name: model-viewer, pl: TypeScript, repositories: 889
# id: 611, name: esamplusplus, pl: Python, repositories: 2
# id: 612, name: devlibrary, pl: Vue, repositories: 80
# id: 613, name: shoptimizer, pl: Python, repositories: 27
# id: 614, name: safe-active-record, pl: Ruby, repositories: 3
# id: 615, name: practical-inverse-rendering-of-textured-and-translucent-appearance, pl: Python, repositories: 12
# id: 616, name: deluca, pl: Jupyter Notebook, repositories: 17
# id: 617, name: wci, pl: Python, repositories: 12
# id: 618, name: csv-to-firestore, pl: Python, repositories: 9
# id: 619, name: tacotron, pl: HTML, repositories: 84
# id: 620, name: sequence-layers, pl: Python, repositories: 8
# id: 621, name: conversational-surveys, pl: JavaScript, repositories: 0
# id: 622, name: ippusb, pl: Rust, repositories: 4
# id: 623, name: rubik, pl: Python, repositories: 3
# id: 624, name: vbootrom, pl: C, repositories: 17
# id: 625, name: web-hv, pl: JavaScript, repositories: 12
# id: 626, name: safety-web, pl: TypeScript, repositories: 1
# id: 627, name: argh, pl: Rust, repositories: 94
# id: 628, name: fedjax, pl: Python, repositories: 42
# id: 629, name: jsonnet, pl: Jsonnet, repositories: 468
# id: 630, name: chrome-ssh-agent, pl: Go, repositories: 40
# id: 631, name: hrx-ruby, pl: Ruby, repositories: 3
# id: 632, name: smc-hello-world, pl: C, repositories: 0
# id: 633, name: smc-common, pl: C, repositories: 0
# id: 634, name: deku, pl: Go, repositories: 0
# id: 635, name: code-review-bot, pl: Go, repositories: 23
# id: 636, name: truestreet, pl: Go, repositories: 12
# id: 637, name: python-card-framework, pl: Python, repositories: 4
# id: 638, name: ruy, pl: C++, repositories: 91
# id: 639, name: wuffs, pl: C, repositories: 142
# id: 640, name: gmail-oauth2-tools, pl: Python, repositories: 219
# id: 641, name: triage-party, pl: Go, repositories: 84
# id: 642, name: web-api-gateway, pl: Go, repositories: 22
# id: 643, name: payjs, pl: JavaScript, repositories: 12
# id: 644, name: gonids, pl: Go, repositories: 50
# id: 645, name: flyweights, pl: Rust, repositories: 3
# id: 646, name: litmus, pl: Vue, repositories: 4
# id: 647, name: gtest-parallel, pl: Python, repositories: 112
# id: 648, name: ml-edu, pl: Python, repositories: 2
# id: 649, name: automotive-design-compose-protos, pl: N/A, repositories: 1
# id: 650, name: swissgl, pl: JavaScript, repositories: 46
# id: 651, name: rde-tester, pl: C++, repositories: 0
# id: 652, name: refvnli, pl: JavaScript, repositories: 0
# id: 653, name: CoMMA, pl: Rust, repositories: 5
# id: 654, name: fsl-gaming, pl: JavaScript, repositories: 8
# id: 655, name: terraform-google-sqlserver, pl: PowerShell, repositories: 1
# id: 656, name: cost-attribution-solution, pl: HCL, repositories: 12
# id: 657, name: lmeval, pl: Python, repositories: 21
# id: 658, name: tachometer, pl: TypeScript, repositories: 23
# id: 659, name: ios-webkit-debug-proxy, pl: C, repositories: 476
# id: 660, name: apilark, pl: N/A, repositories: 0
# id: 661, name: tcli, pl: Python, repositories: 6
# id: 662, name: app-resource-bundle, pl: N/A, repositories: 17
# id: 663, name: recaptcha, pl: PHP, repositories: 777
# id: 664, name: ent, pl: Go, repositories: 7
# id: 665, name: CommonLoopUtils, pl: Jupyter Notebook, repositories: 33
# id: 666, name: ebpf-transport-monitoring, pl: Go, repositories: 3
# id: 667, name: rago, pl: Python, repositories: 5
# id: 668, name: aukera, pl: Go, repositories: 10
# id: 669, name: open-location-code, pl: Java, repositories: 521
# id: 670, name: jaxcam, pl: Python, repositories: 1
# id: 671, name: content_recommendation_using_word2vec, pl: Python, repositories: 2
# id: 672, name: safehtml, pl: Go, repositories: 22
# id: 673, name: forest-data-partnership, pl: Jupyter Notebook, repositories: 8
# id: 674, name: lightweight_mmm, pl: Python, repositories: 232
# id: 675, name: gazoo-device, pl: Python, repositories: 8
# id: 676, name: bt-test-interfaces, pl: Python, repositories: 9
# id: 677, name: avatar, pl: Python, repositories: 13
# id: 678, name: paranoid_crypto, pl: Python, repositories: 48
# id: 679, name: proto-splitter, pl: C++, repositories: 0
# id: 680, name: cadvisor, pl: Go, repositories: 2400
# id: 681, name: unblocking-detail-caption, pl: HTML, repositories: 1
# id: 682, name: auto-arborist, pl: Jupyter Notebook, repositories: 3
# id: 683, name: qkeras, pl: Python, repositories: 110
# id: 684, name: pts-bot, pl: Rust, repositories: 2
# id: 685, name: private-compute-libraries, pl: Kotlin, repositories: 7
# id: 686, name: vroom, pl: Python, repositories: 28
# id: 687, name: libaddressinput, pl: C++, repositories: 107
# id: 688, name: android-key-attestation, pl: Java, repositories: 71
# id: 689, name: dv360-duplicator, pl: TypeScript, repositories: 2
# id: 690, name: eiffel, pl: C, repositories: 0
# id: 691, name: skyline_rl_lab, pl: Jupyter Notebook, repositories: 0
# id: 692, name: pseudo-identity-provider, pl: Go, repositories: 4
# id: 693, name: llvm-premerge-checks, pl: Python, repositories: 37
# id: 694, name: go-configfs-tsm, pl: Go, repositories: 7
# id: 695, name: grr, pl: Python, repositories: 793
# id: 696, name: sandwiched_compression, pl: Jupyter Notebook, repositories: 12
# id: 697, name: gemma_pytorch, pl: Python, repositories: 563
# id: 698, name: go-safeweb, pl: Go, repositories: 84
# id: 699, name: visualblocks, pl: TypeScript, repositories: 178
# id: 700, name: codesearch, pl: Go, repositories: 395
# id: 701, name: webauthndemo, pl: TypeScript, repositories: 132
# id: 702, name: UIforETW, pl: C++, repositories: 221
# id: 703, name: hiba, pl: C, repositories: 18
# id: 704, name: pyink, pl: Python, repositories: 2700
# id: 705, name: vk-layer-for-rust, pl: Rust, repositories: 4
# id: 706, name: liblc3, pl: C, repositories: 78
# id: 707, name: taqo-paco, pl: Dart, repositories: 8
# id: 708, name: jse4conf, pl: Java, repositories: 6
# id: 709, name: synthmark, pl: C++, repositories: 23
# id: 710, name: df-conformer, pl: HTML, repositories: 4
# id: 711, name: zetasketch, pl: Java, repositories: 23
# id: 712, name: cairn, pl: C++, repositories: 3
# id: 713, name: agi, pl: Go, repositories: 157
# id: 714, name: lullaby, pl: C++, repositories: 160
# id: 715, name: visqol, pl: C++, repositories: 140
# id: 716, name: glog, pl: C++, repositories: 2100
# id: 717, name: uvq, pl: Python, repositories: 18
# id: 718, name: aegis_cipher, pl: C++, repositories: 4
# id: 719, name: consent-based-conversion-adjustments, pl: Python, repositories: 8
# id: 720, name: containerdbg, pl: C, repositories: 6
# id: 721, name: Stereoscopic-Video-Generation-via-Denoising-Frame-Matrix, pl: Python, repositories: 4
# id: 722, name: iopddl, pl: C++, repositories: 2
# id: 723, name: badwolf-drivers, pl: Go, repositories: 7
# id: 724, name: project-euphonia-app, pl: Dart, repositories: 12
# id: 725, name: badwolf, pl: Go, repositories: 66
# id: 726, name: fruit, pl: C++, repositories: 203
# id: 727, name: sa360-bigquery-bootstrapper, pl: Python, repositories: 4
# id: 728, name: gemma-unity-plugin, pl: C#, repositories: 7
# id: 729, name: gemma-journey, pl: C#, repositories: 2
# id: 730, name: feabench, pl: Python, repositories: 3
# id: 731, name: hashr, pl: Go, repositories: 7
# id: 732, name: regexpand, pl: Go, repositories: 2
# id: 733, name: myelin-acorn-electron-hardware, pl: Python, repositories: 20
# id: 734, name: vscode-vnc, pl: TypeScript, repositories: 2
# id: 735, name: pica, pl: Python, repositories: 12
# id: 736, name: strangemeadowlark, pl: Rust, repositories: 1
# id: 737, name: note-maps, pl: Go, repositories: 18
# id: 738, name: curie, pl: Jupyter Notebook, repositories: 3
# id: 739, name: mobly-cros, pl: Python, repositories: 2
# id: 740, name: go-tika, pl: Go, repositories: 41
# id: 741, name: textfsm, pl: Python, repositories: 187
# id: 742, name: sherlock, pl: Python, repositories: 1
# id: 743, name: go-tspi, pl: Go, repositories: 22
# id: 744, name: kernel-sanitizers, pl: Python, repositories: 90
# id: 745, name: file-header, pl: Rust, repositories: 3
# id: 746, name: extra-keyboards-for-chrome-os, pl: JavaScript, repositories: 130
# id: 747, name: libprotobuf-mutator, pl: C++, repositories: 127
# id: 748, name: crc32c, pl: C++, repositories: 149
# id: 749, name: codeworld, pl: Haskell, repositories: 199
# id: 750, name: smali, pl: Java, repositories: 54
# id: 751, name: android-riscv64, pl: N/A, repositories: 15
# id: 752, name: unisim, pl: Python, repositories: 9
# id: 753, name: ml-metadata, pl: C++, repositories: 171
# id: 754, name: kmsan, pl: C, repositories: 64
# id: 755, name: play-asset-delivery-unity, pl: C#, repositories: 3
# id: 756, name: play-appbundle-unity, pl: C#, repositories: 2
# id: 757, name: file-based-test-driver, pl: C++, repositories: 3
# id: 758, name: oauth2l, pl: Go, repositories: 85
# id: 759, name: ads-privacy, pl: N/A, repositories: 136
# id: 760, name: trusted-types-helper, pl: TypeScript, repositories: 1
# id: 761, name: search-in-apps, pl: Swift, repositories: 0
# id: 762, name: eslint-config-google, pl: JavaScript, repositories: 137
# id: 763, name: go-replayers, pl: Go, repositories: 38
# id: 764, name: uVkCompute, pl: C++, repositories: 42
# id: 765, name: dfdewey, pl: Python, repositories: 7
# id: 766, name: CFU-Playground, pl: Verilog, repositories: 148
# id: 767, name: sqlcommenter, pl: PHP, repositories: 84
# id: 768, name: picatrix, pl: Python, repositories: 17
# id: 769, name: shadertrap, pl: C++, repositories: 10
# id: 770, name: lldb-eval, pl: C++, repositories: 19
# id: 771, name: pasta, pl: Python, repositories: 39
# id: 772, name: LogicLM, pl: HTML, repositories: 2
# id: 773, name: wuffs-mirror-release-c, pl: C, repositories: 21
# id: 774, name: image_mix, pl: Python, repositories: 0
# id: 775, name: page-alloc-bench, pl: Go, repositories: 0
# id: 776, name: grizzly, pl: Python, repositories: 11
# id: 777, name: tf-quant-finance, pl: Python, repositories: 650
# id: 778, name: coding-with-chrome, pl: JavaScript, repositories: 169
# id: 779, name: html-to-jsonld-converter, pl: Python, repositories: 1
# id: 780, name: gopacket, pl: Go, repositories: 1100
# id: 781, name: RB-Modulation, pl: Jupyter Notebook, repositories: 28
# id: 782, name: briolette, pl: Rust, repositories: 13
# id: 783, name: bbr, pl: N/A, repositories: 681
# id: 784, name: py-lab-hal, pl: Python, repositories: 6
# id: 785, name: bsynth, pl: C++, repositories: 7
# id: 786, name: .github, pl: N/A, repositories: 347
# id: 787, name: snowflake-to-bq-data-transfer-tool, pl: Java, repositories: 1
# id: 788, name: password-alert, pl: JavaScript, repositories: 102
# id: 789, name: moodle-on-gcp, pl: Shell, repositories: 24
# id: 790, name: glance-experimental-tools, pl: Kotlin, repositories: 11
# id: 791, name: myanmar-tools, pl: Java, repositories: 85
# id: 792, name: k8s-digester, pl: Go, repositories: 21
# id: 793, name: splice, pl: Go, repositories: 24
# id: 794, name: cc-device-plugin, pl: Go, repositories: 3
# id: 795, name: project-OCEAN, pl: Python, repositories: 19
# id: 796, name: git-pull-request-mirror, pl: Go, repositories: 13
# id: 797, name: weasel, pl: Go, repositories: 19
# id: 798, name: parse-ego4d, pl: Jupyter Notebook, repositories: 2
# id: 799, name: deepconsensus, pl: Python, repositories: 38
# id: 800, name: deeppolisher, pl: Jupyter Notebook, repositories: 7
# id: 801, name: makerspace-auth, pl: Python, repositories: 29
# id: 802, name: material-design-lite, pl: HTML, repositories: 5000
# id: 803, name: patrick, pl: R, repositories: 17
# id: 804, name: xr-objects, pl: C#, repositories: 20
# id: 805, name: dlc-insight-lab, pl: JavaScript, repositories: 1
# id: 806, name: j2cl-protobuf, pl: JavaScript, repositories: 10
# id: 807, name: yarsa, pl: Go, repositories: 0
# id: 808, name: googlesre, pl: TypeScript, repositories: 31
# id: 809, name: android-auto-companion-android, pl: Kotlin, repositories: 8
# id: 810, name: automl, pl: Jupyter Notebook, repositories: 1500
# id: 811, name: gdb_gcore_point, pl: Python, repositories: 1
# id: 812, name: serde_json5, pl: Rust, repositories: 16
# id: 813, name: emoji-scavenger-hunt, pl: TypeScript, repositories: 200
# id: 814, name: android-auto-companion-ios, pl: Swift, repositories: 7
# id: 815, name: library-wrapper-unity-common, pl: C#, repositories: 1
# id: 816, name: lottie-tools, pl: Rust, repositories: 2
# id: 817, name: speedy, pl: C++, repositories: 8
# id: 818, name: pebble, pl: C, repositories: 379
# id: 819, name: volley, pl: Java, repositories: 756
# id: 820, name: open-sztp, pl: Go, repositories: 2
# id: 821, name: pyu2f, pl: Python, repositories: 27
# id: 822, name: biva, pl: C++, repositories: 1
# id: 823, name: marl, pl: C++, repositories: 197
# id: 824, name: cppdap, pl: C++, repositories: 63
# id: 825, name: uem_poc, pl: TypeScript, repositories: 0
# id: 826, name: new-project, pl: N/A, repositories: 163
# id: 827, name: go-cmp, pl: Go, repositories: 218
# id: 828, name: mlir-hs, pl: Haskell, repositories: 17
# id: 829, name: webrisk, pl: Go, repositories: 40
# id: 830, name: csp-evaluator, pl: TypeScript, repositories: 50
# id: 831, name: multichannel-audio-tools, pl: C++, repositories: 36
# id: 832, name: pprof-nodejs, pl: JavaScript, repositories: 31
# id: 833, name: hctr2, pl: C, repositories: 2
# id: 834, name: santa-tracker-web, pl: JavaScript, repositories: 158
# id: 835, name: jira-to-issues, pl: TypeScript, repositories: 4
# id: 836, name: best, pl: Rust, repositories: 13
# id: 837, name: alu-api, pl: Jupyter Notebook, repositories: 1
# id: 838, name: haskell-indexer, pl: Haskell, repositories: 20
# id: 839, name: latexify_py, pl: Python, repositories: 397
# id: 840, name: abseil-cpp-binary, pl: Swift, repositories: 5
# id: 841, name: fuzzbench, pl: Python, repositories: 287
# id: 842, name: jarjar, pl: Java, repositories: 31
# id: 843, name: xdtk, pl: Java, repositories: 3
# id: 844, name: play-integrity-unity, pl: C#, repositories: 2
# id: 845, name: play-in-app-reviews-unity, pl: C#, repositories: 1
# ...
# id: 2543, name: chkstream, pl: Python, repositories: 10
# id: 2544, name: glmmplus, pl: R, repositories: 7
# id: 2545, name: codeu_coding_assessment_2017, pl: Java, repositories: 100
# id: 2546, name: address-geocoder-js, pl: HTML, repositories: 9
# id: 2547, name: classp, pl: Bison, repositories: 14
# id: 2548, name: xmpmeta, pl: C++, repositories: 11
# id: 2549, name: depth_fusion, pl: C++, repositories: 6
# id: 2550, name: amp-pwa-demo, pl: JavaScript, repositories: 33
# id: 2551, name: Zhi, pl: Python, repositories: 14
# id: 2552, name: agata, pl: JavaScript, repositories: 7
# id: 2553, name: prerender-test, pl: JavaScript, repositories: 11
# id: 2554, name: audit-normalmap, pl: C, repositories: 10
# id: 2555, name: varstruct, pl: C++, repositories: 15
# id: 2556, name: emre, pl: C++, repositories: 5
# id: 2557, name: simple-reinforcement-learning, pl: Python, repositories: 30
# id: 2558, name: homebrew-google-authenticator, pl: Ruby, repositories: 15
# id: 2559, name: request-test, pl: Python, repositories: 5
# id: 2560, name: blockly-repo, pl: N/A, repositories: 5
# id: 2561, name: pindrop, pl: C++, repositories: 27
# id: 2562, name: goldfinch, pl: N/A, repositories: 17
# id: 2563, name: scene_lab, pl: C++, repositories: 21
# id: 2564, name: corgi, pl: C++, repositories: 32
# id: 2565, name: dropzone-polyfill, pl: HTML, repositories: 5
# id: 2566, name: ot-crdt-papers, pl: JavaScript, repositories: 26
# id: 2567, name: windowtester, pl: Java, repositories: 19
# id: 2568, name: fpc, pl: C, repositories: 5
# id: 2569, name: fchan-go, pl: Go, repositories: 23
# id: 2570, name: xdelta3-decoder-js, pl: C, repositories: 10
# id: 2571, name: appengine-phabricator, pl: Shell, repositories: 15
# id: 2572, name: cpp-frp, pl: C++, repositories: 19
# id: 2573, name: yang_vocoder, pl: MATLAB, repositories: 26
# id: 2574, name: keystone, pl: Elm, repositories: 7
# id: 2575, name: adapt-googleanalytics, pl: JavaScript, repositories: 6
# id: 2576, name: deepboost, pl: C++, repositories: 53
# id: 2577, name: mcic-coco, pl: N/A, repositories: 13
# id: 2578, name: readahead, pl: Go, repositories: 13
# id: 2579, name: source_transformer.dart, pl: Dart, repositories: 4
# id: 2580, name: mcafp, pl: Python, repositories: 17
# id: 2581, name: gtm-oauth, pl: Objective-C, repositories: 23
# id: 2582, name: morphie, pl: C++, repositories: 15
# id: 2583, name: libgep, pl: C++, repositories: 19
# id: 2584, name: smilesparser, pl: Python, repositories: 11
# id: 2585, name: built_json.dart, pl: N/A, repositories: 10
# id: 2586, name: conferenceDB, pl: HTML, repositories: 6
# id: 2587, name: indexable-pwa-samples, pl: JavaScript, repositories: 14
# id: 2588, name: enum_class.dart, pl: N/A, repositories: 7
# id: 2589, name: sass_generator, pl: N/A, repositories: 0
# id: 2590, name: vpn-reverse-tether, pl: C, repositories: 61
# id: 2591, name: protocall, pl: Python, repositories: 6
# id: 2592, name: transliteration, pl: N/A, repositories: 31
# id: 2593, name: power-traces, pl: Protocol Buffer, repositories: 12
# id: 2594, name: indexed-db-as-promised, pl: JavaScript, repositories: 4
# id: 2595, name: gotrace, pl: N/A, repositories: 0
# id: 2596, name: cameraraw, pl: Go, repositories: 13
# id: 2597, name: everythingisconnected, pl: JavaScript, repositories: 5
# id: 2598, name: libkml, pl: C++, repositories: 55
# id: 2599, name: geovelo, pl: JavaScript, repositories: 24
# id: 2600, name: gfw-toolkit, pl: Python, repositories: 21
# id: 2601, name: googleapps-message-recall, pl: Python, repositories: 19
# id: 2602, name: macops-MOMenu, pl: Objective-C, repositories: 9
# id: 2603, name: dart2java, pl: Java, repositories: 14
# id: 2604, name: param_runner, pl: Shell, repositories: 8
# id: 2605, name: gde-speakersbureau, pl: JavaScript, repositories: 12
# id: 2606, name: AppUpdateTrackerLib, pl: Java, repositories: 12
# id: 2607, name: rustcxx, pl: Rust, repositories: 22
# id: 2608, name: dualhttp, pl: JavaScript, repositories: 11
# id: 2609, name: go-webdav, pl: Go, repositories: 19
# id: 2610, name: dorusu-js, pl: JavaScript, repositories: 15
# id: 2611, name: identity-toolkit-go-client, pl: Go, repositories: 24
# id: 2612, name: dynamex-proto, pl: Protocol Buffer, repositories: 11
# id: 2613, name: auto-common, pl: N/A, repositories: 0
# id: 2614, name: auto-service, pl: N/A, repositories: 0
# id: 2615, name: auto-factory, pl: N/A, repositories: 0
# id: 2616, name: prudaq, pl: Eagle, repositories: 32
# id: 2617, name: realtime-help, pl: Python, repositories: 17
# id: 2618, name: pepper.js, pl: JavaScript, repositories: 53
# id: 2619, name: instant-hangouts, pl: JavaScript, repositories: 49
# id: 2620, name: LiquidFunPaint, pl: Java, repositories: 54
# id: 2621, name: easy-gwt-mock, pl: Java, repositories: 6
# id: 2622, name: gofountain, pl: Go, repositories: 16
# id: 2623, name: VoltAir, pl: C++, repositories: 83
# id: 2624, name: bzip2-rpc, pl: C, repositories: 9
# id: 2625, name: gipfeli, pl: C++, repositories: 26
# id: 2626, name: go-circuits, pl: Go, repositories: 10
# id: 2627, name: rpki-mgmt, pl: Puppet, repositories: 12
# id: 2628, name: simplecfg, pl: Java, repositories: 8
# id: 2629, name: maketrace, pl: C++, repositories: 15
# id: 2630, name: Chrome.Docs, pl: JavaScript, repositories: 9
# id: 2631, name: bluesky-watchface, pl: C, repositories: 4
# id: 2632, name: slowfs, pl: Go, repositories: 10
# id: 2633, name: arc-jazzy-linter, pl: PHP, repositories: 4
# id: 2634, name: merge_pyi, pl: Python, repositories: 12
# id: 2635, name: drone-firebase, pl: Go, repositories: 12
# id: 2636, name: cncmicroscope-cad, pl: OpenSCAD, repositories: 8
# id: 2637, name: access-bridge-explorer, pl: C#, repositories: 57
# id: 2638, name: gitwf, pl: N/A, repositories: 0
# id: 2639, name: arc-proselint, pl: PHP, repositories: 11
# id: 2640, name: channel-id-enclave, pl: N/A, repositories: 10
# id: 2641, name: generator-goro, pl: JavaScript, repositories: 14
# id: 2642, name: xpaf, pl: C++, repositories: 54
# id: 2643, name: google-empty-test-module, pl: N/A, repositories: 0
# id: 2644, name: cloud-reporting, pl: Java, repositories: 6
# id: 2645, name: reagera, pl: Java, repositories: 8
# id: 2646, name: py-decorators-tutorial, pl: Jupyter Notebook, repositories: 11
# id: 2647, name: identity-toolkit-node-client, pl: JavaScript, repositories: 16
# id: 2648, name: GOS-conventions, pl: Shell, repositories: 10
# id: 2649, name: identity-toolkit-java-client, pl: Java, repositories: 27
# id: 2650, name: jalic, pl: C, repositories: 10
# id: 2651, name: arc-regex-line-length-linter, pl: PHP, repositories: 8
# id: 2652, name: identity-toolkit-ruby-client, pl: Ruby, repositories: 9
# id: 2653, name: file-system-stress-testing, pl: C, repositories: 21
# id: 2654, name: linux-sensor, pl: C, repositories: 10
# id: 2655, name: multibox, pl: N/A, repositories: 95
# id: 2656, name: offline-content-packager, pl: N/A, repositories: 20
# id: 2657, name: crush-tools, pl: Shell, repositories: 21
# id: 2658, name: flutter-data, pl: Dart, repositories: 9
# id: 2659, name: resolver-library, pl: Python, repositories: 10
# id: 2660, name: hops, pl: C++, repositories: 12
# id: 2661, name: kythe-cloud9, pl: JavaScript, repositories: 3
# id: 2662, name: physical-web-core, pl: N/A, repositories: 0
# id: 2663, name: flooefi, pl: N/A, repositories: 0
# id: 2664, name: serialization.dart, pl: Dart, repositories: 14
# id: 2665, name: templatekit, pl: Objective-C, repositories: 9
# id: 2666, name: metrosvg, pl: C++, repositories: 12
# id: 2667, name: paramgmt, pl: Python, repositories: 29
# id: 2668, name: pienoon, pl: C++, repositories: 112
# id: 2669, name: translation-cards, pl: Java, repositories: 11
# id: 2670, name: topdown-btg-preordering, pl: C++, repositories: 10
# id: 2671, name: openpgp-interop, pl: N/A, repositories: 6
# id: 2672, name: appengine-codiad, pl: JavaScript, repositories: 30
# id: 2673, name: godata, pl: Go, repositories: 14
# id: 2674, name: opentest4j, pl: Java, repositories: 39
# id: 2675, name: identity-toolkit-php-client, pl: PHP, repositories: 22
# id: 2676, name: google-maven-parents, pl: N/A, repositories: 4
# id: 2677, name: identity-toolkit-python-client, pl: Python, repositories: 21
# id: 2678, name: Refaster, pl: Java, repositories: 18
# id: 2679, name: strabo, pl: Elixir, repositories: 13
# id: 2680, name: http2preload, pl: Go, repositories: 9
# id: 2681, name: checkers_classic, pl: Python, repositories: 12
# id: 2682, name: node-nest, pl: JavaScript, repositories: 12
# id: 2683, name: intellij-cmdline-vcs-plugin, pl: Java, repositories: 4
# id: 2684, name: docopt-scripts, pl: Go, repositories: 10
# id: 2685, name: xpra-upstart, pl: N/A, repositories: 10
# id: 2686, name: steamkeysactivator, pl: AppleScript, repositories: 18
# id: 2687, name: homebrew-xpra, pl: Ruby, repositories: 10
# id: 2688, name: shipshape-demo, pl: Python, repositories: 9
# id: 2689, name: hashing-demo, pl: C++, repositories: 12
# id: 2690, name: autopiper, pl: C++, repositories: 11
# id: 2691, name: inception, pl: N/A, repositories: 170
# id: 2692, name: clang-lens, pl: Haskell, repositories: 9
# id: 2693, name: crisis-info-hub, pl: JavaScript, repositories: 16
# id: 2694, name: dart-immutables, pl: Dart, repositories: 8
# id: 2695, name: streamhtmlparser, pl: C, repositories: 10
# id: 2696, name: pods-helper, pl: Objective-C, repositories: 10
# id: 2697, name: cluster-insight, pl: Python, repositories: 24
# id: 2698, name: freebase-wikidata-converter, pl: PHP, repositories: 27
# id: 2699, name: snappy-start, pl: C, repositories: 23
# id: 2700, name: capsicum-man-pages, pl: Groff, repositories: 3
# id: 2701, name: rust-multihash, pl: Rust, repositories: 10
# id: 2702, name: organ-donor-app, pl: N/A, repositories: 0
# id: 2703, name: trace-viewer, pl: N/A, repositories: 77
# id: 2704, name: rowhammer-test, pl: C++, repositories: 200
# id: 2705, name: ferret, pl: Java, repositories: 15
# id: 2706, name: module-server, pl: JavaScript, repositories: 44
# id: 2707, name: autoparse, pl: Ruby, repositories: 33
# id: 2708, name: android-studio-check, pl: Java, repositories: 11
# id: 2709, name: chromeos-filesystems, pl: JavaScript, repositories: 25
# id: 2710, name: gojiraw, pl: Go, repositories: 9
# id: 2711, name: terminal-py, pl: Python, repositories: 5
# id: 2712, name: lmctfy, pl: C++, repositories: 240
# id: 2713, name: dart-shapeshift, pl: Dart, repositories: 8
# id: 2714, name: calenviroscreen, pl: R, repositories: 5
# id: 2715, name: cncmicroscope-code, pl: C++, repositories: 10
# id: 2716, name: o3dtoydefense, pl: JavaScript, repositories: 9
# id: 2717, name: epr, pl: JavaScript, repositories: 12
# id: 2718, name: codename-mvsv, pl: JavaScript, repositories: 10
# id: 2719, name: io-captions-gadget, pl: Python, repositories: 9
# id: 2720, name: ytstatistics-demo, pl: Java, repositories: 11
# id: 2721, name: sensei, pl: C++, repositories: 16
# id: 2722, name: comid, pl: Dart, repositories: 18
# id: 2723, name: service_worker.dart, pl: Dart, repositories: 10
# id: 2724, name: google-visualization-issues, pl: N/A, repositories: 35
# id: 2725, name: dart-doc_coverage, pl: Dart, repositories: 12
# id: 2726, name: voter-info-tool, pl: JavaScript, repositories: 10
# id: 2727, name: chrome-language-immersion, pl: JavaScript, repositories: 19
# id: 2728, name: coursebuilder_xblock_module, pl: Python, repositories: 12
# id: 2729, name: py-html-contextual-escaping, pl: Python, repositories: 9
# id: 2730, name: json-sans-eval, pl: HTML, repositories: 11
# id: 2731, name: mysql-tools, pl: Python, repositories: 78
# id: 2732, name: refr, pl: C++, repositories: 9
# id: 2733, name: coursebuilder-hello-world-module, pl: Python, repositories: 5
# id: 2734, name: dart-emacs-plugin-unsupported, pl: Emacs Lisp, repositories: 11
# id: 2735, name: older-mirrored-patches, pl: N/A, repositories: 10
# id: 2736, name: objectfilter, pl: Python, repositories: 10
# id: 2737, name: retrofit, pl: Java, repositories: 7300
# id: 2738, name: nfc-smart-tag, pl: Java, repositories: 6
# id: 2739, name: irrduino, pl: Processing, repositories: 13
# id: 2740, name: reportlatency, pl: Perl, repositories: 8
# id: 2741, name: gmailsnooze, pl: JavaScript, repositories: 7
# id: 2742, name: deliberate, pl: N/A, repositories: 0
# id: 2743, name: network-visualizer-x, pl: N/A, repositories: 0
# id: 2744, name: reboot-somalia, pl: N/A, repositories: 0
# id: 2745, name: citizen-x, pl: N/A, repositories: 0
# id: 2746, name: pytypedecl, pl: Python, repositories: 17
# id: 2747, name: rysim, pl: Erlang, repositories: 14
# id: 2748, name: jsontoken-tmp, pl: N/A, repositories: 0
# id: 2749, name: go-shlex, pl: N/A, repositories: 0
# id: 2750, name: zarathustra, pl: Java, repositories: 13
# id: 2751, name: pull-request-mailer, pl: Haskell, repositories: 9
# id: 2752, name: elfling, pl: C++, repositories: 12
# id: 2753, name: vim-ft-vroom, pl: Vim Script, repositories: 8
# id: 2754, name: picview-for-android, pl: Java, repositories: 33
# id: 2755, name: picasa-app-demo, pl: Java, repositories: 14
# id: 2756, name: web-starter-kit-extras, pl: N/A, repositories: 29
# id: 2757, name: simple-pedometer, pl: Java, repositories: 48
# id: 2758, name: sensor-data-collection-library, pl: Java, repositories: 21
# id: 2759, name: ashier, pl: Python, repositories: 15
# id: 2760, name: coursebuilder-lti-module, pl: Python, repositories: 5
# id: 2761, name: episodes.dart, pl: Dart, repositories: 26
# id: 2762, name: polymer-dart-log-controller, pl: Dart, repositories: 16
# id: 2763, name: ebola-tools, pl: Python, repositories: 9
# id: 2764, name: pubsubhubbub, pl: N/A, repositories: 0
# id: 2765, name: dart-tagtree, pl: Dart, repositories: 14
# id: 2766, name: turing-doodle, pl: JavaScript, repositories: 68
# id: 2767, name: linear-book-scanner, pl: Python, repositories: 25
# id: 2768, name: java-thread-sanitizer, pl: Java, repositories: 25
# id: 2769, name: gin, pl: N/A, repositories: 0
# id: 2770, name: go-glicko2, pl: N/A, repositories: 0
# id: 2771, name: rct-automation, pl: C++, repositories: 15
# id: 2772, name: Idris-dev, pl: Haskell, repositories: 633
# id: 2773, name: forcefield, pl: Gosu, repositories: 18
# id: 2774, name: dart-gif-encoder, pl: Dart, repositories: 13
# id: 2775, name: glassbox, pl: R, repositories: 10
# id: 2776, name: coursebuilder-learning-analytics, pl: N/A, repositories: 0
# id: 2777, name: NLSdata, pl: R, repositories: 8
# id: 2778, name: jenkins-flaky-test-report, pl: N/A, repositories: 0
# id: 2779, name: build-debian-cloud, pl: Python, repositories: 117
# id: 2780, name: dart-collab, pl: Dart, repositories: 9
# id: 2781, name: wheelbarrow, pl: Python, repositories: 14
# id: 2782, name: photo-sphere, pl: N/A, repositories: 0
# id: 2783, name: oss-bench, pl: N/A, repositories: 5
# id: 2784, name: heartbleed-burp-extension, pl: Java, repositories: 13
# id: 2785, name: lab_device_proxy, pl: Python, repositories: 8
# id: 2786, name: gdal-autotest2, pl: N/A, repositories: 0
# id: 2787, name: patchfield, pl: Java, repositories: 43
# id: 2788, name: googleapps-password-generator, pl: N/A, repositories: 30
# id: 2789, name: YouCompleteSubl, pl: N/A, repositories: 0
# id: 2790, name: favcolor-findidp, pl: N/A, repositories: 10
# id: 2791, name: appengine_xblock_runtime, pl: Python, repositories: 16
# id: 2792, name: memcache-collections, pl: Python, repositories: 21
# id: 2793, name: course-builder, pl: N/A, repositories: 0
# id: 2794, name: favcolor-android, pl: Java, repositories: 22
# id: 2795, name: systemjs, pl: JavaScript, repositories: 20
# id: 2796, name: favcolor-ios, pl: N/A, repositories: 0
# id: 2797, name: pixelcycle-sample-app, pl: Dart, repositories: 14
# id: 2798, name: container-rfc, pl: N/A, repositories: 23
# id: 2799, name: gae-channel-api.dart, pl: Dart, repositories: 17
# id: 2800, name: ChannelPlate, pl: JavaScript, repositories: 18
# id: 2801, name: testRunner, pl: JavaScript, repositories: 9
# id: 2802, name: devtoolsExtended, pl: JavaScript, repositories: 22
# id: 2803, name: self-hosted-rss-to-email, pl: Go, repositories: 9
# id: 2804, name: zimu, pl: C, repositories: 5
# id: 2805, name: tsviewdb, pl: JavaScript, repositories: 21
# id: 2806, name: beta-binomial-fitting, pl: N/A, repositories: 0
# id: 2807, name: wiberg-minimization, pl: N/A, repositories: 10
# id: 2808, name: crx2app, pl: JavaScript, repositories: 15
# id: 2809, name: concatenate.js, pl: JavaScript, repositories: 18
# id: 2810, name: firmata.py, pl: Python, repositories: 16
# id: 2811, name: sirius, pl: N/A, repositories: 0
