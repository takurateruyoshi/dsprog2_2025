# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import time

# %%
path = ''
db_name = 'github_google.db'

try:
    #DBへのコネクションを確立
    conn = sqlite3.connect(path + db_name)

    #SQL(ROBを操作するための言語)を実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # SQL文の作成
    # テーブルの作成
    sql = "CREATE TABLE cars (id INTEGER PRIMARY KEY AUTOINCREMENT, name TEXT, pl TEXT, star INTEGER);"

    # SQL文の実行
    cur.execute(sql)

    conn.commit()  # 変更を保存

except sqlite3.Error as e:
    print('SQLite error:', e)
    
finally:
    # DBへの接続を閉じる
    conn.close()

# %%
page_now = 1

# %%
# https://github.com/orgs/google/repositories?page=1  ---  リポジトリ一覧ページのURL
repositories = []

for page in range(page_now, 95):
    time.sleep(1)
    url = f"https://github.com/orgs/google/repositories?page={page}"
    print(f"ページ{page}: {url}")
    try:
        res = requests.get(url)

        #200以外の接続を弾く
        res.raise_for_status()
        
        soup = BeautifulSoup(res.text, 'html.parser')

        selsectors = soup.find_all(class_ = "ListItem-module__listItem--k4eMk")
        print(f"ページ{page}のセクター数: {len(selsectors)}")
        for selsector in selsectors:

            # リポジトリ名、プログラミング言語、スター数を取得し改行を削除して文字に変換
            name = selsector.find(class_ = "Title-module__anchor--GmXUE Title-module__inline--oM0P7")
            name = name.text.strip() if name else "N/A"
            pl = selsector.find(class_ = "ReposListItem-module__Text_4--mkG7R")
            pl = pl.text.strip() if pl else "N/A"
            star = selsector.find(class_ = "ReposListItem-module__Link_1--v5NDF prc-Link-Link-85e08")
            star = star.text.strip() if star else "0"

            # スター数の文字列を整数に変換
            if star[-1] == "k":
                star = int(float(star[:-1]) * 1000)
            else:
                star = int(star)

            #取得したデータをリポジトリリストに追加
            print(f"name:{name} pl:{pl} star:{star}")
            repositories.append((name, pl, star))
            
    except requests.RequestException as e:
        print(f"Error fetching page {page}: {e}")
        print("次回はこのページから再開します")
        page_now = page
        break
# Out:
# ページ1: https://github.com/orgs/google/repositories?page=1
# ページ1のセクター数: 30
# name:adk-java pl:Java star:197
# name:perfetto pl:C++ star:619
# name:clusterfuzz pl:Python star:592
# name:conscrypt pl:Java star:310
# name:or-tools pl:C++ star:2300
# name:workflow-graph pl:TypeScript star:27
# name:dagger pl:Java star:3100
# name:nearby pl:C++ star:185
# name:crubit pl:C++ star:54
# name:osv-scalibr pl:Go star:90
# name:heir pl:C++ star:106
# name:site-kit-wp pl:JavaScript star:326
# name:oss-fuzz pl:Shell star:2500
# name:horologist pl:Kotlin star:109
# name:dawn pl:C++ star:136
# name:xls pl:C++ star:217
# name:adk-samples pl:Python star:1900
# name:nomulus pl:Java star:295
# name:orbax pl:Python star:71
# name:earthengine-catalog pl:Jsonnet star:92
# name:open-dice pl:C++ star:9
# name:yggdrasil-decision-forests pl:C++ star:70
# name:device-infra pl:Java star:23
# name:gemma.cpp pl:C++ star:573
# name:ground-android pl:Kotlin star:138
# name:koladata pl:C++ star:14
# name:j2cl pl:Java star:153
# name:garf pl:Python star:3
# name:highway pl:C++ star:387
# name:googletest-rust pl:Rust star:27
# ページ2: https://github.com/orgs/google/repositories?page=2
# ページ2のセクター数: 30
# name:testrun pl:Python star:16
# name:error-prone pl:Java star:773
# name:skia pl:C++ star:1600
# name:skia-buildbot pl:Go star:79
# name:flax pl:Jupyter Notebook star:757
# name:android-beat pl:N/A star:0
# name:angle pl:C++ star:687
# name:fonts pl:HTML star:2800
# name:brotli pl:TypeScript star:1300
# name:cel-java pl:Java star:28
# name:bumble pl:Python star:105
# name:merchant-api-samples pl:Java star:5
# name:adk-python pl:Python star:2400
# name:docsy pl:JavaScript star:953
# name:llvm-propeller pl:C++ star:45
# name:libphonenumber pl:C++ star:2100
# name:syzkaller pl:Go star:1300
# name:gwpsan pl:C++ star:10
# name:nftables pl:Go star:161
# name:wasefire pl:Rust star:27
# name:crosvm pl:Rust star:130
# name:filament pl:C++ star:2100
# name:filonov pl:Python star:1
# name:adk-go pl:Go star:251
# name:boringssl pl:C++ star:851
# name:tsl pl:C++ star:28
# name:meridian pl:Python star:208
# name:grain pl:Python star:56
# name:dotprompt pl:Python star:39
# name:langfun pl:Python star:69
# ページ3: https://github.com/orgs/google/repositories?page=3
# ページ3のセクター数: 30
# name:tunix pl:Python star:172
# name:osv-scanner pl:Go star:481
# name:mug pl:Java star:75
# name:quiche pl:C++ star:160
# name:osv.dev pl:Python star:251
# name:adk-docs pl:HTML star:636
# name:langextract pl:Python star:1200
# name:ecclesia-machine-management pl:C++ star:4
# name:earthengine-community pl:Jupyter Notebook star:866
# name:jetpack-camera-app pl:Kotlin star:49
# name:earthengine-api pl:JavaScript star:1100
# name:clasp pl:TypeScript star:477
# name:android-cuttlefish pl:C++ star:175
# name:guava pl:Java star:11000
# name:embardiment pl:C# star:1
# name:go-tdx-guest pl:Go star:28
# name:bloaty pl:C++ star:365
# name:gvisor pl:Go star:1500
# name:googleapis.dart pl:Dart star:126
# name:qwix pl:Python star:5
# name:XNNPACK pl:C star:450
# name:chromium-policy-vulnfeed pl:Go star:6
# name:zerocopy pl:Rust star:131
# name:openhtf pl:Python star:221
# name:civics_cdf_validator pl:Python star:22
# name:github_workflows_playground pl:N/A star:1
# name:eclipsa-audio-plugin pl:C++ star:8
# name:ml-metrics pl:Python star:4
# name:oss-rebuild pl:Go star:39
# name:adk-web pl:TypeScript star:158
# ページ4: https://github.com/orgs/google/repositories?page=4
# ページ4のセクター数: 30
# name:tensorstore pl:C++ star:133
# name:gce-tcb-verifier pl:Go star:3
# name:tcmalloc pl:C++ star:530
# name:closure-templates pl:Java star:193
# name:go-units pl:Go star:2
# name:torchax pl:Python star:14
# name:github-team pl:Shell star:1
# name:secure-aggregation pl:Rust star:2
# name:fhir-gateway pl:Java star:34
# name:fuzztest pl:C++ star:114
# name:pyglove pl:Python star:33
# name:shaderc pl:C++ star:408
# name:ink pl:C++ star:12
# name:fhir-data-pipes pl:Jupyter Notebook star:118
# name:cel-go pl:Go star:251
# name:arolla pl:C++ star:14
# name:dive pl:C++ star:10
# name:go-github pl:Go star:2200
# name:inverting-proxy pl:Go star:80
# name:copybara pl:Java star:291
# name:minijail pl:C star:36
# name:xrblocks pl:TypeScript star:14
# name:assertor pl:Rust star:15
# name:closure-compiler pl:JavaScript star:1200
# name:android-fhir pl:Kotlin star:317
# name:ChromeBrowserEnterprise pl:C# star:53
# name:mcp-security pl:Python star:81
# name:fleetbench pl:C++ star:15
# name:travel-impact-model-website pl:TypeScript star:3
# name:learned_optimization pl:Python star:68
# ページ5: https://github.com/orgs/google/repositories?page=5
# ページ5のセクター数: 30
# name:gfxstream pl:C++ star:11
# name:rpmpack pl:Go star:32
# name:kotlin-fhirpath pl:Kotlin star:1
# name:cctz pl:C++ star:173
# name:dwh-migration-tools pl:Java star:63
# name:weather-tools pl:Python star:45
# name:go-querystring pl:Go star:183
# name:schema-dts pl:TypeScript star:46
# name:oss-fuzz-vulns pl:Python star:46
# name:foteli pl:C++ star:1
# name:protobuf.dart pl:Dart star:197
# name:security-research pl:C star:502
# name:benchmark pl:C++ star:1700
# name:aoss-verifier pl:Go star:4
# name:sedpack pl:Python star:8
# name:mdbook-i18n-helpers pl:Rust star:36
# name:zx pl:JavaScript star:1200
# name:tabuli pl:C++ star:7
# name:timesketch pl:Python star:634
# name:s2geometry pl:C++ star:337
# name:gurl pl:N/A star:0
# name:deps.dev pl:Go star:36
# name:tsec pl:TypeScript star:15
# name:budoux-extension pl:TypeScript star:8
# name:ground-platform pl:TypeScript star:98
# name:init2winit pl:Python star:10
# name:github-sandbox pl:N/A star:209
# name:dotguides pl:TypeScript star:1
# name:aarch64-esr-decoder pl:Rust star:19
# name:torq pl:Python star:1
# ページ6: https://github.com/orgs/google/repositories?page=6
# ページ6のセクター数: 30
# name:osdfir-infrastructure pl:Smarty star:18
# name:cel-cpp pl:C++ star:63
# name:github_nonpublic_api pl:Python star:9
# name:cel-spec pl:Starlark star:268
# name:libhoth pl:C star:26
# name:flatbuffers pl:C++ star:3400
# name:oss-fuzz-gen pl:Python star:202
# name:osv-scanner-action pl:Python star:24
# name:auto pl:Java star:1200
# name:xctestrunner pl:Python star:69
# name:digitalbuildings pl:Python star:159
# name:oracle-toolkit pl:Shell star:35
# name:clspv pl:LLVM star:100
# name:escapevelocity pl:Java star:10
# name:postcss-rename pl:TypeScript star:20
# name:Xee pl:Python star:38
# name:praxis pl:Python star:44
# name:transit pl:N/A star:206
# name:riegeli pl:C++ star:61
# name:swiftshader pl:C++ star:312
# name:osdemo pl:Rust star:1
# name:j2objc pl:Java star:993
# name:turbine pl:Java star:23
# name:differential-privacy pl:Go star:406
# name:caliper pl:Java star:108
# name:aidl-language pl:N/A star:4
# name:selinux-policy-languages pl:N/A star:2
# name:pdl-language pl:N/A star:2
# name:comprehensive-rust pl:Rust star:1900
# name:webcrypto.dart pl:Dart star:70
# ページ7: https://github.com/orgs/google/repositories?page=7
# ページ7のセクター数: 30
# name:budoux pl:Python star:38
# name:pytype pl:Python star:289
# name:paxml pl:Python star:70
# name:renameio pl:Go star:29
# name:seqio pl:Python star:60
# name:scaaml pl:Python star:54
# name:secops-wrapper pl:Python star:27
# name:google-toolbox-for-mac pl:Objective-C star:266
# name:gtm-session-fetcher pl:Objective-C star:164
# name:alioth pl:Rust star:21
# name:iwa-vscode-extension pl:TypeScript star:3
# name:mobly pl:Python star:203
# name:project-voice pl:TypeScript star:11
# name:json_serializable.dart pl:Dart star:435
# name:duet pl:Python star:16
# name:cro3 pl:Rust star:14
# name:automotive-design-compose pl:Rust star:32
# name:arb-editor pl:TypeScript star:7
# name:peoplemath pl:TypeScript star:39
# name:codeql-action pl:TypeScript star:420
# name:dfindexeddb pl:Python star:11
# name:sound-checker pl:Kotlin star:9
# name:traceviz pl:TypeScript star:0
# name:etils pl:Python star:25
# name:adk-python-community pl:Python star:17
# name:labs-prototypes pl:Jupyter Notebook star:22
# name:vector_math.dart pl:Dart star:88
# name:pprof pl:Go star:641
# name:rust-crate-audits pl:N/A star:12
# name:netkat pl:C++ star:3
# ページ8: https://github.com/orgs/google/repositories?page=8
# ページ8のセクター数: 30
# name:silifuzz pl:C++ star:31
# name:aarch64-rt pl:Rust star:7
# name:aside pl:TypeScript star:11
# name:privacy-sandbox-aggregation-service pl:Go star:14
# name:dart-neats pl:Dart star:89
# name:rbrotli-enc pl:Rust star:5
# name:ads-api-report-fetcher pl:TypeScript star:17
# name:guice pl:Java star:1700
# name:mobly-bundled-snippets pl:Java star:64
# name:go-sev-guest pl:Go star:28
# name:metrax pl:Python star:12
# name:nccl-plugin-gpudirect-tcpxo pl:C++ star:0
# name:across pl:HTML star:8
# name:magika pl:Python star:474
# name:sec-gemini pl:Svelte star:19
# name:symphony-gcp pl:Python star:1
# name:cameratrapai pl:Python star:43
# name:ml-compiler-opt pl:Python star:113
# name:adk-js pl:TypeScript star:12
# name:google-cloud-datastore-quadruple pl:M4 star:1
# name:styleguide pl:HTML star:13000
# name:array_record pl:C++ star:23
# name:mobly-android-screen-recorder pl:Python star:3
# name:android-security-lints pl:Kotlin star:11
# name:certificate-transparency-community-site pl:HTML star:68
# name:tsunami-security-scanner-plugins pl:Java star:212
# name:tsunami-security-scanner pl:Java star:920
# name:keep-sorted pl:Go star:26
# name:go-containerregistry pl:Go star:601
# name:docsy-example pl:HTML star:735
# ページ9: https://github.com/orgs/google/repositories?page=9
# ページ9のセクター数: 30
# name:perf_data_converter pl:C++ star:63
# name:android-emulator-hypervisor-driver pl:C star:256
# name:ads_oneshop pl:Python star:7
# name:pdl pl:Rust star:12
# name:EarlGrey pl:Objective-C star:739
# name:zetasql pl:C++ star:232
# name:myvibe pl:N/A star:1
# name:business_intelligence_group pl:Jupyter Notebook star:3
# name:mobly-bluetooth-ref-validation pl:Python star:3
# name:googletest pl:C++ star:11000
# name:oboe pl:C++ star:612
# name:cloud-android-orchestration pl:Go star:35
# name:jax-datetime pl:Python star:1
# name:compile-testing pl:Java star:124
# name:fhir-py pl:Python star:15
# name:product_video_ads pl:TypeScript star:25
# name:xplat pl:Java star:4
# name:go-tpm pl:Go star:171
# name:guava-beta-checker pl:Java star:19
# name:go-cloud pl:Go star:824
# name:dranet pl:Go star:25
# name:neuroglancer pl:TypeScript star:333
# name:google-authenticator-libpam pl:C star:302
# name:gutil pl:C++ star:4
# name:go-attestation pl:Go star:101
# name:spatial-media pl:Python star:455
# name:jimfs pl:Java star:283
# name:truth pl:Java star:267
# name:longfellow-zk pl:C++ star:79
# name:kernel-research pl:C++ star:8
# ページ10: https://github.com/orgs/google/repositories?page=10
# ページ10のセクター数: 30
# name:bindiff pl:Java star:205
# name:shifter pl:Go star:26
# name:cddlconv pl:TypeScript star:1
# name:coset pl:Rust star:22
# name:sbom-conformance pl:Go star:3
# name:brax pl:Jupyter Notebook star:316
# name:pullsheet pl:Go star:20
# name:starlark-go pl:Go star:228
# name:mozc pl:C++ star:437
# name:GoogleSignIn-iOS pl:Objective-C star:245
# name:rust_icu pl:Rust star:31
# name:jsonschema-go pl:Go star:17
# name:jsir pl:C++ star:9
# name:walt pl:Java star:76
# name:meterstick pl:Jupyter Notebook star:20
# name:cpu_features pl:C++ star:289
# name:binexport pl:C++ star:232
# name:ksp pl:Kotlin star:358
# name:kotlin-fhir pl:Kotlin star:11
# name:saxml pl:Python star:31
# name:ever pl:Jupyter Notebook star:3
# name:sso-offloading pl:TypeScript star:1
# name:kf pl:Go star:60
# name:vizier pl:Python star:108
# name:instrumentsToPprof pl:Go star:12
# name:mozc-devices pl:C++ star:174
# name:ml_collections pl:Python star:46
# name:graph-renderer pl:N/A star:0
# name:toucan pl:C++ star:2
# name:container-explorer pl:Go star:12
# ページ11: https://github.com/orgs/google/repositories?page=11
# ページ11のセクター数: 30
# name:googet pl:Go star:45
# name:aqt pl:Python star:30
# name:google-api-objectivec-client-for-rest pl:Objective-C star:337
# name:desugar_jdk_libs pl:Java star:31
# name:uncertainty-baselines pl:Python star:215
# name:bt-navi-tests pl:Python star:3
# name:capslock pl:Go star:39
# name:sentencepiece pl:C++ star:1300
# name:go-tpm-tools pl:C star:83
# name:jax-cfd pl:Jupyter Notebook star:132
# name:p4-infra pl:C++ star:2
# name:kotlin_convert pl:Kotlin star:2
# name:built_collection.dart pl:Dart star:52
# name:source_helper.dart pl:Dart star:6
# name:quiver-dart pl:Dart star:132
# name:pthreadpool pl:C++ star:148
# name:webkit_inspection_protocol.dart pl:Dart star:18
# name:semantic-locators pl:JavaScript star:13
# name:brotli-wheels pl:N/A star:10
# name:openintent pl:N/A star:5
# name:re2 pl:C++ star:1200
# name:bazel-common pl:Starlark star:44
# name:bughunters pl:N/A star:24
# name:filament-assets pl:Mathematica star:1
# name:xarray-beam pl:Python star:14
# name:fscrypt pl:Go star:104
# name:gsocguides pl:CSS star:174
# name:mpact-cheriot pl:C++ star:1
# name:glazier pl:Python star:92
# name:mpact-riscv pl:C++ star:6
# ページ12: https://github.com/orgs/google/repositories?page=12
# ページ12のセクター数: 30
# name:gson pl:Java star:4400
# name:tfp-causalimpact pl:Python star:16
# name:fscryptctl pl:C star:37
# name:capirca pl:Python star:210
# name:imt pl:C++ star:3
# name:trillian pl:Go star:418
# name:certificate-transparency-go pl:Go star:278
# name:neper pl:C star:86
# name:autofdo pl:C++ star:120
# name:ARC-GEN pl:Python star:4
# name:fresnel pl:Go star:18
# name:dart_cli_pkg pl:Dart star:24
# name:fiddle pl:Python star:20
# name:elemental2 pl:Java star:38
# name:jsinterop-base pl:Java star:17
# name:jsinterop-annotations pl:Java star:8
# name:jsinterop-generator pl:Java star:23
# name:genie-for-sap-abap-ai-assistant-sample pl:ABAP star:7
# name:omaha-client pl:Rust star:4
# name:sbat-rs pl:Rust star:7
# name:authenticode-rs pl:Rust star:12
# name:gpt-disk-rs pl:Rust star:12
# name:trillian-examples pl:Go star:67
# name:hackable_diffusion pl:Python star:2
# name:zimtohrli pl:Jupyter Notebook star:10
# name:safevalues pl:TypeScript star:15
# name:uri.dart pl:Dart star:43
# name:mangle pl:Go star:145
# name:mono_repo.dart pl:Dart star:33
# name:python-fire pl:Python star:1500
# ページ13: https://github.com/orgs/google/repositories?page=13
# ページ13のセクター数: 30
# name:gn-language-server pl:Rust star:4
# name:ragvis pl:N/A star:0
# name:xarray-tensorstore pl:Python star:5
# name:flogger pl:Java star:125
# name:breakpad pl:C++ star:770
# name:hotels-template-library pl:C++ star:7
# name:google-ctf pl:Python star:582
# name:process_runner pl:Dart star:7
# name:nsync pl:C star:94
# name:quic-trace pl:C++ star:22
# name:libnss-cache pl:C star:26
# name:temporian pl:Python star:46
# name:mtail pl:Go star:393
# name:obr pl:C++ star:3
# name:turbinia pl:Python star:167
# name:google-java-format pl:Java star:904
# name:addlicense pl:Go star:189
# name:GoogleAppMeasurement pl:Swift star:21
# name:rrg pl:Rust star:27
# name:evt-air-risk-aiaa-scitech-2026 pl:Python star:1
# name:watchface pl:Kotlin star:5
# name:double-conversion pl:C++ star:302
# name:der-ascii pl:Go star:29
# name:pack pl:Rust star:14
# name:inject-common pl:Java star:8
# name:jaxite pl:Python star:7
# name:airio pl:Python star:11
# name:buzzer pl:Go star:37
# name:jpegli pl:C++ star:35
# name:ts-bridge pl:Go star:20
# ページ14: https://github.com/orgs/google/repositories?page=14
# ページ14のセクター数: 30
# name:slo-generator pl:Python star:87
# name:nsscache pl:Python star:59
# name:autobound pl:Python star:19
# name:pdsl-xray pl:Java star:3
# name:TestParameterInjector pl:Java star:37
# name:test-server pl:Go star:8
# name:sbsim pl:Python star:35
# name:tracey pl:Go star:0
# name:smbios-validation-tool pl:Go star:19
# name:pmax_best_practices_dashboard pl:Shell star:16
# name:pubmed-rag pl:Jupyter Notebook star:1
# name:loudness_ebur128 pl:C++ star:2
# name:python-proto-converter pl:Python star:3
# name:pathways-job pl:Go star:5
# name:humanio pl:JavaScript star:6
# name:anonymous-tokens pl:C++ star:22
# name:eDistantObject pl:Objective-C star:35
# name:built_value.dart pl:Dart star:192
# name:fleetspeak pl:Go star:31
# name:yamlfmt pl:Go star:61
# name:tf-shell pl:Python star:3
# name:rootcanal pl:C++ star:9
# name:skcms pl:N/A star:2
# name:deepvariant pl:Python star:767
# name:drjax pl:Python star:1
# name:jaxloop pl:Jupyter Notebook star:2
# name:private-join-and-compute pl:C++ star:151
# name:gnxi pl:Python star:123
# name:winops pl:Go star:15
# name:intellij-community pl:Java star:5600
# ページ15: https://github.com/orgs/google/repositories?page=15
# ページ15のセクター数: 30
# name:snappy pl:C++ star:1000
# name:wireit pl:TypeScript star:114
# name:aarch64-paging pl:Rust star:10
# name:synopsys-dw-uart pl:Rust star:0
# name:command-fds pl:Rust star:8
# name:OpenSK pl:Rust star:318
# name:capsem pl:Python star:0
# name:private-membership pl:C++ star:13
# name:yapf pl:Python star:902
# name:osv-scanner-v1 pl:Go star:2
# name:rune pl:C star:46
# name:trillian-website pl:HTML star:20
# name:shell-encryption pl:C++ star:41
# name:vanir pl:Python star:29
# name:cabbie pl:Go star:20
# name:travel-impact-model pl:N/A star:26
# name:kotlin pl:Kotlin star:6100
# name:nsjail pl:C++ star:293
# name:sandboxed-api pl:C++ star:194
# name:deepsomatic pl:N/A star:41
# name:licenseclassifier pl:Go star:79
# name:distbench pl:C++ star:17
# name:ide-perf pl:Kotlin star:14
# name:native-pkcs11 pl:Rust star:18
# name:mpact-sim pl:C++ star:8
# name:webview-ads pl:HTML star:1
# name:gematria pl:Python star:18
# name:taxinomia pl:Go star:0
# name:opendocs pl:N/A star:51
# name:jaxopt pl:Python star:73
# ページ16: https://github.com/orgs/google/repositories?page=16
# ページ16のセクター数: 30
# name:threat-team pl:YARA star:7
# name:generative-ai-docs pl:Jupyter Notebook star:738
# name:oss-policies-info pl:N/A star:23
# name:cloud-forensics-utils pl:Python star:90
# name:play-unreal-engine-plugin pl:C++ star:6
# name:security-testbeds pl:Tcl star:43
# name:amber pl:C++ star:70
# name:proto-lens pl:Haskell star:118
# name:play-services-plugins pl:Java star:155
# name:packetdrill pl:C star:232
# name:codemirror.dart pl:Dart star:33
# name:emboss pl:Python star:26
# name:playground-elements pl:TypeScript star:61
# name:snippet-uiautomator pl:Java star:21
# name:slowjam pl:HTML star:14
# name:fswalker pl:Go star:11
# name:sanitizers pl:C star:1100
# name:reflectable.dart pl:Dart star:63
# name:private-compute-services pl:Java star:118
# name:tarpc pl:Rust star:213
# name:llm-sidebar-with-context pl:JavaScript star:1
# name:mediapy pl:Jupyter Notebook star:20
# name:learn-oss-with-google pl:Python star:10
# name:google.github.io pl:HTML star:68
# name:minimalloc pl:C++ star:15
# name:smccc pl:Rust star:3
# name:s2a-proto pl:N/A star:6
# name:s2a-go pl:Go star:10
# name:GoogleUtilities pl:Objective-C star:57
# name:mount-zip pl:C++ star:19
# ページ17: https://github.com/orgs/google/repositories?page=17
# ページ17のセクター数: 30
# name:dnsmasq_exporter pl:Go star:61
# name:libultrahdr pl:C++ star:46
# name:GTMAppAuth pl:Swift star:220
# name:ffn pl:Python star:103
# name:trax pl:Python star:828
# name:mobly-wifi pl:Python star:0
# name:CausalImpact pl:R star:260
# name:create-service-account pl:Python star:12
# name:wmt-mqm-human-evaluation pl:N/A star:11
# name:fhir pl:C++ star:203
# name:polymorphicDSL pl:Java star:6
# name:apitools pl:Python star:116
# name:flink-connector-gcp pl:Java star:3
# name:bundletool pl:Java star:410
# name:glome pl:C star:18
# name:rdma-unit-test pl:C++ star:16
# name:kafel pl:C star:54
# name:GiftStick pl:Python star:21
# name:minja pl:C++ star:25
# name:gin-config pl:Python star:119
# name:quahog pl:Go star:1
# name:sagetv pl:Java star:173
# name:protobuf-gradle-plugin pl:Groovy star:282
# name:struct2tensor pl:Python star:21
# name:material-design-icons pl:N/A star:9700
# name:closure-compiler-npm pl:JavaScript star:71
# name:allocation-instrumenter pl:Java star:89
# name:draco pl:C++ star:1000
# name:jscin pl:JavaScript star:18
# name:kati pl:Rust star:121
# ページ18: https://github.com/orgs/google/repositories?page=18
# ページ18のセクター数: 30
# name:GoogleDataTransport pl:Objective-C star:36
# name:cql pl:Go star:12
# name:interop-ios-for-google-sdks pl:Objective-C star:3
# name:app-check pl:Objective-C star:6
# name:fully-homomorphic-encryption pl:C++ star:266
# name:strict-csp pl:TypeScript star:10
# name:jaxonnxruntime pl:Python star:23
# name:subcommands pl:Go star:50
# name:ukey2 pl:Java star:20
# name:dataflow-ml-starter pl:Python star:8
# name:async-request-dispatcher-rs pl:Rust star:0
# name:virtual-broadcast-production-assistant pl:JavaScript star:16
# name:honggfuzz pl:C star:528
# name:kctf pl:Go star:75
# name:gcp_scanner pl:Python star:106
# name:bigwheels pl:C++ star:39
# name:web-game-samples pl:JavaScript star:12
# name:fleetspeak-rs pl:Rust star:7
# name:eng-edu pl:Jupyter Notebook star:428
# name:certtostore pl:Go star:32
# name:edward2 pl:Jupyter Notebook star:78
# name:fuse-archive pl:C++ star:24
# name:github-webhook-pubsub-bridge pl:Go star:3
# name:safe-mmio pl:Rust star:5
# name:percore pl:Rust star:2
# name:go-licenses pl:Go star:128
# name:pybind11clif pl:C++ star:7
# name:shaderc-rs pl:Rust star:71
# name:closure-net pl:N/A star:0
# name:gops pl:Go star:337
# ページ19: https://github.com/orgs/google/repositories?page=19
# ページ19のセクター数: 30
# name:rax pl:Python star:12
# name:go-dap pl:Go star:28
# name:distributed_point_functions pl:C++ star:19
# name:rust-scudo pl:Rust star:9
# name:casimir pl:Rust star:0
# name:ota-analyzer pl:JavaScript star:4
# name:crumbles pl:Java star:0
# name:tuple.dart pl:Dart star:27
# name:grinder.dart pl:Dart star:36
# name:webdriver.dart pl:Dart star:47
# name:sync_http.dart pl:Dart star:16
# name:flutter-mediapipe pl:Dart star:25
# name:dart-basics pl:Dart star:18
# name:genc pl:C++ star:7
# name:carfac pl:Jupyter Notebook star:50
# name:kube-startup-cpu-boost pl:Go star:24
# name:jni-bind pl:C++ star:36
# name:autocxx pl:Rust star:165
# name:ghc-source-gen pl:Haskell star:32
# name:tsunami-security-scanner-callback-server pl:Java star:2
# name:partner-ads-experience pl:N/A star:0
# name:fast-isotropic-median-filter pl:C++ star:3
# name:ink-stroke-modeler pl:C++ star:17
# name:cad_campaign_anomaly_detector pl:JavaScript star:2
# name:pcie_lmt pl:Go star:3
# name:llvm-memprof pl:C++ star:0
# name:soql-tool pl:Apex star:2
# name:pl011-uart pl:Rust star:1
# name:saif-data pl:N/A star:0
# name:link-diver pl:TypeScript star:10
# ページ20: https://github.com/orgs/google/repositories?page=20
# ページ20のセクター数: 30
# name:wire pl:Go star:710
# name:grpc-binary pl:Swift star:2
# name:kunit-docs pl:HTML star:8
# name:evolve-forms pl:Apex star:45
# name:matched_markets pl:Python star:30
# name:flow-lens pl:TypeScript star:9
# name:distributed_graph_flow pl:N/A star:0
# name:go-eventlog pl:Go star:4
# name:Serberus pl:N/A star:0
# name:node-gles pl:C++ star:31
# name:co-op-4-all pl:TypeScript star:5
# name:data-driven-discretization-1d pl:Jupyter Notebook star:61
# name:howtodiv pl:Python star:2
# name:corpuscrawler pl:Python star:54
# name:accompanist pl:Kotlin star:654
# name:proto-task-queue pl:Python star:6
# name:arm-gic pl:Rust star:11
# name:python-spanner-orm pl:Python star:15
# name:multichase pl:C star:93
# name:graph-mining pl:C++ star:42
# name:executor.nvim pl:Lua star:9
# name:s2-geometry-library-java pl:Java star:237
# name:gnostic pl:Go star:272
# name:cluster-data pl:TeX star:206
# name:cassowary.dart pl:Dart star:15
# name:speaker-id pl:Python star:39
# name:localtoast pl:Go star:13
# name:generative-ai-go pl:Go star:91
# name:if-this-then-ad pl:TypeScript star:16
# name:dynamicworld pl:Jupyter Notebook star:22
# ページ21: https://github.com/orgs/google/repositories?page=21
# ページ21のセクター数: 30
# name:effcee pl:C++ star:40
# name:facade pl:Python star:16
# name:har2csv pl:JavaScript star:15
# name:reflow-list pl:TypeScript star:6
# name:model-viewer pl:TypeScript star:889
# name:esamplusplus pl:Python star:2
# name:devlibrary pl:Vue star:80
# name:shoptimizer pl:Python star:27
# name:safe-active-record pl:Ruby star:3
# name:practical-inverse-rendering-of-textured-and-translucent-appearance pl:Python star:12
# name:deluca pl:Jupyter Notebook star:17
# name:wci pl:Python star:12
# name:csv-to-firestore pl:Python star:9
# name:tacotron pl:HTML star:84
# name:sequence-layers pl:Python star:8
# name:conversational-surveys pl:JavaScript star:0
# name:ippusb pl:Rust star:4
# name:rubik pl:Python star:3
# name:vbootrom pl:C star:17
# name:web-hv pl:JavaScript star:12
# name:safety-web pl:TypeScript star:1
# name:argh pl:Rust star:94
# name:fedjax pl:Python star:42
# name:jsonnet pl:Jsonnet star:468
# name:chrome-ssh-agent pl:Go star:40
# name:hrx-ruby pl:Ruby star:3
# name:smc-hello-world pl:C star:0
# name:smc-common pl:C star:0
# name:deku pl:Go star:0
# name:code-review-bot pl:Go star:23
# ページ22: https://github.com/orgs/google/repositories?page=22
# ページ22のセクター数: 30
# name:truestreet pl:Go star:12
# name:python-card-framework pl:Python star:4
# name:gke-policy-automation pl:Go star:27
# name:ruy pl:C++ star:91
# name:wuffs pl:C star:142
# name:gmail-oauth2-tools pl:Python star:219
# name:triage-party pl:Go star:84
# name:web-api-gateway pl:Go star:22
# name:payjs pl:JavaScript star:12
# name:gonids pl:Go star:50
# name:flyweights pl:Rust star:3
# name:litmus pl:Vue star:4
# name:gtest-parallel pl:Python star:112
# name:ml-edu pl:Python star:2
# name:automotive-design-compose-protos pl:N/A star:1
# name:swissgl pl:JavaScript star:46
# name:rde-tester pl:C++ star:0
# name:refvnli pl:JavaScript star:0
# name:CoMMA pl:Rust star:5
# name:fsl-gaming pl:JavaScript star:8
# name:terraform-google-sqlserver pl:PowerShell star:1
# name:cost-attribution-solution pl:HCL star:12
# name:lmeval pl:Python star:21
# name:tachometer pl:TypeScript star:23
# name:ios-webkit-debug-proxy pl:C star:476
# name:apilark pl:N/A star:0
# name:tcli pl:Python star:6
# name:app-resource-bundle pl:N/A star:17
# name:gnostic-models pl:Go star:6
# name:recaptcha pl:PHP star:778
# ページ23: https://github.com/orgs/google/repositories?page=23
# ページ23のセクター数: 30
# name:ent pl:Go star:7
# name:CommonLoopUtils pl:Jupyter Notebook star:33
# name:ebpf-transport-monitoring pl:Go star:3
# name:rago pl:Python star:5
# name:aukera pl:Go star:10
# name:open-location-code pl:Java star:521
# name:jaxcam pl:Python star:1
# name:content_recommendation_using_word2vec pl:Python star:2
# name:go-jsonnet pl:Go star:249
# name:safehtml pl:Go star:22
# name:forest-data-partnership pl:Jupyter Notebook star:8
# name:lightweight_mmm pl:Python star:232
# name:gazoo-device pl:Python star:8
# name:bt-test-interfaces pl:Python star:9
# name:avatar pl:Python star:13
# name:paranoid_crypto pl:Python star:48
# name:proto-splitter pl:C++ star:0
# name:cadvisor pl:Go star:2400
# name:unblocking-detail-caption pl:HTML star:1
# name:auto-arborist pl:Jupyter Notebook star:3
# name:qkeras pl:Python star:110
# name:pts-bot pl:Rust star:2
# name:private-compute-libraries pl:Kotlin star:7
# name:vroom pl:Python star:28
# name:libaddressinput pl:C++ star:107
# name:android-key-attestation pl:Java star:71
# name:dv360-duplicator pl:TypeScript star:2
# name:eiffel pl:C star:0
# name:skyline_rl_lab pl:Jupyter Notebook star:0
# name:pseudo-identity-provider pl:Go star:4
# ページ24: https://github.com/orgs/google/repositories?page=24
# ページ24のセクター数: 30
# name:llvm-premerge-checks pl:Python star:37
# name:go-configfs-tsm pl:Go star:6
# name:grr pl:Python star:793
# name:sandwiched_compression pl:Jupyter Notebook star:12
# name:gemma_pytorch pl:Python star:563
# name:go-safeweb pl:Go star:84
# name:visualblocks pl:TypeScript star:178
# name:codesearch pl:Go star:395
# name:webauthndemo pl:TypeScript star:132
# name:UIforETW pl:C++ star:221
# name:hiba pl:C star:18
# name:pyink pl:Python star:2700
# name:vk-layer-for-rust pl:Rust star:4
# name:liblc3 pl:C star:78
# name:taqo-paco pl:Dart star:8
# name:jse4conf pl:Java star:6
# name:synthmark pl:C++ star:23
# name:df-conformer pl:HTML star:4
# name:zetasketch pl:Java star:23
# name:cairn pl:C++ star:3
# name:agi pl:Go star:157
# name:lullaby pl:C++ star:160
# name:visqol pl:C++ star:140
# name:glog pl:C++ star:2100
# name:uvq pl:Python star:18
# name:aegis_cipher pl:C++ star:4
# name:consent-based-conversion-adjustments pl:Python star:8
# name:containerdbg pl:C star:6
# name:Stereoscopic-Video-Generation-via-Denoising-Frame-Matrix pl:Python star:4
# name:iopddl pl:C++ star:2
# ページ25: https://github.com/orgs/google/repositories?page=25
# ページ25のセクター数: 30
# name:badwolf-drivers pl:Go star:7
# name:project-euphonia-app pl:Dart star:12
# name:badwolf pl:Go star:66
# name:fruit pl:C++ star:203
# name:sa360-bigquery-bootstrapper pl:Python star:4
# name:gemma-unity-plugin pl:C# star:7
# name:gemma-journey pl:C# star:2
# name:feabench pl:Python star:3
# name:hashr pl:Go star:7
# name:regexpand pl:Go star:2
# name:myelin-acorn-electron-hardware pl:Python star:20
# name:vscode-vnc pl:TypeScript star:2
# name:pica pl:Python star:12
# name:strangemeadowlark pl:Rust star:1
# name:note-maps pl:Go star:18
# name:seesaw pl:Go star:508
# name:curie pl:Jupyter Notebook star:3
# name:mobly-cros pl:Python star:2
# name:go-tika pl:Go star:41
# name:textfsm pl:Python star:187
# name:sherlock pl:Python star:1
# name:go-tspi pl:Go star:22
# name:kernel-sanitizers pl:Python star:90
# name:file-header pl:Rust star:3
# name:extra-keyboards-for-chrome-os pl:JavaScript star:130
# name:libprotobuf-mutator pl:C++ star:127
# name:crc32c pl:C++ star:149
# name:codeworld pl:Haskell star:199
# name:smali pl:Java star:53
# name:android-riscv64 pl:N/A star:15
# ページ26: https://github.com/orgs/google/repositories?page=26
# ページ26のセクター数: 30
# name:unisim pl:Python star:9
# name:ml-metadata pl:C++ star:171
# name:kmsan pl:C star:64
# name:play-asset-delivery-unity pl:C# star:3
# name:play-appbundle-unity pl:C# star:2
# name:file-based-test-driver pl:C++ star:3
# name:oauth2l pl:Go star:85
# name:ads-privacy pl:N/A star:136
# name:trusted-types-helper pl:TypeScript star:1
# name:search-in-apps pl:Swift star:0
# name:eslint-config-google pl:JavaScript star:137
# name:go-replayers pl:Go star:38
# name:uVkCompute pl:C++ star:42
# name:dfdewey pl:Python star:7
# name:CFU-Playground pl:Verilog star:148
# name:sqlcommenter pl:PHP star:83
# name:picatrix pl:Python star:17
# name:shadertrap pl:C++ star:10
# name:lldb-eval pl:C++ star:19
# name:pasta pl:Python star:39
# name:LogicLM pl:HTML star:2
# name:wuffs-mirror-release-c pl:C star:21
# name:image_mix pl:Python star:0
# name:page-alloc-bench pl:Go star:0
# name:grizzly pl:Python star:11
# name:tf-quant-finance pl:Python star:650
# name:coding-with-chrome pl:JavaScript star:169
# name:html-to-jsonld-converter pl:Python star:1
# name:gopacket pl:Go star:1100
# name:RB-Modulation pl:Jupyter Notebook star:28
# ページ27: https://github.com/orgs/google/repositories?page=27
# ページ27のセクター数: 30
# name:briolette pl:Rust star:13
# name:bbr pl:N/A star:681
# name:py-lab-hal pl:Python star:6
# name:bsynth pl:C++ star:7
# name:.github pl:N/A star:347
# name:snowflake-to-bq-data-transfer-tool pl:Java star:1
# name:password-alert pl:JavaScript star:102
# name:moodle-on-gcp pl:Shell star:24
# name:glance-experimental-tools pl:Kotlin star:11
# name:myanmar-tools pl:Java star:85
# name:k8s-digester pl:Go star:21
# name:splice pl:Go star:24
# name:cc-device-plugin pl:Go star:3
# name:project-OCEAN pl:Python star:19
# name:git-pull-request-mirror pl:Go star:13
# name:weasel pl:Go star:19
# name:parse-ego4d pl:Jupyter Notebook star:2
# name:deepconsensus pl:Python star:38
# name:deeppolisher pl:Jupyter Notebook star:7
# name:makerspace-auth pl:Python star:29
# name:material-design-lite pl:HTML star:5000
# name:patrick pl:R star:17
# name:xr-objects pl:C# star:20
# name:dlc-insight-lab pl:JavaScript star:1
# name:j2cl-protobuf pl:JavaScript star:10
# name:yarsa pl:Go star:0
# name:googlesre pl:TypeScript star:31
# name:android-auto-companion-android pl:Kotlin star:8
# name:automl pl:Jupyter Notebook star:1500
# name:gdb_gcore_point pl:Python star:1
# ページ28: https://github.com/orgs/google/repositories?page=28
# ページ28のセクター数: 30
# name:serde_json5 pl:Rust star:15
# name:emoji-scavenger-hunt pl:TypeScript star:200
# name:android-auto-companion-ios pl:Swift star:7
# name:library-wrapper-unity-common pl:C# star:1
# name:lottie-tools pl:Rust star:2
# name:speedy pl:C++ star:8
# name:pebble pl:C star:379
# name:volley pl:Java star:756
# name:open-sztp pl:Go star:2
# name:pyu2f pl:Python star:27
# name:biva pl:C++ star:1
# name:marl pl:C++ star:196
# name:cppdap pl:C++ star:63
# name:uem_poc pl:TypeScript star:0
# name:new-project pl:N/A star:163
# name:go-cmp pl:Go star:218
# name:mlir-hs pl:Haskell star:16
# name:webrisk pl:Go star:40
# name:csp-evaluator pl:TypeScript star:50
# name:multichannel-audio-tools pl:C++ star:36
# name:pprof-nodejs pl:JavaScript star:31
# name:hctr2 pl:C star:2
# name:santa-tracker-web pl:JavaScript star:158
# name:jira-to-issues pl:TypeScript star:4
# name:best pl:Rust star:13
# name:alu-api pl:Jupyter Notebook star:1
# name:haskell-indexer pl:Haskell star:20
# name:latexify_py pl:Python star:397
# name:abseil-cpp-binary pl:Swift star:5
# name:fuzzbench pl:Python star:287
# ページ29: https://github.com/orgs/google/repositories?page=29
# ページ29のセクター数: 30
# name:jarjar pl:Java star:31
# name:xdtk pl:Java star:3
# name:play-integrity-unity pl:C# star:2
# name:play-in-app-reviews-unity pl:C# star:1
# name:play-in-app-updates-unity pl:C# star:5
# name:santa pl:Objective-C++ star:296
# name:play-core-unity pl:C# star:1
# name:android-auto-companion-app pl:Dart star:1
# name:orbit pl:C++ star:359
# name:leveldb pl:C++ star:8100
# name:ctrdac pl:Go star:1
# name:mail-importer pl:Java star:95
# name:deck pl:Go star:2
# name:unsmear pl:C++ star:15
# name:library-wrapper-unity-openjdk8 pl:C# star:2
# name:calblink pl:Go star:14
# name:kir-holiday-lights pl:Shell star:9
# name:io-connect-2024-ui-workshop pl:CSS star:19
# name:snaplayout-for-xmonad pl:Haskell star:2
# name:dfiq pl:Python star:26
# name:git-tree pl:Rust star:7
# name:learn_unsafe_rust pl:N/A star:13
# name:archat pl:TypeScript star:12
# name:summit-ast pl:Kotlin star:7
# name:rust-p9 pl:Rust star:7
# name:spiqa pl:Python star:3
# name:oxsea pl:Rust star:0
# name:re2j pl:Java star:163
# name:megalista pl:Python star:56
# name:serde_json_lenient pl:Rust star:9
# ページ30: https://github.com/orgs/google/repositories?page=30
# ページ30のセクター数: 30
# name:bulk-actions-framework pl:Apex star:1
# name:rag-playground pl:Python star:16
# name:agi-dev-releases pl:Shell star:8
# name:fhir-app-examples pl:Kotlin star:27
# name:shopping_insider pl:Python star:13
# name:gnostic-grpc pl:Go star:53
# name:acjs pl:Go star:0
# name:go-react pl:Go star:2
# name:broken-dns pl:Go star:5
# name:xtoproto pl:Go star:16
# name:martian pl:Go star:255
# name:recursive-version-control-system pl:Go star:6
# name:spdmd pl:C++ star:0
# name:bulk_fhir_tools pl:Go star:9
# name:ondc-opencommerce pl:Go star:13
# name:goblet pl:Go star:32
# name:webpackager pl:Go star:20
# name:apt-golang-s3 pl:Go star:15
# name:fhir-dbt-analytics pl:Shell star:8
# name:vxsig pl:C++ star:33
# name:traceur-compiler pl:JavaScript star:575
# name:vimscript-language-server pl:Rust star:15
# name:cpp-from-the-sky-down pl:HTML star:34
# name:tree-math pl:Python star:8
# name:go-streaming-globber pl:Go star:5
# name:clusterfuzzlite pl:N/A star:46
# name:ads-bi-suite pl:Shell star:2
# name:tcpgpudmarxd pl:C++ star:0
# name:play-common-unity pl:C# star:0
# name:play-unity-plugins pl:C# star:113
# ページ31: https://github.com/orgs/google/repositories?page=31
# ページ31のセクター数: 30
# name:codex pl:Jupyter Notebook star:5
# name:sre_yield pl:Python star:46
# name:lintush pl:JavaScript star:8
# name:emoji-segmenter pl:C star:16
# name:unity-anr-plugin pl:Java star:0
# name:imageinwords pl:JavaScript star:7
# name:android-emulator-container-scripts pl:Python star:283
# name:werm pl:C star:4
# name:season-of-docs pl:N/A star:1000
# name:uuid pl:Go star:405
# name:android-auto-companion-calendarsync-ios pl:Swift star:1
# name:ionosphere pl:Jupyter Notebook star:0
# name:takeout pl:N/A star:0
# name:promises pl:Objective-C star:304
# name:iba-opt-out-plugin pl:JavaScript star:0
# name:dopamine pl:Jupyter Notebook star:1400
# name:docci pl:HTML star:0
# name:compute-virtual-ethernet-dpdk pl:C star:0
# name:angular-directed-graph pl:TypeScript star:4
# name:skywater-pdk pl:Python star:432
# name:safearchive pl:Go star:2
# name:gts pl:TypeScript star:210
# name:fuzzing pl:C++ star:446
# name:slang-gaussian-rasterization pl:Python star:8
# name:talkback pl:Java star:233
# name:langsvr pl:C++ star:5
# name:coroutine-stacks pl:Kotlin star:6
# name:devtools-driver pl:Java star:8
# name:account-provisioning-for-google-apps pl:Java star:20
# name:chicago-brick pl:TypeScript star:36
# ページ32: https://github.com/orgs/google/repositories?page=32
# ページ32のセクター数: 30
# name:tour-of-wgsl pl:TypeScript star:22
# name:crfs pl:Go star:68
# name:cql-on-beam pl:Java star:0
# name:capsicum-test pl:C++ star:22
# name:docker-explorer pl:Python star:46
# name:graphicsfuzz pl:Java star:115
# name:CodeCity pl:JavaScript star:36
# name:moriarty pl:C++ star:0
# name:uis-rnn pl:Python star:321
# name:purr pl:Shell star:4
# name:karma-webkit-launcher pl:JavaScript star:3
# name:yaml-ui-editor pl:Java star:11
# name:supl-client pl:Java star:30
# name:robotstxt-spec-test pl:Java star:8
# name:step49-2020 pl:Java star:2
# name:robotstxt-java pl:Java star:22
# name:exposure-notifications-private-analytics-ingestion pl:Java star:11
# name:play-work pl:Java star:44
# name:grr-doc pl:Shell star:153
# name:eng-practices pl:N/A star:2000
# name:tec-web-assignments pl:JavaScript star:4
# name:webdriver-shadow-dom pl:Kotlin star:0
# name:drive-file-search-fix pl:JavaScript star:1
# name:gousb pl:Go star:134
# name:bayesnf pl:Python star:18
# name:funke-eudi-wallet-prototype pl:Kotlin star:0
# name:vimdoc pl:Python star:29
# name:paseos pl:JavaScript star:14
# name:tsunami pl:TypeScript star:6
# name:hrx pl:SCSS star:10
# ページ33: https://github.com/orgs/google/repositories?page=33
# ページ33のセクター数: 30
# name:english-- pl:JavaScript star:0
# name:clif pl:C++ star:125
# name:grrshell pl:Python star:2
# name:cdc-file-transfer pl:C++ star:117
# name:devops-governance pl:N/A star:24
# name:google-visualization pl:TypeScript star:3
# name:price_visibility_booster pl:JavaScript star:1
# name:vim-codefmt pl:Vim Script star:104
# name:project-gameface pl:Java star:84
# name:Vulkan-Errata pl:Python star:1
# name:ad_language_monitor pl:JavaScript star:0
# name:cell_img pl:Jupyter Notebook star:2
# name:souper pl:C++ star:181
# name:audio-to-tactile pl:C star:16
# name:secrets-gradle-plugin pl:Kotlin star:121
# name:madi pl:Python star:25
# name:google-api-javascript-client pl:CSS star:1100
# name:btree pl:Go star:424
# name:it-cert-automation-practice pl:Python star:46000
# name:sxg-rs pl:Rust star:17
# name:lyra pl:C++ star:367
# name:schemarama pl:JavaScript star:25
# name:premium-vs-standard-network-latency pl:Shell star:0
# name:lut3d_utils pl:Python star:1
# name:rust-derive-fuzztest pl:Rust star:3
# name:real-time-intelligence-workshop pl:Jupyter Notebook star:2
# name:ghost-kernel pl:C star:41
# name:ansicolor-dart pl:Dart star:26
# name:libnop pl:C++ star:62
# name:zopfli pl:C++ star:344
# ページ34: https://github.com/orgs/google/repositories?page=34
# ページ34のセクター数: 30
# name:flutter.widgets pl:Dart star:528
# name:lifetime_value pl:Jupyter Notebook star:98
# name:ExoPlayer pl:Java star:6000
# name:woff2 pl:C++ star:216
# name:pwlfit pl:Jupyter Notebook star:8
# name:haloquest pl:Jupyter Notebook star:0
# name:robotstxt pl:C++ star:243
# name:closure-library pl:JavaScript star:1100
# name:omaha pl:C++ star:737
# name:pycnite pl:Python star:3
# name:model_search pl:Python star:513
# name:shopping-markup pl:Python star:15
# name:resultstoreui pl:Python star:12
# name:sg2im pl:Python star:233
# name:namebench pl:Go star:157
# name:flight-lab pl:Python star:10
# name:nccl-plugin-gpudirecttcpx pl:C++ star:5
# name:zazu pl:TypeScript star:11
# name:codewords pl:TypeScript star:8
# name:voice-builder pl:JavaScript star:138
# name:dynamic-form pl:TypeScript star:17
# name:werewolf_arena pl:Python star:13
# name:cargo-raze pl:Rust star:105
# name:safetext pl:Go star:6
# name:daguerreotype pl:TypeScript star:0
# name:sgtm-migrator pl:TypeScript star:2
# name:BIG-bench pl:Python star:614
# name:feedloader pl:Python star:8
# name:wikiloop-explorer pl:Vue star:7
# name:nodejs-container-image-builder pl:TypeScript star:22
# ページ35: https://github.com/orgs/google/repositories?page=35
# ページ35のセクター数: 30
# name:node-fastify-auto-push pl:TypeScript star:15
# name:streetview-publish-client-libraries pl:Java star:9
# name:defi-for-good-contracts pl:TypeScript star:4
# name:oodle-demo pl:HTML star:22
# name:making_with_ml pl:Jupyter Notebook star:186
# name:centaur pl:TypeScript star:4
# name:poseshield-tfjs pl:Vue star:9
# name:personfinder pl:Python star:192
# name:ai_assisted_display_creative pl:Python star:0
# name:automated-native-creatives pl:TypeScript star:1
# name:budoux-illustrator-script pl:TypeScript star:2
# name:aoss-django-sample-starter-project pl:Shell star:2
# name:nanopb-podspec pl:Ruby star:11
# name:setfilters pl:Java star:1
# name:agamotto pl:Python star:3
# name:balloon-learning-environment pl:Python star:15
# name:seatera pl:Python star:0
# name:diffseg pl:Jupyter Notebook star:25
# name:window-mirror pl:C# star:3
# name:keyword_factory pl:Python star:3
# name:merchant_center_repor_builder pl:Python star:1
# name:inspiration_tree pl:Jupyter Notebook star:12
# name:brain-tokyo-workshop pl:Jupyter Notebook star:343
# name:taxonomy_wizard pl:Python star:1
# name:mandiant-ti-client pl:Python star:7
# name:vertex-pipelines-boilerplate pl:Python star:3
# name:project_cartesian pl:Python star:3
# name:android-emulator-webrtc pl:JavaScript star:44
# name:password-sync-support-tool pl:VBScript star:15
# name:jsonapi pl:Go star:219
# ページ36: https://github.com/orgs/google/repositories?page=36
# ページ36のセクター数: 30
# name:ad-manager-alerter pl:Python star:5
# name:looker-studio-dashboard-cloner pl:TypeScript star:5
# name:gcp-scc-iac-validation-utils pl:Go star:0
# name:iconvg pl:C star:11
# name:playhvz pl:Kotlin star:21
# name:assetMG pl:TypeScript star:10
# name:bulkan pl:TypeScript star:8
# name:evojax pl:Jupyter Notebook star:109
# name:telluride_decoding pl:Python star:13
# name:font-go pl:Go star:7
# name:java-time-client pl:Java star:4
# name:project-euphonia-audiotool pl:TypeScript star:10
# name:task-oriented-queries pl:N/A star:1
# name:peripheral-customization-pwa pl:TypeScript star:4
# name:protobuf-extensibility-for-burp pl:Python star:5
# name:eventid-js pl:TypeScript star:20
# name:node-h2-auto-push pl:TypeScript star:21
# name:js-green-licenses pl:TypeScript star:28
# name:gasket-driver pl:C star:91
# name:wikiloop-doublecheck pl:TypeScript star:55
# name:data-layer-helper pl:JavaScript star:87
# name:dana pl:JavaScript star:23
# name:accname pl:TypeScript star:7
# name:libhidtelephony pl:TypeScript star:8
# name:incremental-dom pl:TypeScript star:179
# name:pixelate pl:TypeScript star:7
# name:conversion-audit pl:TypeScript star:2
# name:data-quality-monitor pl:TypeScript star:3
# name:product-dsa pl:Python star:3
# name:react-schemaorg pl:TypeScript star:19
# ページ37: https://github.com/orgs/google/repositories?page=37
# ページ37のセクター数: 30
# name:android-management-api-samples pl:Jupyter Notebook star:23
# name:creative-screenshots pl:TypeScript star:7
# name:dqm pl:Python star:4
# name:fusion-tables-archive-visualizer pl:TypeScript star:13
# name:nodejs-wiki pl:JavaScript star:7
# name:assortment-quality-for-shopping-ads pl:Python star:3
# name:eleventy-high-performance-blog pl:JavaScript star:272
# name:uafcs pl:Python star:0
# name:vsf-time-series pl:Python star:5
# name:oculi pl:Jupyter Notebook star:21
# name:android-uiconductor pl:Java star:24
# name:tamperchrome pl:TypeScript star:227
# name:gov-meetings-made-searchable pl:Python star:7
# name:patents-public-data pl:Jupyter Notebook star:178
# name:tweakr pl:JavaScript star:9
# name:ngrx-visualizer pl:TypeScript star:8
# name:mweb-analysis-tools pl:JavaScript star:4
# name:fusion-tables-drive-export pl:TypeScript star:5
# name:atheris pl:Python star:118
# name:vscode-zxdb pl:TypeScript star:1
# name:gtasks-md pl:Python star:7
# name:triggerator pl:TypeScript star:2
# name:service-worker-detector pl:JavaScript star:27
# name:cronet-transport-for-okhttp pl:Java star:43
# name:ditto-mocks pl:Apex star:8
# name:gps-measurement-tools pl:Java star:356
# name:stijl pl:JavaScript star:12
# name:schedviz pl:Go star:36
# name:grassland pl:TypeScript star:4
# name:synthesizer-io pl:Rust star:11
# ページ38: https://github.com/orgs/google/repositories?page=38
# ページ38のセクター数: 30
# name:eslint-closure pl:JavaScript star:12
# name:intermock pl:TypeScript star:71
# name:mpact-sim-codelabs pl:C++ star:1
# name:pybadges pl:Python star:150
# name:uv-metrics pl:Python star:5
# name:caliban pl:Python star:67
# name:verilogpp pl:Perl star:9
# name:t5patches pl:Python star:2
# name:vpn-libraries pl:C++ star:48
# name:go-p11-kit pl:Go star:16
# name:ngx_brotli pl:C star:228
# name:psp pl:C star:25
# name:google-sql-syntax-ts pl:TypeScript star:2
# name:fishy-pdf pl:Python star:0
# name:dv360-spend-monitoring-tool pl:JavaScript star:1
# name:diff-match-patch pl:Python star:1200
# name:hi-lassie pl:Python star:0
# name:lassie pl:Python star:3
# name:lkml-gerrit-bridge pl:Python star:8
# name:lecam-gan pl:Jupyter Notebook star:16
# name:prog-edu-assistant pl:Jupyter Notebook star:18
# name:har-sanitizer pl:Python star:13
# name:pre-commit-tool-hooks pl:Python star:6
# name:jsaction pl:JavaScript star:67
# name:deepmac pl:HTML star:3
# name:game-changing-assets pl:Jupyter Notebook star:0
# name:framework-for-osdu pl:Java star:5
# name:hintless_pir pl:C++ star:6
# name:jwt_verify_lib pl:C++ star:43
# name:prompt-to-prompt pl:Jupyter Notebook star:324
# ページ39: https://github.com/orgs/google/repositories?page=39
# ページ39のセクター数: 30
# name:how-unique-is-whose-web-browser pl:Jupyter Notebook star:0
# name:brunsli pl:C++ star:52
# name:gapid pl:Go star:329
# name:report2bq pl:Python star:3
# name:brandometer pl:Python star:7
# name:ldif pl:Python star:35
# name:pawn pl:C++ star:46
# name:empirical_calibration pl:Jupyter Notebook star:17
# name:shuwa pl:Python star:25
# name:tabletopaudio-action pl:TypeScript star:3
# name:hypernerf pl:Python star:107
# name:importlab pl:Python star:25
# name:ota-generator pl:Python star:5
# name:ai_video_dubbing pl:Python star:7
# name:prefab pl:Kotlin star:32
# name:starthinker pl:Python star:51
# name:golden-path-for-app-delivery pl:Go star:11
# name:ringli pl:C++ star:5
# name:oatts pl:JavaScript star:36
# name:web-starter-kit pl:HTML star:3000
# name:nerfies pl:Python star:264
# name:flexbox-layout pl:Kotlin star:1800
# name:cityhash pl:Shell star:193
# name:intellij-gn-plugin pl:Kotlin star:11
# name:safebrowsing pl:Go star:137
# name:AEUX pl:JavaScript star:64
# name:highwayhash pl:C++ star:186
# name:amot pl:Shell star:1
# name:licensecheck pl:Go star:84
# name:osdetector-gradle-plugin pl:Java star:22
# ページ40: https://github.com/orgs/google/repositories?page=40
# ページ40のセクター数: 30
# name:permhash pl:Python star:9
# name:flaxformer pl:Python star:32
# name:GTXiLib pl:Objective-C star:44
# name:esh pl:C star:66
# name:quota-monitoring-solution pl:Java star:23
# name:common-multicloud-runtime pl:N/A star:0
# name:cmrt pl:N/A star:0
# name:coding-with-chrome-libraries pl:JavaScript star:7
# name:macops-MOLXPCConnection pl:Objective-C star:11
# name:macops-MOLAuthenticatingURLSession pl:Objective-C star:10
# name:macops-molcodesignchecker pl:Objective-C star:15
# name:macops-molcertificate pl:Objective-C star:10
# name:example-demos-for-msft-workloads pl:HCL star:3
# name:python-adb pl:Python star:362
# name:cronutils pl:C star:20
# name:dmabuf_importer_helper pl:C star:0
# name:flutter-desktop-embedding pl:C++ star:605
# name:Accessibility-Test-Framework-for-Android pl:Java star:145
# name:devx-tools pl:Go star:17
# name:php-crc32 pl:PHP star:14
# name:step197-2020 pl:Java star:2
# name:adb-sync pl:Python star:180
# name:mint-line-follower pl:Python star:1
# name:gps-babel-tower pl:Python star:3
# name:simhospital pl:Go star:91
# name:adiantum pl:C star:48
# name:visionai pl:Python star:14
# name:xsecurelock pl:C star:62
# name:cel-policy-templates-go pl:Go star:21
# name:mawfs pl:Go star:12
# ページ41: https://github.com/orgs/google/repositories?page=41
# ページ41のセクター数: 30
# name:distla_core pl:Python star:1
# name:abstracttext pl:JavaScript star:10
# name:mobly-snippet-lib pl:N/A star:24
# name:skywater-pdk-libs-sky130_fd_pr pl:N/A star:27
# name:spdm-accelerator-requirement pl:N/A star:0
# name:longbet pl:C++ star:5
# name:dexmod pl:Python star:9
# name:space pl:Python star:8
# name:netbsd-gce pl:Shell star:10
# name:neural-tangents pl:Jupyter Notebook star:237
# name:redgrep pl:C++ star:21
# name:binja-hexagon pl:Python star:22
# name:hark pl:N/A star:1
# name:mobly-windows pl:Python star:1
# name:tree-sitter-fidl pl:C star:1
# name:bazel_rules_install pl:Starlark star:15
# name:putting-dune pl:Python star:1
# name:hierarchical-state-machine.dart pl:Dart star:4
# name:casa-android pl:Kotlin star:15
# name:security-crawl-maze pl:HTML star:41
# name:cordova-plugin-browsertab pl:Java star:147
# name:csv2pprof pl:Go star:1
# name:compact_enc_det pl:C star:85
# name:grafika pl:Java star:1500
# name:gwtmockito pl:Java star:54
# name:navi pl:Jupyter Notebook star:2
# name:eidos-audition pl:C++ star:7
# name:alligator2 pl:Python star:23
# name:process-tree pl:C++ star:0
# name:hashtable-benchmarks pl:Jupyter Notebook star:18
# ページ42: https://github.com/orgs/google/repositories?page=42
# ページ42のセクター数: 30
# name:json5format pl:Rust star:19
# name:gemmlowp pl:C++ star:456
# name:play-licensing pl:Java star:59
# name:net_http pl:C++ star:7
# name:objax pl:Python star:74
# name:safeopen pl:Go star:4
# name:todo-tracks pl:Go star:25
# name:alertmanager-irc-relay pl:Go star:19
# name:crossmodal-3600 pl:HTML star:1
# name:piex pl:C++ star:26
# name:pkcs11test pl:C++ star:51
# name:ceviche-challenges pl:Python star:14
# name:flutter.plugins pl:Dart star:57
# name:DOM-Tutorials pl:HTML star:6
# name:memutil pl:Python star:0
# name:dsg pl:HTML star:0
# name:zoekt pl:N/A star:115
# name:android-lint-performance-probe pl:Java star:16
# name:break-a-scene pl:Python star:26
# name:kinda-tidy pl:Python star:1
# name:asml pl:N/A star:0
# name:impl_trait_utils pl:Rust star:2
# ...
# ページ81: https://github.com/orgs/google/repositories?page=81
# ページ81のセクター数: 30
# name:swift-cmark pl:C star:617
# name:maddpg-replication pl:Jupyter Notebook star:13
# name:node-armor pl:N/A star:0
# name:virtualdesktops-extension pl:JavaScript star:13
# name:nips_assignments pl:C++ star:13
# name:sparrowhawk pl:Shell star:59
# name:zooshi pl:C++ star:57
# name:http_prefetching pl:JavaScript star:6
# name:kv-s3105c pl:C star:5
# name:fastboot-mobile pl:Kotlin star:13
# name:amss pl:R star:28
# name:search-samples pl:Java star:238
# name:abstreet pl:Rust star:6
# name:dl_bounds pl:Python star:8
# name:chrome-tabber pl:JavaScript star:7
# name:beacon-platform pl:N/A star:258
# name:dcm_bulk_onboarding pl:JavaScript star:3
# name:fast-simple-lcsk pl:C++ star:9
# name:dcm-video-uploader pl:Python star:12
# name:TouchTime pl:Java star:19
# name:uniflow-polymer pl:HTML star:15
# name:rally pl:Java star:10
# name:teknowledge pl:Python star:15
# name:clerk pl:C++ star:16
# name:ahdlc pl:C star:4
# name:aperture_supervision pl:Python star:15
# name:YetAnotherChatApp pl:Java star:8
# name:grittibanzli pl:C++ star:6
# name:ds-trix-addon pl:JavaScript star:13
# name:hat-backup pl:Rust star:30
# ページ82: https://github.com/orgs/google/repositories?page=82
# ページ82のセクター数: 30
# name:angular-sticky-element pl:TypeScript star:9
# name:vae-seq pl:Python star:32
# name:cloud-cup pl:JavaScript star:8
# name:cloud-cup-android pl:Java star:34
# name:fest pl:N/A star:10
# name:decoupled_gaussian_process pl:Python star:8
# name:safevarargs pl:N/A star:13
# name:opentest pl:N/A star:0
# name:encrypted-bigquery-client pl:Python star:34
# name:rbe-integration-test pl:Python star:5
# name:chained-promise pl:TypeScript star:18
# name:synergyfinderengineered pl:R star:5
# name:amp-client-id-library pl:JavaScript star:13
# name:go-trace pl:Go star:10
# name:hell0world-curriculum pl:HTML star:8
# name:intelligent_annotation_dialogs pl:Jupyter Notebook star:7
# name:cornerstoneMath pl:JavaScript star:46
# name:burst-denoising pl:Python star:58
# name:generativemloncloud pl:Python star:14
# name:aiyprojects-deeplearn-tensorflow pl:TypeScript star:10
# name:tensorflow-tools pl:JavaScript star:11
# name:hugeml pl:N/A star:0
# name:coq-bpf pl:Coq star:8
# name:pinotify pl:Java star:3
# name:CallBuilder pl:Java star:24
# name:catnip pl:Python star:10
# name:yaricv32 pl:Verilog star:10
# name:unigem-objective-c pl:Objective-C star:7
# name:speech_style_transfer pl:HTML star:4
# name:perf_api.dart pl:Dart star:19
# ページ83: https://github.com/orgs/google/repositories?page=83
# ページ83のセクター数: 30
# name:golden pl:Go star:3
# name:latency-benchmark pl:C star:38
# name:joint_vae pl:OpenEdge ABL star:12
# name:stumblybot pl:Python star:12
# name:mt pl:C++ star:13
# name:cornerstoneWebImageLoader pl:JavaScript star:51
# name:streamy-dart pl:Dart star:22
# name:dicomParser pl:JavaScript star:232
# name:vulkan-cpp-library pl:C++ star:23
# name:bbcpu pl:Verilog star:11
# name:dev-on-chromeos-gce-setup pl:Shell star:5
# name:pbvi pl:Python star:8
# name:capture-thread pl:C++ star:29
# name:pblog pl:C star:9
# name:text2text pl:Python star:22
# name:ce-open-data-set pl:N/A star:18
# name:voice-iot-maker-demo pl:JavaScript star:21
# name:terminal-app-function-keys pl:Python star:23
# name:FakeMaker pl:JavaScript star:17
# name:genomics-protos pl:Python star:8
# name:clicktrackers-panel pl:Python star:8
# name:yara-procdump-python pl:C star:5
# name:streaming_hdp pl:Go star:8
# name:coursebuilder-android-container-module pl:Python star:12
# name:sync3k-server pl:Scala star:4
# name:tern-closure pl:JavaScript star:18
# name:helm-broker pl:Go star:12
# name:ndash pl:C++ star:17
# name:VRD pl:Python star:7
# name:sync3k-client pl:TypeScript star:5
# ページ84: https://github.com/orgs/google/repositories?page=84
# ページ84のセクター数: 30
# name:acme pl:Go star:51
# name:dart-sync-webdriver pl:Dart star:26
# name:dart-sync-socket pl:Dart star:18
# name:Legilimency pl:Python star:13
# name:mipsqa pl:Python star:10
# name:devicehub pl:Java star:11
# name:gtd-txt pl:Shell star:8
# name:bitutils pl:Python star:7
# name:sonic-midi pl:Ruby star:5
# name:gumbel_sinkhorn pl:Python star:18
# name:arc-xcode-test-engine pl:PHP star:16
# name:energystrategies pl:TypeScript star:7
# name:marmot pl:Go star:13
# name:clojure-turtle pl:Clojure star:33
# name:dev-on-chromeos-che pl:N/A star:7
# name:dev-on-chromeos-openvpn pl:Shell star:6
# name:keytransparency-java pl:Java star:9
# name:bocado pl:Python star:11
# name:anvil-build pl:Python star:15
# name:river pl:N/A star:0
# name:trix-auto-complete pl:JavaScript star:10
# name:MAB pl:R star:12
# name:idris-protobuf pl:Idris star:11
# name:energysimulation pl:Jupyter Notebook star:17
# name:pyrios pl:Go star:26
# name:thread-weaver pl:Java star:60
# name:cwd_jmp pl:Shell star:8
# name:kratu pl:JavaScript star:33
# name:codeu_coding_assessment_b_2017 pl:Java star:60
# name:coverage pl:Emacs Lisp star:12
# ページ85: https://github.com/orgs/google/repositories?page=85
# ページ85のセクター数: 30
# name:ts-gulp pl:N/A star:0
# name:git-annex-external-gcs pl:N/A star:0
# name:makerspace-emonth pl:KiCad Layout star:10
# name:paper-gui pl:HTML star:17
# name:testrunner-rosemary pl:Java star:9
# name:spline pl:Java star:14
# name:creatism pl:HTML star:9
# name:mockable_filesystem.dart pl:Dart star:8
# name:okay pl:Go star:10
# name:metaserver pl:Go star:5
# name:microdhcpd pl:Go star:8
# name:pubkeystore pl:Go star:6
# name:unimorph pl:HTML star:4
# name:GL-Shader-Validator pl:Python star:18
# name:light-my-piano pl:Python star:22
# name:grr_go_client pl:Go star:9
# name:fury pl:Go star:9
# name:grr_go_api_client pl:Go star:7
# name:rttcp pl:Python star:16
# name:functions-demo pl:JavaScript star:6
# name:packet-queue pl:Python star:10
# name:easybundler pl:Java star:19
# name:chkstream pl:Python star:10
# name:glmmplus pl:R star:7
# name:codeu_coding_assessment_2017 pl:Java star:100
# name:address-geocoder-js pl:HTML star:9
# name:classp pl:Bison star:14
# name:xmpmeta pl:C++ star:11
# name:depth_fusion pl:C++ star:6
# name:amp-pwa-demo pl:JavaScript star:33
# ページ86: https://github.com/orgs/google/repositories?page=86
# ページ86のセクター数: 30
# name:Zhi pl:Python star:14
# name:agata pl:JavaScript star:7
# name:prerender-test pl:JavaScript star:11
# name:audit-normalmap pl:C star:10
# name:varstruct pl:C++ star:15
# name:emre pl:C++ star:5
# name:simple-reinforcement-learning pl:Python star:30
# name:homebrew-google-authenticator pl:Ruby star:15
# name:request-test pl:Python star:5
# name:blockly-repo pl:N/A star:5
# name:pindrop pl:C++ star:27
# name:goldfinch pl:N/A star:17
# name:scene_lab pl:C++ star:21
# name:corgi pl:C++ star:32
# name:dropzone-polyfill pl:HTML star:5
# name:ot-crdt-papers pl:JavaScript star:26
# name:windowtester pl:Java star:19
# name:fpc pl:C star:5
# name:fchan-go pl:Go star:23
# name:xdelta3-decoder-js pl:C star:10
# name:appengine-phabricator pl:Shell star:15
# name:cpp-frp pl:C++ star:19
# name:yang_vocoder pl:MATLAB star:26
# name:keystone pl:Elm star:7
# name:adapt-googleanalytics pl:JavaScript star:6
# name:deepboost pl:C++ star:53
# name:mcic-coco pl:N/A star:13
# name:readahead pl:Go star:13
# name:source_transformer.dart pl:Dart star:4
# name:mcafp pl:Python star:17
# ページ87: https://github.com/orgs/google/repositories?page=87
# ページ87のセクター数: 30
# name:gtm-oauth pl:Objective-C star:23
# name:morphie pl:C++ star:15
# name:libgep pl:C++ star:19
# name:smilesparser pl:Python star:11
# name:built_json.dart pl:N/A star:10
# name:conferenceDB pl:HTML star:6
# name:indexable-pwa-samples pl:JavaScript star:14
# name:enum_class.dart pl:N/A star:7
# name:sass_generator pl:N/A star:0
# name:vpn-reverse-tether pl:C star:61
# name:protocall pl:Python star:6
# name:transliteration pl:N/A star:31
# name:power-traces pl:Protocol Buffer star:12
# name:indexed-db-as-promised pl:JavaScript star:4
# name:gotrace pl:N/A star:0
# name:cameraraw pl:Go star:13
# name:everythingisconnected pl:JavaScript star:5
# name:libkml pl:C++ star:55
# name:geovelo pl:JavaScript star:24
# name:gfw-toolkit pl:Python star:21
# name:googleapps-message-recall pl:Python star:19
# name:macops-MOMenu pl:Objective-C star:9
# name:dart2java pl:Java star:14
# name:param_runner pl:Shell star:8
# name:gde-speakersbureau pl:JavaScript star:12
# name:AppUpdateTrackerLib pl:Java star:12
# name:rustcxx pl:Rust star:22
# name:dualhttp pl:JavaScript star:11
# name:go-webdav pl:Go star:19
# name:dorusu-js pl:JavaScript star:15
# ページ88: https://github.com/orgs/google/repositories?page=88
# ページ88のセクター数: 30
# name:identity-toolkit-go-client pl:Go star:24
# name:dynamex-proto pl:Protocol Buffer star:11
# name:auto-common pl:N/A star:0
# name:auto-service pl:N/A star:0
# name:auto-factory pl:N/A star:0
# name:prudaq pl:Eagle star:32
# name:realtime-help pl:Python star:17
# name:pepper.js pl:JavaScript star:53
# name:instant-hangouts pl:JavaScript star:49
# name:LiquidFunPaint pl:Java star:54
# name:easy-gwt-mock pl:Java star:6
# name:gofountain pl:Go star:16
# name:VoltAir pl:C++ star:83
# name:bzip2-rpc pl:C star:9
# name:gipfeli pl:C++ star:26
# name:go-circuits pl:Go star:10
# name:rpki-mgmt pl:Puppet star:12
# name:simplecfg pl:Java star:8
# name:maketrace pl:C++ star:15
# name:Chrome.Docs pl:JavaScript star:9
# name:bluesky-watchface pl:C star:4
# name:slowfs pl:Go star:10
# name:arc-jazzy-linter pl:PHP star:4
# name:merge_pyi pl:Python star:12
# name:drone-firebase pl:Go star:12
# name:cncmicroscope-cad pl:OpenSCAD star:8
# name:access-bridge-explorer pl:C# star:57
# name:gitwf pl:N/A star:0
# name:arc-proselint pl:PHP star:11
# name:channel-id-enclave pl:N/A star:10
# ページ89: https://github.com/orgs/google/repositories?page=89
# ページ89のセクター数: 30
# name:generator-goro pl:JavaScript star:14
# name:xpaf pl:C++ star:54
# name:google-empty-test-module pl:N/A star:0
# name:cloud-reporting pl:Java star:6
# name:reagera pl:Java star:8
# name:py-decorators-tutorial pl:Jupyter Notebook star:11
# name:identity-toolkit-node-client pl:JavaScript star:16
# name:GOS-conventions pl:Shell star:10
# name:identity-toolkit-java-client pl:Java star:27
# name:jalic pl:C star:10
# name:arc-regex-line-length-linter pl:PHP star:8
# name:identity-toolkit-ruby-client pl:Ruby star:9
# name:file-system-stress-testing pl:C star:21
# name:linux-sensor pl:C star:11
# name:multibox pl:N/A star:95
# name:offline-content-packager pl:N/A star:20
# name:crush-tools pl:Shell star:21
# name:flutter-data pl:Dart star:9
# name:resolver-library pl:Python star:10
# name:hops pl:C++ star:12
# name:kythe-cloud9 pl:JavaScript star:3
# name:physical-web-core pl:N/A star:0
# name:flooefi pl:N/A star:0
# name:serialization.dart pl:Dart star:14
# name:templatekit pl:Objective-C star:9
# name:metrosvg pl:C++ star:12
# name:paramgmt pl:Python star:29
# name:pienoon pl:C++ star:112
# name:translation-cards pl:Java star:11
# name:topdown-btg-preordering pl:C++ star:10
# ページ90: https://github.com/orgs/google/repositories?page=90
# ページ90のセクター数: 30
# name:openpgp-interop pl:N/A star:6
# name:appengine-codiad pl:JavaScript star:30
# name:godata pl:Go star:14
# name:opentest4j pl:Java star:39
# name:identity-toolkit-php-client pl:PHP star:22
# name:google-maven-parents pl:N/A star:4
# name:identity-toolkit-python-client pl:Python star:21
# name:Refaster pl:Java star:18
# name:strabo pl:Elixir star:13
# name:http2preload pl:Go star:9
# name:checkers_classic pl:Python star:12
# name:node-nest pl:JavaScript star:12
# name:intellij-cmdline-vcs-plugin pl:Java star:4
# name:docopt-scripts pl:Go star:10
# name:xpra-upstart pl:N/A star:10
# name:steamkeysactivator pl:AppleScript star:18
# name:homebrew-xpra pl:Ruby star:10
# name:shipshape-demo pl:Python star:9
# name:hashing-demo pl:C++ star:12
# name:autopiper pl:C++ star:11
# name:inception pl:N/A star:170
# name:clang-lens pl:Haskell star:9
# name:crisis-info-hub pl:JavaScript star:16
# name:dart-immutables pl:Dart star:8
# name:streamhtmlparser pl:C star:10
# name:pods-helper pl:Objective-C star:10
# name:cluster-insight pl:Python star:24
# name:freebase-wikidata-converter pl:PHP star:27
# name:snappy-start pl:C star:23
# name:capsicum-man-pages pl:Groff star:3
# ページ91: https://github.com/orgs/google/repositories?page=91
# ページ91のセクター数: 30
# name:rust-multihash pl:Rust star:10
# name:organ-donor-app pl:N/A star:0
# name:trace-viewer pl:N/A star:77
# name:rowhammer-test pl:C++ star:200
# name:ferret pl:Java star:15
# name:module-server pl:JavaScript star:44
# name:autoparse pl:Ruby star:33
# name:android-studio-check pl:Java star:11
# name:chromeos-filesystems pl:JavaScript star:25
# name:gojiraw pl:Go star:9
# name:terminal-py pl:Python star:5
# name:lmctfy pl:C++ star:240
# name:dart-shapeshift pl:Dart star:8
# name:calenviroscreen pl:R star:5
# name:cncmicroscope-code pl:C++ star:10
# name:o3dtoydefense pl:JavaScript star:9
# name:epr pl:JavaScript star:12
# name:codename-mvsv pl:JavaScript star:10
# name:io-captions-gadget pl:Python star:9
# name:ytstatistics-demo pl:Java star:11
# name:sensei pl:C++ star:16
# name:comid pl:Dart star:18
# name:service_worker.dart pl:Dart star:10
# name:google-visualization-issues pl:N/A star:35
# name:dart-doc_coverage pl:Dart star:12
# name:voter-info-tool pl:JavaScript star:10
# name:chrome-language-immersion pl:JavaScript star:19
# name:coursebuilder_xblock_module pl:Python star:12
# name:py-html-contextual-escaping pl:Python star:9
# name:json-sans-eval pl:HTML star:11
# ページ92: https://github.com/orgs/google/repositories?page=92
# ページ92のセクター数: 30
# name:mysql-tools pl:Python star:78
# name:refr pl:C++ star:9
# name:coursebuilder-hello-world-module pl:Python star:5
# name:dart-emacs-plugin-unsupported pl:Emacs Lisp star:11
# name:older-mirrored-patches pl:N/A star:10
# name:objectfilter pl:Python star:10
# name:retrofit pl:Java star:7300
# name:nfc-smart-tag pl:Java star:6
# name:irrduino pl:Processing star:13
# name:reportlatency pl:Perl star:8
# name:gmailsnooze pl:JavaScript star:7
# name:deliberate pl:N/A star:0
# name:network-visualizer-x pl:N/A star:0
# name:reboot-somalia pl:N/A star:0
# name:citizen-x pl:N/A star:0
# name:pytypedecl pl:Python star:17
# name:rysim pl:Erlang star:14
# name:jsontoken-tmp pl:N/A star:0
# name:go-shlex pl:N/A star:0
# name:zarathustra pl:Java star:13
# name:pull-request-mailer pl:Haskell star:9
# name:elfling pl:C++ star:12
# name:vim-ft-vroom pl:Vim Script star:8
# name:picview-for-android pl:Java star:33
# name:picasa-app-demo pl:Java star:14
# name:web-starter-kit-extras pl:N/A star:29
# name:simple-pedometer pl:Java star:48
# name:sensor-data-collection-library pl:Java star:21
# name:ashier pl:Python star:15
# name:coursebuilder-lti-module pl:Python star:5
# ページ93: https://github.com/orgs/google/repositories?page=93
# ページ93のセクター数: 30
# name:episodes.dart pl:Dart star:26
# name:polymer-dart-log-controller pl:Dart star:16
# name:ebola-tools pl:Python star:9
# name:pubsubhubbub pl:N/A star:0
# name:dart-tagtree pl:Dart star:14
# name:turing-doodle pl:JavaScript star:68
# name:linear-book-scanner pl:Python star:25
# name:java-thread-sanitizer pl:Java star:25
# name:gin pl:N/A star:0
# name:go-glicko2 pl:N/A star:0
# name:rct-automation pl:C++ star:15
# name:Idris-dev pl:Haskell star:633
# name:forcefield pl:Gosu star:18
# name:dart-gif-encoder pl:Dart star:13
# name:glassbox pl:R star:10
# name:coursebuilder-learning-analytics pl:N/A star:0
# name:NLSdata pl:R star:8
# name:jenkins-flaky-test-report pl:N/A star:0
# name:build-debian-cloud pl:Python star:118
# name:dart-collab pl:Dart star:9
# name:wheelbarrow pl:Python star:14
# name:photo-sphere pl:N/A star:0
# name:oss-bench pl:N/A star:5
# name:heartbleed-burp-extension pl:Java star:13
# name:lab_device_proxy pl:Python star:8
# name:gdal-autotest2 pl:N/A star:0
# name:patchfield pl:Java star:43
# name:googleapps-password-generator pl:N/A star:30
# name:YouCompleteSubl pl:N/A star:0
# name:favcolor-findidp pl:N/A star:10
# ページ94: https://github.com/orgs/google/repositories?page=94
# ページ94のセクター数: 21
# name:appengine_xblock_runtime pl:Python star:16
# name:memcache-collections pl:Python star:21
# name:course-builder pl:N/A star:0
# name:favcolor-android pl:Java star:22
# name:systemjs pl:JavaScript star:20
# name:favcolor-ios pl:N/A star:0
# name:pixelcycle-sample-app pl:Dart star:14
# name:container-rfc pl:N/A star:23
# name:gae-channel-api.dart pl:Dart star:17
# name:ChannelPlate pl:JavaScript star:18
# name:testRunner pl:JavaScript star:9
# name:devtoolsExtended pl:JavaScript star:22
# name:self-hosted-rss-to-email pl:Go star:9
# name:zimu pl:C star:5
# name:tsviewdb pl:JavaScript star:21
# name:beta-binomial-fitting pl:N/A star:0
# name:wiberg-minimization pl:N/A star:10
# name:crx2app pl:JavaScript star:15
# name:concatenate.js pl:JavaScript star:18
# name:firmata.py pl:Python star:16
# name:sirius pl:N/A star:0

# %%
path = ''
db_name = 'github_google.db'

try:
    #DBへのコネクションを確立
    conn = sqlite3.connect(path + db_name)

    #SQL(ROBを操作するための言語)を実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # SQL文の作成
    # 複数レコードの挿入
    sql = "INSERT INTO cars (name, pl, star) VALUES (?, ?, ?);"

    # SQL文の実行
    cur.executemany(sql, repositories)

    conn.commit()  # 変更を保存
    

except sqlite3.Error as e:
    print('SQLite error:', e)
    
finally:
    # DBへの接続を閉じる
    conn.close()
